# %% [markdown]
# ### Economic Geography of Interwar Poland
# This notebook uses the administrative database and files with economic data to compute the GDP of Interwar Poland on the district level and present an overview of the Polish economic geography in the Interwar Period.
#
# It is a showcase of the use of the whole toolkit. An instance of the AdministrativeHistory class constructed with inputs describing administrative history is used as an API that allows to access, impute, and harmonize data in the database. In the mature form of the toolkit, a PostgreSQL database with economic data will be created and hosted online and a pip-installable package called interwar_poland_database will be publicly shared. The pip package will reconstruct the administrative base locally, and will connect as a read-only-user to the PostgreSQL database to import the necessary data. In this preliminary version of the toolkit, the economic data is stored in the CSV form.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Necessary imports
import pandas as pd
import numpy as np
import copy
from administrative_history.utils.helper_functions import load_adm_history_config, load_processing_config
from administrative_history.core.core import AdministrativeHistory
from administrative_history.core.processor import AdministrativeHistoryProcessor
from administrative_history.core.api import AdministrativeHistoryAPI
from administrative_history.core.plotter import AdministrativeHistoryPlotter
from administrative_history.utils.helper_functions import extract_date_parts, read_economic_csv_input

# %%
import os
os.chdir("../..")
plots_output_path = "E:/Studia/Studia magisterskie/Masterarbeit - Wirtschaftwissenschaft/post_master_data_plots"

# %%
# Load the administrative history, and processing configuration
config = load_adm_history_config("data/adm_histories/interwar_poland/adm_history_config.json")
processing_config = load_processing_config("data/datasets/interwar_poland_database/processing_config.json")

# Create an administrative history object
administrative_history = AdministrativeHistory(config, load_geometries=True)

# Create a data processor object
adm_history_processor = AdministrativeHistoryProcessor(processing_config, administrative_history)

# Create an api object
#adm_history_api = AdministrativeHistoryAPI(adm_history_processor=adm_history_processor, duckdb_path="data/datasets/interwar_poland_database/processed_data/interwar_poland_database.duckdb", overwrite_duckdb=True)

# Create a plotter object
adm_history_plotter = AdministrativeHistoryPlotter(administrative_history)
# Out:
# Loading changes list...
# ✅ Loaded 309 validated changes in 0.07 seconds.
# Loading initial state...
# ✅ Loaded initial state.
# Loading initial district registry...
# ✅ Loaded 292 validated districts in 0.03 seconds. Set their initial state timespans to (1921-02-19, 1939-09-01).
# Loading initial region registry...
# ✅ Loaded 19 validated regions in 0.00 seconds. Set their initial state timespans to (1921-02-19, 1939-09-01)
# Creating administrative history (sequentially applying changes)...
# ✅ Successfully applied all changes in 9.84 seconds. Administrative history database created.
# Loading territories...
# Loaded: districts_1922_generalized_dp_800m.shp (271 rows)
# Loaded: districts_1929_generalized_dp_800m.shp (281 rows)
# Loaded: districts_1931_generalized_dp_800m.shp (283 rows)
# Loaded: districts_1934_generalized_dp_800m.shp (264 rows)
# Loaded: districts_1939_generalized_dp_800m.shp (265 rows)
# ✅ Successfully loaded all territories in 1.26 seconds.
# Deducing all possible dist territories on the basis of the loaded ones.
# Iteration 0 of territory deduction.
# ✅ All possible information on territories deduced 0.07 seconds.
# Defining fallback territories for states with missing state information (where possible).
# [Warning] The district 'BARDIOWSKI' has no defined territory in any state. All district states' territories left as undefined (None).
# [Warning] The district 'BYTOM MIASTO' has no defined territory in any state. All district states' territories left as undefined (None).
# [Warning] The district 'BYTOM WIEŚ' has no defined territory in any state. All district states' territories left as undefined (None).
# [Warning] The district 'CZADECKI' has no defined territory in any state. All district states' territories left as undefined (None).
# [Warning] The district 'CZESKOCIESZYŃSKI' has no defined territory in any state. All district states' territories left as undefined (None).
# [Warning] The district 'FRYDECKI' has no defined territory in any state. All district states' territories left as undefined (None).
# [Warning] The district 'GLIWICKI' has no defined territory in any state. All district states' territories left as undefined (None).
# [Warning] The district 'KIEŻMARSKI' has no defined territory in any state. All district states' territories left as undefined (None).
# [Warning] The district 'NAMIESTOWSKI' has no defined territory in any state. All district states' territories left as undefined (None).
# [Warning] The district 'RACIBORSKI' has no defined territory in any state. All district states' territories left as undefined (None).
# [Warning] The district 'RUDZKI' has no defined territory in any state. All district states' territories left as undefined (None).
# [Warning] The district 'RYBNICKI (ŚLĄSK NIEMIECKI)' has no defined territory in any state. All district states' territories left as undefined (None).
# [Warning] The district 'SNIŃSKI' has no defined territory in any state. All district states' territories left as undefined (None).
# [Warning] The district 'STAROLUBOWELSKI' has no defined territory in any state. All district states' territories left as undefined (None).
# [Warning] The district 'STAROWIEJSKI' has no defined territory in any state. All district states' territories left as undefined (None).
# [Warning] The district 'TARNOGÓRSKI (ŚLĄSK NIEMIECKI)' has no defined territory in any state. All district states' territories left as undefined (None).
# [Warning] The district 'TROCKI' has no defined territory in any state. All district states' territories left as undefined (None).
# [Warning] The district 'TRZCIAŃSKI' has no defined territory in any state. All district states' territories left as undefined (None).
# [Warning] The district 'WILEŃSKI' has no defined territory in any state. All district states' territories left as undefined (None).
# [Warning] The district 'ZABRSKI' has no defined territory in any state. All district states' territories left as undefined (None).
# ✅ Successfully created fallback territories in 0.00 seconds.
# ✅ Successfully loaded 659 cities from data/adm_histories/interwar_poland/cities_coords/cities_coords.geojson
# Loading metadata of the data tables that will be harmonized...
# ✅ Successfully loaded metadata of raw data tables in 0.04 seconds.
# Loading processed data metadata...
# ✅ Successfully loaded harmonized data metadata in 0.06 seconds.

# %%
# Use administrative history to process all the input data tables to one administrative state
adm_history_processor.build_db(metadata_format=["json", "parquet"])
# Out:
# Harmonizing data in the 'data/datasets/interwar_poland_database/adm_units_raw_data/data/' folder.
# Constructing conversion matrix between two administrative states:
# Administrative State from: <AdministrativeState timespan=(1921-02-19, 1921-08-01), regions=19, districts=292>
# Administrative State to: <AdministrativeState timespan=(1934-07-23, 1937-04-01), regions=19, districts=282>
# ✅ Successfully constructed conversion dict in 0.27 seconds.
# Constructing conversion matrix based on the dict.
# ✅ Successfully constructed conversion matrix in 0.31 seconds.
# Processing 'data/datasets/interwar_poland_database/adm_units_raw_data/data/1921-education_ready.csv' with District-level raw data.
# E:\git_projects\border_harmonization_toolkit\src\administrative_history\utils\helper_functions.py:308: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# 📊 Completeness before imputation:
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Liczba ludności w wieku 10 lat i więcej/Miasta/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Liczba ludności w wieku 10 lat i więcej/Ogółem/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Liczba ludności w wieku 10 lat i więcej/Wieś/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Liczba ludności w wieku 10 lat i więcej/Miasta/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Liczba ludności w wieku 10 lat i więcej/Ogółem/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Liczba ludności w wieku 10 lat i więcej/Wieś/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Liczba ludności w wieku 10 lat i więcej/Miasta/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Liczba ludności w wieku 10 lat i więcej/Ogółem/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Liczba ludności w wieku 10 lat i więcej/Wieś/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Domowe/Miasta/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Domowe/Ogółem/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Domowe/Wieś/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Domowe/Miasta/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Domowe/Ogółem/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Domowe/Wieś/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Domowe/Miasta/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Domowe/Ogółem/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Domowe/Wieś/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Początkowe/Miasta/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Początkowe/Ogółem/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Początkowe/Wieś/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Początkowe/Miasta/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Początkowe/Ogółem/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Początkowe/Wieś/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Początkowe/Miasta/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Początkowe/Ogółem/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Początkowe/Wieś/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Średnie/Miasta/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Średnie/Ogółem/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Średnie/Wieś/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Średnie/Miasta/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Średnie/Ogółem/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Średnie/Wieś/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Średnie/Miasta/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Średnie/Ogółem/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Średnie/Wieś/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Zawodowe średnie i niższe/Miasta/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Zawodowe średnie i niższe/Ogółem/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Zawodowe średnie i niższe/Wieś/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Zawodowe średnie i niższe/Miasta/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Zawodowe średnie i niższe/Ogółem/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Zawodowe średnie i niższe/Wieś/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Zawodowe średnie i niższe/Miasta/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Zawodowe średnie i niższe/Ogółem/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Zawodowe średnie i niższe/Wieś/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Wyższe/Miasta/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Wyższe/Ogółem/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Wyższe/Wieś/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Wyższe/Miasta/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Wyższe/Ogółem/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Wyższe/Wieś/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Wyższe/Miasta/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Wyższe/Ogółem/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Wyższe/Wieś/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Niewiadome/Miasta/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Niewiadome/Ogółem/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Niewiadome/Wieś/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Niewiadome/Miasta/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Niewiadome/Ogółem/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Niewiadome/Wieś/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Niewiadome/Miasta/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Niewiadome/Ogółem/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Niewiadome/Wieś/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Nie umiało czytać/Miasta/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Nie umiało czytać/Ogółem/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Nie umiało czytać/Wieś/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Nie umiało czytać/Miasta/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Nie umiało czytać/Ogółem/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Nie umiało czytać/Wieś/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Nie umiało czytać/Miasta/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Nie umiało czytać/Ogółem/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Nie umiało czytać/Wieś/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Umiejętność czytania niewiadoma/Miasta/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Umiejętność czytania niewiadoma/Ogółem/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Umiejętność czytania niewiadoma/Wieś/r: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Umiejętność czytania niewiadoma/Miasta/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Umiejętność czytania niewiadoma/Ogółem/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Umiejętność czytania niewiadoma/Wieś/m: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Umiejętność czytania niewiadoma/Miasta/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Umiejętność czytania niewiadoma/Ogółem/k: 100.00%
#   - Spis powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Umiejętność czytania niewiadoma/Wieś/k: 100.00%
# 🔄 Applying harmonization...
# ✅ Finished processing in 0.50 seconds. Output: data/datasets/interwar_poland_database/processed_data/parquet/1921-education_ready.parquet
# Set data_table_metadata_dict.adm_state_date to 1934-10-01.\data_table_metadata_dict: data_table_id='1921-education_ready' adm_level='District' source='' link='' table='' page=None pdf_page=None description={'pol': 'Wykształcenie ludności w wieku 10 lat i powyżej wg. spisu powszechnego 1921 (stan na 30.09.1921).', 'eng': 'Educational attainment of the population aged 10 years and over according to the 1921 Census (state for 30.09.1921).'} date='30.09.1921' orig_adm_state_date=datetime.datetime(1921, 7, 30, 0, 0) adm_state_date=datetime.datetime(1934, 10, 1, 0, 0) standardization_comments='Dane dla występującego osobno Okręgu Dąbrowsko-Sosnowieckiego (taki powiat nie istniał w 1921 roku) zostały dodane do danych dla powiatu Będzińskiego.' harmonization_method='proportional_to_territory' imputation_method=None columns={'Census 1921/Educational attainment of the population aged 10 years and over/Number of people aged 10 years and over/Cities/r': ColumnMetadata(unit='', category={'pol': 'Spis Powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Liczba ludności w wieku 10 lat i więcej/Miasta/r', 'eng': 'Census 1921/Educational attainment of the population aged 10 years and over/Number of people aged 10 years and over/Cities/r'}, data_type='int', completeness=1.0, n_na=0, n_not_na=264, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Educational attainment of the population aged 10 years and over/Number of people aged 10 years and over/Total/r': ColumnMetadata(unit='', category={'pol': 'Spis Powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Liczba ludności w wieku 10 lat i więcej/Ogółem/r', 'eng': 'Census 1921/Educational attainment of the population aged 10 years and over/Number of people aged 10 years and over/Total/r'}, data_type='int', completeness=1.0, n_na=0, n_not_na=264, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Educational attainment of the population aged 10 years and over/Number of people aged 10 years and over/Rural Areas/r': ColumnMetadata(unit='', category={'pol': 'Spis Powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Liczba ludności w wieku 10 lat i więcej/Wieś/r', 'eng': 'Census 1921/Educational attainment of the population aged 10 years and over/Number of people aged 10 years and over/Rural Areas/r'}, data_type='int', completeness=1.0, n_na=0, n_not_na=264, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Educational attainment of the population aged 10 years and over/Number of people aged 10 years and over/Cities/m': ColumnMetadata(unit='', category={'pol': 'Spis Powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Liczba ludności w wieku 10 lat i więcej/Miasta/m', 'eng': 'Census 1921/Educational attainment of the population aged 10 years and over/Number of people aged 10 years and over/Cities/m'}, data_type='int', completeness=1.0, n_na=0, n_not_na=264, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Educational attainment of the population aged 10 years and over/Number of people aged 10 years and over/Total/m': ColumnMetadata(unit='', category={'pol': 'Spis Powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Liczba ludności w wieku 10 lat i więcej/Ogółem/m', 'eng': 'Census 1921/Educational attainment of the population aged 10 years and over/Number of people aged 10 years and over/Total/m'}, data_type='int', completeness=1.0, n_na=0, n_not_na=264, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Educational attainment of the population aged 10 years and over/Number of people aged 10 years and over/Rural Areas/m': ColumnMetadata(unit='', category={'pol': 'Spis Powszechny 1921/Wykształcenie ludności w wieku 10 lat i więcej/Liczba ludności w wieku 10 lat ...
# ✅ Successfully harmonized 'data/datasets/interwar_poland_database/adm_units_raw_data/data/1921-education_ready.csv' and saved to 'data/datasets/interwar_poland_database/processed_data/parquet/1921-education_ready.parquet' in 0.50 seconds
# Processing 'data/datasets/interwar_poland_database/adm_units_raw_data/data/1921-occupation_ready_clean.csv' with District-level raw data.
# 📊 Completeness before imputation:
#   - Indirect Occupation - Total: 98.48%
#   - Indirect Occupation - A. Agriculture and forestry: 98.48%
#   - Indirect Occupation - B. Mining and industry: 98.48%
#   - Indirect Occupation - C. Trade and insurance: 98.48%
#   - Indirect Occupation - D. Transport and communication: 98.48%
#   - Indirect Occupation - E. Public service, liberal professions: 98.48%
#   - Indirect Occupation - F. Army: 98.48%
#   - Indirect Occupation - G. Domestic service: 98.48%
#   - Indirect Occupation - H. Unemployed: 98.48%
#   - Indirect Occupation - N. Not further specified: 98.48%
# 🔄 Applying harmonization...
# ✅ Finished processing in 0.06 seconds. Output: data/datasets/interwar_poland_database/processed_data/parquet/1921-occupation_ready_clean.parquet
# Set data_table_metadata_dict.adm_state_date to 1934-10-01.\data_table_metadata_dict: data_table_id='1921-occupation_ready_clean' adm_level='District' source='' link='' table='' page=None pdf_page=None description={'pol': 'Struktura zatrudnienia wg. spisu powszechnego 1921 (stan na 30.09.1921). Aktywni zawodowo wraz z członkami rodzin, bezrobotni itd.', 'eng': 'Employment structure according to the 1921 national census (as of September 30, 1921). Economically active together with family members, unemployed etc.'} date='30.09.1921' orig_adm_state_date=datetime.datetime(1921, 7, 30, 0, 0) adm_state_date=datetime.datetime(1934, 10, 1, 0, 0) standardization_comments='Brakuje danych dla powiatu warszawskiego (jest tylko Warszawa). Podobnie może być w przypadku innych miast.' harmonization_method='proportional_to_territory' imputation_method=None columns={'Census 1921/Indirect Occupation/B. Mining and industry': ColumnMetadata(unit='', category={'eng': 'Census 1921/Indirect Occupation/B. Mining and industry', 'pol': 'Spis Powszechny 1921/Zawód Główny/B. Górnictwo i przemysł'}, data_type='int', completeness=0.9848484848484849, n_na=4, n_not_na=260, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Indirect Occupation/Total': ColumnMetadata(unit='', category={'eng': 'Census 1921/Indirect Occupation/Total', 'pol': 'Spis Powszechny 1921/Zawód Główny/Razem'}, data_type='int', completeness=0.9848484848484849, n_na=4, n_not_na=260, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Indirect Occupation/C. Trade and insurance': ColumnMetadata(unit='', category={'eng': 'Census 1921/Indirect Occupation/C. Trade and insurance', 'pol': 'Spis Powszechny 1921/Zawód Główny/C. Handel i ubezpieczenia'}, data_type='int', completeness=0.9848484848484849, n_na=4, n_not_na=260, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Indirect Occupation/G. Domestic service': ColumnMetadata(unit='', category={'eng': 'Census 1921/Indirect Occupation/G. Domestic service', 'pol': 'Spis Powszechny 1921/Zawód Główny/G. Służba domowa'}, data_type='int', completeness=0.9848484848484849, n_na=4, n_not_na=260, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Indirect Occupation/E. Public service, liberal professions': ColumnMetadata(unit='', category={'eng': 'Census 1921/Indirect Occupation/E. Public service, liberal professions', 'pol': 'Spis Powszechny 1921/Zawód Główny/E. Służba publiczna, wolne zawody'}, data_type='int', completeness=0.9848484848484849, n_na=4, n_not_na=260, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Indirect Occupation/A. Agriculture and forestry': ColumnMetadata(unit='', category={'eng': 'Census 1921/Indirect Occupation/A. Agriculture and forestry', 'pol': 'Spis Powszechny 1921/Zawód Główny/A. Rolnictwo i leśnictwo'}, data_type='int', completeness=0.9848484848484849, n_na=4, n_not_na=260, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Indirect Occupation/H. Unemployed': ColumnMetadata(unit='', category={'eng': 'Census 1921/Indirect Occupation/H. Unemployed', 'pol': 'Spis Powszechny 1921/Zawód Główny/H. Bezrobotni'}, data_type='int', completeness=0.9848484848484849, n_na=4, n_not_na=260, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Indirect Occupation/F. Army': ColumnMetadata(unit='', category={'eng': 'Census 1921/Indirect Occupation/F. Army', 'pol': 'Spis Powszechny 1921/Zawód Główny/F. Armia'}, data_type='int', completeness=0.9848484848484849, n_na=4, n_not_na=260, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Indirect Occupation/N. Not further specified': Co ...
# ✅ Successfully harmonized 'data/datasets/interwar_poland_database/adm_units_raw_data/data/1921-occupation_ready_clean.csv' and saved to 'data/datasets/interwar_poland_database/processed_data/parquet/1921-occupation_ready_clean.parquet' in 0.06 seconds
# Processing 'data/datasets/interwar_poland_database/adm_units_raw_data/data/1921-ethnicity_ready_clean.csv' with District-level raw data.
# E:\git_projects\border_harmonization_toolkit\src\administrative_history\utils\helper_functions.py:308: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# E:\git_projects\border_harmonization_toolkit\src\administrative_history\utils\helper_functions.py:308: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# E:\git_projects\border_harmonization_toolkit\src\administrative_history\utils\helper_functions.py:308: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# E:\git_projects\border_harmonization_toolkit\src\administrative_history\utils\helper_functions.py:308: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# 📊 Completeness before imputation:
#   - Polish: 98.48%
#   - % Polish: 98.48%
#   - Belarusian: 57.58%
#   - % Belarusian: 98.48%
#   - Ruthenian: 94.32%
#   - % Ruthenian: 98.48%
#   - Local (Tutejszy): 3.41%
#   - % Local (Tutejszy): 21.21%
#   - German: 98.48%
#   - % German: 98.48%
#   - Jewish: 96.97%
#   - % Jewish: 98.48%
#   - Other and unknown: total: 98.48%
#   - % Other: total: 84.47%
#   - Minorities total (excluding Polish nationality): 98.48%
#   - % Minorities total: 98.48%
# 🔄 Applying harmonization...
# ✅ Finished processing in 0.08 seconds. Output: data/datasets/interwar_poland_database/processed_data/parquet/1921-ethnicity_ready_clean.parquet
# Set data_table_metadata_dict.adm_state_date to 1934-10-01.\data_table_metadata_dict: data_table_id='1921-ethnicity_ready_clean' adm_level='District' source='' link='' table='' page=None pdf_page=None description={'pol': 'Struktura narodowościowa wg. spisu powszechnego 1921 (stan na 30.09.1921).', 'eng': 'Ethnicity structure according to the 1921 national census (as of September 30, 1921).'} date='30.09.1921' orig_adm_state_date=datetime.datetime(1921, 7, 30, 0, 0) adm_state_date=datetime.datetime(1934, 10, 1, 0, 0) standardization_comments='Brakuje danych dla powiatu warszawskiego (jest tylko Warszawa). Podobnie może być w przypadku innych miast.' harmonization_method='proportional_to_territory' imputation_method=None columns={'Census 1921/Ethnicity/% Local (Tutejsza)': ColumnMetadata(unit='', category={'eng': 'Census 1921/Ethnicity/% Local (Tutejsza)', 'pol': 'Spis Powszechny 1921/Narodowość/% Tutejsza'}, data_type='%', completeness=0.21212121212121213, n_na=208, n_not_na=56, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Ethnicity/% Minorities total': ColumnMetadata(unit='', category={'eng': 'Census 1921/Ethnicity/% Minorities total', 'pol': 'Spis Powszechny 1921/Narodowość/% Mniejszości razem'}, data_type='%', completeness=0.9848484848484849, n_na=4, n_not_na=260, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Ethnicity/% Belarusian': ColumnMetadata(unit='', category={'eng': 'Census 1921/Ethnicity/% Belarusian', 'pol': 'Spis Powszechny 1921/Narodowość/% Białorusińska'}, data_type='%', completeness=0.9848484848484849, n_na=4, n_not_na=260, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Ethnicity/Belarusian': ColumnMetadata(unit='', category={'eng': 'Census 1921/Ethnicity/Belarusian', 'pol': 'Spis Powszechny 1921/Narodowość/Białorusińska'}, data_type='int', completeness=0.5757575757575758, n_na=112, n_not_na=152, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Ethnicity/Ruthenian': ColumnMetadata(unit='', category={'eng': 'Census 1921/Ethnicity/Ruthenian', 'pol': 'Spis Powszechny 1921/Narodowość/Rusińska'}, data_type='int', completeness=0.9431818181818182, n_na=15, n_not_na=249, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Ethnicity/Polish': ColumnMetadata(unit='', category={'eng': 'Census 1921/Ethnicity/Polish', 'pol': 'Spis Powszechny 1921/Narodowość/Polska'}, data_type='int', completeness=0.9848484848484849, n_na=4, n_not_na=260, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Ethnicity/% Ruthenian': ColumnMetadata(unit='', category={'eng': 'Census 1921/Ethnicity/% Ruthenian', 'pol': 'Spis Powszechny 1921/Narodowość/% Rusińska'}, data_type='%', completeness=0.9848484848484849, n_na=4, n_not_na=260, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Ethnicity/German': ColumnMetadata(unit='', category={'eng': 'Census 1921/Ethnicity/German', 'pol': 'Spis Powszechny 1921/Narodowość/Niemiecka'}, data_type='int', completeness=0.9848484848484849, n_na=4, n_not_na=260, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Ethnicity/% Other: total': ColumnMetadata(unit='', category={'eng': 'Census 1921/Ethnicity/% Other: total', 'pol': 'Spis Powszechny 1921/Narodowość/% Inna i niewiadoma: ogółem'}, data_type='%', completeness=0.8446969696969697, n_na=41, n_not_na=223, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Ethnicity/% Jewish': ColumnMetadata(unit='', category={'eng': 'Census 1921/Ethnicity/% Jewish', 'pol': 'Spis Powszechny 1921/Narodowość/% Żydowska'}, data_type='%', completene ...
# ✅ Successfully harmonized 'data/datasets/interwar_poland_database/adm_units_raw_data/data/1921-ethnicity_ready_clean.csv' and saved to 'data/datasets/interwar_poland_database/processed_data/parquet/1921-ethnicity_ready_clean.parquet' in 0.08 seconds
# Processing 'data/datasets/interwar_poland_database/adm_units_raw_data/data/1921-total_population_ready_clean.csv' with District-level raw data.
# 📊 Completeness before imputation:
#   - Total population: 98.48%
# 🔄 Applying harmonization...
# ✅ Finished processing in 0.03 seconds. Output: data/datasets/interwar_poland_database/processed_data/parquet/1921-total_population_ready_clean.parquet
# Set data_table_metadata_dict.adm_state_date to 1934-10-01.\data_table_metadata_dict: data_table_id='1921-total_population_ready_clean' adm_level='District' source='' link='' table='' page=None pdf_page=None description={'pol': 'Całkowita liczba ludności wg. spisu powszechnego 1921 (stan na 30.09.1921).', 'eng': 'Total population according to the 1921 national census (as of September 30, 1921).'} date='30.09.1921' orig_adm_state_date=datetime.datetime(1921, 7, 30, 0, 0) adm_state_date=datetime.datetime(1934, 10, 1, 0, 0) standardization_comments='Brakuje danych dla powiatu warszawskiego (jest tylko Warszawa). Podobnie może być w przypadku innych miast.' harmonization_method='proportional_to_territory' imputation_method=None columns={'Census 1921/Population/Total': ColumnMetadata(unit='', category={'eng': 'Census 1921/Population/Total', 'pol': 'Spis Powszechny 1921/Ludność/Ogółem'}, data_type='int', completeness=0.9848484848484849, n_na=4, n_not_na=260, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None)}.
# ✅ Successfully harmonized 'data/datasets/interwar_poland_database/adm_units_raw_data/data/1921-total_population_ready_clean.csv' and saved to 'data/datasets/interwar_poland_database/processed_data/parquet/1921-total_population_ready_clean.parquet' in 0.03 seconds
# Processing 'data/datasets/interwar_poland_database/adm_units_raw_data/data/1921-religion_ready_clean.csv' with District-level raw data.
# 📊 Completeness before imputation:
#   - Roman Catholic: 98.48%
#   - % Roman Catholic: 98.48%
#   - Greek Catholic: 93.94%
#   - % Greek Catholic: 98.48%
#   - Evangelical: 98.11%
#   - % Evangelical: 98.48%
#   - Orthodox: 97.73%
#   - % Orthodox: 98.48%
#   - Mosaic (Jewish): 98.48%
#   - % Mosaic (Jewish): 98.48%
#   - Other Christian denominations: 79.92%
#   - % Other Christian: 98.48%
#   - Other or unknown: 81.44%
#   - % Other: 98.48%
# 🔄 Applying harmonization...
# ✅ Finished processing in 0.08 seconds. Output: data/datasets/interwar_poland_database/processed_data/parquet/1921-religion_ready_clean.parquet
# Set data_table_metadata_dict.adm_state_date to 1934-10-01.\data_table_metadata_dict: data_table_id='1921-religion_ready_clean' adm_level='District' source='' link='' table='' page=None pdf_page=None description={'pol': 'Struktura wyznaniowa wg. spisu powszechnego 1921 (stan na 30.09.1921).', 'eng': 'Confessional population structure according to the 1921 national census (as of September 30, 1921).'} date='30.09.1921' orig_adm_state_date=datetime.datetime(1921, 7, 30, 0, 0) adm_state_date=datetime.datetime(1934, 10, 1, 0, 0) standardization_comments='Brakuje danych dla powiatu warszawskiego (jest tylko Warszawa). Podobnie może być w przypadku innych miast.' harmonization_method='proportional_to_territory' imputation_method=None columns={'Census 1921/Religion/% Orthodox': ColumnMetadata(unit='', category={'eng': 'Census 1921/Religion/% Orthodox', 'pol': 'Spis Powszechny 1921/Wyznanie/% Prawosławne'}, data_type='%', completeness=0.9848484848484849, n_na=4, n_not_na=260, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Religion/% Evangelical': ColumnMetadata(unit='', category={'eng': 'Census 1921/Religion/% Evangelical', 'pol': 'Spis Powszechny 1921/Wyznanie/% Ewangelickie'}, data_type='%', completeness=0.9848484848484849, n_na=4, n_not_na=260, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Religion/Other Christian Denominations': ColumnMetadata(unit='', category={'eng': 'Census 1921/Religion/Other Christian Denominations', 'pol': 'Spis Powszechny 1921/Wyznanie/Pozostałe wyznania chrześcijańskie'}, data_type='int', completeness=0.7992424242424242, n_na=53, n_not_na=211, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Religion/Other or Unknown': ColumnMetadata(unit='', category={'eng': 'Census 1921/Religion/Other or Unknown', 'pol': 'Spis Powszechny 1921/Wyznanie/Inne lub niewiadome'}, data_type='int', completeness=0.8143939393939394, n_na=49, n_not_na=215, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Religion/Roman Catholic': ColumnMetadata(unit='', category={'eng': 'Census 1921/Religion/Roman Catholic', 'pol': 'Spis Powszechny 1921/Wyznanie/Rzymskokatolickie'}, data_type='int', completeness=0.9848484848484849, n_na=4, n_not_na=260, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Religion/% Mosaic (Jewish)': ColumnMetadata(unit='', category={'eng': 'Census 1921/Religion/% Mosaic (Jewish)', 'pol': 'Spis Powszechny 1921/Wyznanie/% Mojżeszowe'}, data_type='%', completeness=0.9848484848484849, n_na=4, n_not_na=260, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Religion/Evangelical': ColumnMetadata(unit='', category={'eng': 'Census 1921/Religion/Evangelical', 'pol': 'Spis Powszechny 1921/Wyznanie/Ewangelickie'}, data_type='int', completeness=0.9810606060606061, n_na=5, n_not_na=259, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Religion/% Greek Catholic': ColumnMetadata(unit='', category={'eng': 'Census 1921/Religion/% Greek Catholic', 'pol': 'Spis Powszechny 1921/Wyznanie/% Grecko-katolickie'}, data_type='%', completeness=0.9848484848484849, n_na=4, n_not_na=260, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Religion/Orthodox': ColumnMetadata(unit='', category={'eng': 'Census 1921/Religion/Orthodox', 'pol': 'Spis Powszechny 1921/Wyznanie/Prawosławne'}, data_type='int', completeness=0.9772727272727273, n_na=6, n_not_na=258, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Census 1921/Religion/Greek Catholic': ColumnMetadata(unit='', category={'eng': 'Census 1921/Religion/Greek Catholic', 'pol ...
# ✅ Successfully harmonized 'data/datasets/interwar_poland_database/adm_units_raw_data/data/1921-religion_ready_clean.csv' and saved to 'data/datasets/interwar_poland_database/processed_data/parquet/1921-religion_ready_clean.parquet' in 0.08 seconds
# Processing 'data/datasets/interwar_poland_database/adm_units_raw_data/data/1921-number_of_buildings_ready.csv' with District-level raw data.
# 📊 Completeness before imputation:
#   - Liczba nieruchomości: 100.00%
# 🔄 Applying harmonization...
# ✅ Finished processing in 0.03 seconds. Output: data/datasets/interwar_poland_database/processed_data/parquet/1921-number_of_buildings_ready.parquet
# Set data_table_metadata_dict.adm_state_date to 1934-10-01.\data_table_metadata_dict: data_table_id='1921-number_of_buildings_ready' adm_level='District' source='' link='' table='' page=None pdf_page=None description={'pol': 'Budynki/Całkowita liczba nieruchomości wg. spisu powszechnego 1921 (stan na 30.09.1921). Aktywni zawodowo wraz z członkami rodzin, bezrobotni itd.', 'eng': 'Buildings/Number of buildings according to the 1921 national census (as of September 30, 1921). Economically active together with family members, unemployed etc.'} date='30.09.1921' orig_adm_state_date=datetime.datetime(1921, 7, 30, 0, 0) adm_state_date=datetime.datetime(1934, 10, 1, 0, 0) standardization_comments='' harmonization_method='proportional_to_territory' imputation_method=None columns={'Buildings/Census 1921/Buildings/Total Number': ColumnMetadata(unit='', category={'eng': 'Buildings/Census 1921/Buildings/Total Number', 'pol': 'Budynki/Spis Powszechny 1921/Budynki/Całkowita liczba nieruchomości'}, data_type='int', completeness=1.0, n_na=0, n_not_na=264, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None)}.
# ✅ Successfully harmonized 'data/datasets/interwar_poland_database/adm_units_raw_data/data/1921-number_of_buildings_ready.csv' and saved to 'data/datasets/interwar_poland_database/processed_data/parquet/1921-number_of_buildings_ready.parquet' in 0.03 seconds
# Processing 'data/datasets/interwar_poland_database/adm_units_raw_data/data/1921-building_counts_ready.csv' with District-level raw data.
# E:\git_projects\border_harmonization_toolkit\src\administrative_history\utils\helper_functions.py:308: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# E:\git_projects\border_harmonization_toolkit\src\administrative_history\utils\helper_functions.py:308: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# E:\git_projects\border_harmonization_toolkit\src\administrative_history\utils\helper_functions.py:308: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# ⚠️ Districts in input but not in conversion matrix: {nan}
# 📊 Completeness before imputation:
#   - Liczba budynków z przeznaczenia mieszkalnych na 1 km2: 100.00%
#   - Liczba budynków z przeznaczenia mieszkalnych i innych zamieszkanych na 1 nieruchomość/Ogółem: 100.00%
#   - Liczba budynków z przeznaczenia mieszkalnych i innych zamieszkanych na 1 nieruchomość/Wieś: 100.00%
#   - Liczba budynków z przeznaczenia mieszkalnych i innych zamieszkanych na 1 nieruchomość/Miasta poniżej 20 000 mieszkańców: 100.00%
#   - Liczba budynków z przeznaczenia mieszkalnych i innych zamieszkanych na 1 nieruchomość/Miasta powyżej 20 000 mieszkańców: 100.00%
#   - Liczba ludności na 1 budynek/Ogółem: 100.00%
#   - Liczba ludności na 1 budynek/Wieś: 100.00%
#   - Liczba ludności na 1 budynek/Miasta poniżej 20 000 mieszkańców: 100.00%
#   - Liczba ludności na 1 budynek/Miasta powyżej 20 000 mieszkańców: 100.00%
#   - Liczba ludności na 1 nieruchomość zamieszkaną/Miasta poniżej 20 000 mieszkanców: 100.00%
#   - Liczba ludności na 1 nieruchomość zamieszkaną/Miasta powyżej 20 000 mieszkańców: 100.00%
#   - Na 100 budynków zamieszkanych było/Z przeznaczenia mieszkalnych/Ogółem: 100.00%
#   - Na 100 budynków zamieszkanych było/Służących głównie dla innych celów/Ogółem: 100.00%
#   - Na 100 budynków zamieszkanych było/Gospodarczych, tymczasowych i ruchomych/Ogółem: 100.00%
#   - Na 100 budynków zamieszkanych było/Z przeznaczenia mieszkalnych/Wieś: 100.00%
#   - Na 100 budynków zamieszkanych było/Służących głównie dla innych celów/Wieś: 100.00%
#   - Na 100 budynków zamieszkanych było/Gospodarczych, tymczasowych i ruchomych/Wieś: 100.00%
#   - Na 100 budynków zamieszkanych było/Z przeznaczenia mieszkalnych/Miasta poniżej 20 000 mieszkańców: 100.00%
#   - Na 100 budynków zamieszkanych było/Służących głównie dla innych celów/Miasta poniżej 20 000 mieszkańców: 100.00%
#   - Na 100 budynków zamieszkanych było/Gospodarczych, tymczasowych i ruchomych/Miasta poniżej 20 000 mieszkańców: 100.00%
#   - Na 100 budynków zamieszkanych było/Z przeznaczenia mieszkalnych/Miasta powyżej 20 000 mieszkańców: 100.00%
#   - Na 100 budynków zamieszkanych było/Służących głównie dla innych celów/Miasta powyżej 20 000 mieszkańców: 100.00%
#   - Na 100 budynków zamieszkanych było/Gospodarczych, tymczasowych i ruchomych/Miasta powyżej 20 000 mieszkańców: 100.00%
#   - Na 100 budynków z przeznaczenia mieszkalnych było niezamieszkanych/Ogółem: 100.00%
#   - Na 100 budynków z przeznaczenia mieszkalnych było niezamieszkanych/Wieś: 100.00%
#   - Na 100 budynków z przeznaczenia mieszkalnych było niezamieszkanych/Miasta poniżej 20 000 mieszkańców: 100.00%
#   - Na 100 budynków z przeznaczenia mieszkalnych było niezamieszkanych/Miasta powyżej 20 000 mieszkańców: 100.00%
#   - Na 100 mieszkań było niezamieszkanych/Ogółem: 100.00%
#   - Na 100 mieszkań było niezamieszkanych/Wieś: 100.00%
#   - Na 100 mieszkań było niezamieszkanych/Miasta poniżej 20 000 mieszkańców: 100.00%
#   - Na 100 mieszkań było niezamieszkanych/Miasta powyżej 20 000 mieszkańców: 100.00%
# 🔄 Applying harmonization...
# ✅ Finished processing in 0.12 seconds. Output: data/datasets/interwar_poland_database/processed_data/parquet/1921-building_counts_ready.parquet
# Set data_table_metadata_dict.adm_state_date to 1934-10-01.\data_table_metadata_dict: data_table_id='1921-building_counts_ready' adm_level='District' source='' link='' table='' page=None pdf_page=None description={'pol': 'Budynki/Gęstość zabudowania i zaludnienia. Liczba budynków na nieruchomość. Budynki zamieszkane według przeznaczenia. Budynki i mieszkania niezamieszkane.', 'eng': 'Buildings/Density of buildings and population. Number of buildings per property. Inhabited buildings by intended use. Uninhabited buildings and dwellings.'} date='30.09.1921' orig_adm_state_date=datetime.datetime(1921, 7, 30, 0, 0) adm_state_date=datetime.datetime(1934, 10, 1, 0, 0) standardization_comments='' harmonization_method='proportional_to_territory' imputation_method=None columns={'Buildings/Number of residential buildings per 1 km2': ColumnMetadata(unit='', category={'eng': 'Buildings/Number of residential buildings per 1 km2', 'pol': 'Budynki/Liczba budynków z przeznaczenia mieszkalnych na 1 km2'}, data_type='', completeness=1.0, n_na=0, n_not_na=264, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Buildings/Number of residential and other inhabited buildings per 1 property/Total': ColumnMetadata(unit='', category={'eng': 'Buildings/Number of residential and other inhabited buildings per 1 property/Total', 'pol': 'Budynki/Liczba budynków z przeznaczenia mieszkalnych i innych zamieszkanych na 1 nieruchomość/Ogółem'}, data_type='', completeness=1.0, n_na=0, n_not_na=264, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Buildings/Number of residential and other inhabited buildings per 1 property/Rural Areas': ColumnMetadata(unit='', category={'eng': 'Buildings/Number of residential and other inhabited buildings per 1 property/Rural Areas', 'pol': 'Budynki/Liczba budynków z przeznaczenia mieszkalnych i innych zamieszkanych na 1 nieruchomość/Wieś'}, data_type='', completeness=1.0, n_na=0, n_not_na=264, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Buildings/Number of residential and other inhabited buildings per 1 property/Towns under 20,000 inhabitants': ColumnMetadata(unit='', category={'eng': 'Buildings/Number of residential and other inhabited buildings per 1 property/Towns under 20,000 inhabitants', 'pol': 'Budynki/Liczba budynków z przeznaczenia mieszkalnych i innych zamieszkanych na 1 nieruchomość/Miasta poniżej 20 000 mieszkańców'}, data_type='', completeness=1.0, n_na=0, n_not_na=264, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Buildings/Number of residential and other inhabited buildings per 1 property/Towns over 20,000 inhabitants': ColumnMetadata(unit='', category={'eng': 'Buildings/Number of residential and other inhabited buildings per 1 property/Towns over 20,000 inhabitants', 'pol': 'Budynki/Liczba budynków z przeznaczenia mieszkalnych i innych zamieszkanych na 1 nieruchomość/Miasta powyżej 20 000 mieszkańców'}, data_type='', completeness=1.0, n_na=0, n_not_na=264, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Buildings/Population per 1 building/Total': ColumnMetadata(unit='', category={'eng': 'Buildings/Population per 1 building/Total', 'pol': 'Budynki/Liczba ludności na 1 budynek/Ogółem'}, data_type='', completeness=1.0, n_na=0, n_not_na=264, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Buildings/Population per 1 building/Rural Areas': ColumnMetadata(unit='', category={'eng': 'Buildings/Population per 1 building/Rural Areas', 'pol': 'Budynki/Liczba ludności na 1 budynek/Wieś'}, data_type='', completeness=1.0, n_na=0, n_not_na=264, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None), 'Buildings/Population per 1 building/Towns under 20,000 inhabitants': ColumnMetadata(unit='', ca ...
# ✅ Successfully harmonized 'data/datasets/interwar_poland_database/adm_units_raw_data/data/1921-building_counts_ready.csv' and saved to 'data/datasets/interwar_poland_database/processed_data/parquet/1921-building_counts_ready.parquet' in 0.12 seconds
# Processing 'data/datasets/interwar_poland_database/adm_units_raw_data/data/1921-building_construction_material_ready.csv' with District-level raw data.
# 📊 Completeness before imputation:
#   - Na 100 budynków było/Murowanych/Ogółem: 100.00%
#   - Na 100 budynków było/Drewnianych/Ogółem: 100.00%
#   - Na 100 budynków było/Z gliny innych materjałów/Ogółem: 100.00%
#   - Na 100 budynków było/Z niewiadomego materiału/Ogółem: 100.00%
#   - Na 100 budynków było/Murowanych/Wieś: 100.00%
#   - Na 100 budynków było/Drewnianych/Wieś: 100.00%
#   - Na 100 budynków było/Z gliny innych materjałów/Wieś: 100.00%
#   - Na 100 budynków było/Z niewiadomego materiału/Wieś: 100.00%
#   - Na 100 budynków było/Murowanych/Miasta poniżej 20 000 mieszk.: 100.00%
#   - Na 100 budynków było/Drewnianych/Miasta poniżej 20 000 mieszk.: 100.00%
#   - Na 100 budynków było/Z gliny innych materjałów/Miasta poniżej 20 000 mieszk.: 100.00%
#   - Na 100 budynków było/Z niewiadomego materiału/Miasta poniżej 20 000 mieszk.: 100.00%
#   - Na 100 budynków było/Murowanych/Miasta powyżej 20 000 mieszkańców: 100.00%
#   - Na 100 budynków było/Drewnianych/Miasta powyżej 20 000 mieszkańców: 100.00%
#   - Na 100 budynków było/Z gliny innych materjałów/Miasta powyżej 20 000 mieszkańców: 100.00%
#   - Na 100 budynków było/Z niewiadomego materiału/Miasta powyżej 20 000 mieszkańców: 100.00%
#   - Na 100 budynków miało pokrycie/Ogniotrwałe/Ogółem: 100.00%
#   - Na 100 budynków miało pokrycie/Z drzewa/Ogółem: 100.00%
#   - Na 100 budynków miało pokrycie/Ze słomy/Ogółem: 100.00%
#   - Na 100 budynków miało pokrycie/Niewiadome/Ogółem: 100.00%
#   - Na 100 budynków miało pokrycie/Ogniotrwałe/Wieś: 100.00%
#   - Na 100 budynków miało pokrycie/Z drzewa/Wieś: 100.00%
#   - Na 100 budynków miało pokrycie/Ze słomy/Wieś: 100.00%
#   - Na 100 budynków miało pokrycie/Niewiadome/Wieś: 100.00%
#   - Na 100 budynków miało pokrycie/Ogniotrwałe/Miasta poniżej 20 000 mieszkańców: 100.00%
#   - Na 100 budynków miało pokrycie/Z drzewa/Miasta poniżej 20 000 mieszkańców: 100.00%
#   - Na 100 budynków miało pokrycie/Ze słomy/Miasta poniżej 20 000 mieszkańców: 100.00%
#   - Na 100 budynków miało pokrycie/Niewiadome/Miasta poniżej 20 000 mieszkańców: 100.00%
#   - Na 100 budynków miało pokrycie/Ogniotrwałe/Miasta powyżej 20 000 mieszkańców: 100.00%
#   - Na 100 budynków miało pokrycie/Z drzewa/Miasta powyżej 20 000 mieszkańców: 100.00%
#   - Na 100 budynków miało pokrycie/Ze słomy/Miasta powyżej 20 000 mieszkańców: 100.00%
#   - Na 100 budynków miało pokrycie/Niewiadome/Miasta powyżej 20 000 mieszkańców: 100.00%
# 🔄 Applying harmonization...
# ✅ Finished processing in 0.13 seconds. Output: data/datasets/interwar_poland_database/processed_data/parquet/1921-building_construction_material_ready.parquet
# ...
# ✅ Successfully harmonized 'data/datasets/interwar_poland_database/cities_raw_data/data/1931-population-more-than-10000.csv' and saved to 'data/datasets/interwar_poland_database/processed_data/parquet/1931-population-more-than-10000.parquet' in 0.02 seconds
# Processing 'data/datasets/interwar_poland_database/cities_raw_data/data/city-1939-population.csv' with City-level raw data.
# E:\git_projects\border_harmonization_toolkit\src\administrative_history\utils\helper_functions.py:308: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# E:\git_projects\border_harmonization_toolkit\src\administrative_history\utils\helper_functions.py:308: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# E:\git_projects\border_harmonization_toolkit\src\administrative_history\utils\helper_functions.py:308: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# E:\git_projects\border_harmonization_toolkit\src\administrative_history\utils\helper_functions.py:308: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# E:\git_projects\border_harmonization_toolkit\src\administrative_history\utils\helper_functions.py:308: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# E:\git_projects\border_harmonization_toolkit\src\administrative_history\utils\helper_functions.py:308: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# Index name: City
# ⚠️ Dropped 1 cities due to name mismatch: ['Staszów']
# 📊 Completeness before imputation:
#   - Population: 100.00%
# ✅ Finished processing in 0.03 seconds. Output: data/datasets/interwar_poland_database/processed_data/parquet/city-1939-population.parquet
# Set data_table_metadata_dict.adm_state_date to 1934-10-01.\data_table_metadata_dict: data_table_id='city-1939-population' adm_level='City' source='Rocznik Polityczny i Gospodarczy 1939. Polska Agencja Telegraficzna. Warszawa 1939.' link='https://bcul.lib.uni.lodz.pl/dlibra/publication/2855/edition/1931?language=pl' table=None page=328 pdf_page=310 description={'pol': 'Populacja miast w 1939 r.', 'eng': 'Population of cities in 1939.'} date='1.01.1939' orig_adm_state_date=datetime.datetime(1939, 4, 1, 0, 0) adm_state_date=datetime.datetime(1934, 10, 1, 0, 0) standardization_comments='Niektóre dane zostały uzupełnione lub zmienione według danych z publikacji Adama Jelonka "Ludność Miast i Osiedli Typu Miejskiego na Ziemiach Polski od 1810 do 1960 roku." (https://rcin.org.pl/dlibra/show-content/publication/edition/29117). W szczególności miasta Błaszki, Bydgoszcz, Chodecz, Częstochowa, Dukla, Działoszyce, Gdynia, Gostyń, Kleszczele, Kłobuck, Kock, Kraków, Krynica Zdrój, Krynki, Lublin, Lubliniec, Łęczna, Łowicz, Łódź, Maków Mazowiecki, Ostrów Lubelski, Ostrów Mazowiecka, Piwniczna (Piwnicznia-Zdrój), Pniewy, Pobiedziska, Poznań, Praszka, Radom, Rozwadów, Sieraków, Solec Kujawski, Sosnowiec, Strzyżów, Suchowola, Śrem, Wadowice, Warszawa, Wilamowice, Włodawa, Włoszczowa, Wyśmierzyce, Żelechów, Żory. Dla miast Brody, Kamień Koszyrski, Myślenice, Olesko, Radoszkowice (Radoszkowicze), Zbąszyń dane z roku 1939 zostały wyekstrapolowane po prostu jako kontynuacja trendów populacyjnych dla miast z 1921 i 1931 roku.' harmonization_method=None imputation_method=None columns={'Yearbook 1939/City Population/Total': ColumnMetadata(unit='', category={'eng': 'Yearbook 1939/City Population/Total', 'pol': 'Rocznik 1939/Ludność Miast/Ogółem'}, data_type='int', completeness=1.0, n_na=0, n_not_na=612, completeness_after_imputation=None, n_na_after_imputation=None, n_not_na_after_imputation=None)}.
# ✅ Successfully harmonized 'data/datasets/interwar_poland_database/cities_raw_data/data/city-1939-population.csv' and saved to 'data/datasets/interwar_poland_database/processed_data/parquet/city-1939-population.parquet' in 0.03 seconds
# ✅ Finished harmonization in 106.67 seconds.
# 🎉 All data tables harmonized successfully.
# Beginning post-processing. Total number of methods to apply: 11
# Calling combine_data_tables method...
# 🟡 Starting combine_data_tables with 'sum' method: ['9.12.1931-occupation_central_eastern_voivodships_ready_clean', '9.12.1931-occupation_southern_western_voivodships_ready_clean'] -> 1931_occupation_ready_clean.parquet
# ✅ Finished combine_data_tables: Output written to data/datasets/interwar_poland_database/processed_data/parquet/1931_occupation_ready_clean.parquet
# 🧹 Deleted 2 source file(s).
# Calling combine_data_tables method...
# 🟡 Starting combine_data_tables with 'sum' method: ['1931-total_population_central_eastern_voivodships', '1931-total_population_southern_western_voivodships'] -> 1931-total_population.parquet
# ✅ Finished combine_data_tables: Output written to data/datasets/interwar_poland_database/processed_data/parquet/1931-total_population.parquet
# 🧹 Deleted 2 source file(s).
# Calling combine_data_tables method...
# 🟡 Starting combine_data_tables with 'sum' method: ['1931-ethnicity_central_eastern_voivodships', '1931-ethnicity_southern_western_voivodships'] -> 1931-ethnicity.parquet
# ✅ Finished combine_data_tables: Output written to data/datasets/interwar_poland_database/processed_data/parquet/1931-ethnicity.parquet
# 🧹 Deleted 2 source file(s).
# Calling combine_data_tables method...
# 🟡 Starting combine_data_tables with 'sum' method: ['1931-indirect_occupation_central_eastern_voivodships', '1931-indirect_occupation_southern_western_voivodships'] -> 1931-indirect_occupation.parquet
# ✅ Finished combine_data_tables: Output written to data/datasets/interwar_poland_database/processed_data/parquet/1931-indirect_occupation.parquet
# 🧹 Deleted 2 source file(s).
# Calling combine_data_tables method...
# 🟡 Starting combine_data_tables with 'sum' method: ['1931-religion_central_eastern_voivodships', '1931-religion_southern_western_voivodships'] -> 1931-religion.parquet
# ✅ Finished combine_data_tables: Output written to data/datasets/interwar_poland_database/processed_data/parquet/1931-religion.parquet
# 🧹 Deleted 2 source file(s).
# Calling combine_data_tables method...
# 🟡 Starting combine_data_tables with 'sum' method: ['destroyed_buildings_silesia_vilnius_ready', 'destroyed_buildings_no_silesia_vilnius_ready'] -> destroyed_buildings.parquet
# ✅ Finished combine_data_tables: Output written to data/datasets/interwar_poland_database/processed_data/parquet/destroyed_buildings.parquet
# 🧹 Deleted 2 source file(s).
# Calling combine_data_tables method...
# 🟡 Starting combine_data_tables with 'sum' method: ['1931-land_area_shares_pz_ready', '1931-land_area_shares_cw_ready'] -> 1931-land_area_shares.parquet
# ✅ Finished combine_data_tables: Output written to data/datasets/interwar_poland_database/processed_data/parquet/1931-land_area_shares.parquet
# 🧹 Deleted 2 source file(s).
# Calling combine_data_tables method...
# 🟡 Starting combine_data_tables with 'sum' method: ['1921-total_population_from_1931_census_publications_1933_borders', '1921-total_population_from_1931_census_publications_1934_borders'] -> 1921-total_population_from_1931_census_publications.parquet
# ✅ Finished combine_data_tables: Output written to data/datasets/interwar_poland_database/processed_data/parquet/1921-total_population_from_1931_census_publications.parquet
# 🧹 Deleted 2 source file(s).
# Calling combine_data_tables method...
# 🟡 Starting combine_data_tables with 'concatenate' method: ['1921-population-more-than-10000', '1921-population-less-than-10000', '1921-population-minor-cities'] -> city-1921-population.parquet
# ✅ Finished combine_data_tables: Output written to data/datasets/interwar_poland_database/processed_data/parquet/city-1921-population.parquet
# 🧹 Deleted 3 source file(s).
# Calling combine_data_tables method...
# 🟡 Starting combine_data_tables with 'concatenate' method: ['1931-population-more-than-10000', '1931-population-less-than-10000'] -> city-1931-population.parquet
# ✅ Finished combine_data_tables: Output written to data/datasets/interwar_poland_database/processed_data/parquet/city-1931-population.parquet
# 🧹 Deleted 2 source file(s).
# Calling create_dist_area_dataset method...
# 🟡 Starting create_dist_area_dataset (adm. state for 1934-10-01)
# ✅ Finished create_dist_area_dataset: Metadata and output added to the database.
# 🎉 All post-processing methods applied successfully.
# 📦 Combining 78 District Parquet file(s) in 'strict' mode…
#   ✓ Canonical District count: 264 from '07.1935_prices_ready.parquet'
#   ✓ Included '07.1935_prices_ready.parquet' → 3168 rows
#   ✓ Included '08.1926_prices_ready.parquet' → 3696 rows
#   ✓ Included '08.1928_prices_ready.parquet' → 3432 rows
#   ✓ Included '08.1930_prices_ready.parquet' → 3168 rows
#   ✓ Included '08.1931_prices_ready.parquet' → 3168 rows
#   ✓ Included '08.1932_prices_ready.parquet' → 3168 rows
#   ✓ Included '08.1934_prices_ready.parquet' → 3168 rows
#   ✓ Included '08.1935_prices_ready.parquet' → 3168 rows
#   ✓ Included '08.1936_prices_ready.parquet' → 3168 rows
#   ✓ Included '09.1935_prices_ready.parquet' → 3168 rows
#   ✓ Included '1921-building_construction_material_ready.parquet' → 8448 rows
#   ✓ Included '1921-building_counts_ready.parquet' → 8184 rows
#   ✓ Included '1921-education_ready.parquet' → 21384 rows
#   ✓ Included '1921-ethnicity_ready_clean.parquet' → 4224 rows
#   ✓ Included '1921-land_ownership_structure_ready.parquet' → 50160 rows
#   ✓ Included '1921-number_of_buildings_ready.parquet' → 264 rows
#   ✓ Included '1921-occupation_ready_clean.parquet' → 2640 rows
#   ✓ Included '1921-religion_ready_clean.parquet' → 3696 rows
#   ✓ Included '1921-total_population_from_1931_census_publications.parquet' → 264 rows
#   ✓ Included '1921-total_population_ready_clean.parquet' → 264 rows
#   ✓ Included '1923-1924-crops_area_ha_ready.parquet' → 1320 rows
#   ✓ Included '1923-1924-crops_q_ready.parquet' → 1320 rows
#   ✓ Included '1923-1924-sugarbeet_ready.parquet' → 792 rows
#   ✓ Included '1924-industrial_occupations_permissions_ready_clean.parquet' → 4224 rows
#   ✓ Included '1924-industry_permissions_ready_clean.parquet' → 4224 rows
#   ✓ Included '1924-trade_permissions_ready_clean.parquet' → 3168 rows
#   ✓ Included '1925-1926-crops_area_ready.parquet' → 1320 rows
#   ✓ Included '1925-1926-crops_q_ready.parquet' → 1320 rows
#   ✓ Included '1925-1926-sugarbeet_ready.parquet' → 264 rows
#   ✓ Included '1925-industrial_occupations_permissions_ready_clean.parquet' → 4224 rows
#   ✓ Included '1925-industry_permissions_ready_clean.parquet' → 4224 rows
#   ✓ Included '1925-trade_permissions_ready_clean.parquet' → 3168 rows
#   ✓ Included '1927-1928-crops_area_ha_ready.parquet' → 6072 rows
#   ✓ Included '1927-1928-crops_q_ready.parquet' → 1584 rows
#   ✓ Included '1928-industrial_occupations_permissions_ready_clean.parquet' → 4224 rows
#   ✓ Included '1928-industry_permissions_ready_clean.parquet' → 4752 rows
#   ✓ Included '1928-trade_permissions_ready_clean.parquet' → 3168 rows
#   ✓ Included '1930-crops_q_ready.parquet' → 1584 rows
#   ✓ Included '1930-forests_area_ha_ready.parquet' → 264 rows
#   ✓ Included '1931-crops_q_ready.parquet' → 1584 rows
#   ✓ Included '1931-ethnicity.parquet' → 5280 rows
#   ✓ Included '1931-indirect_occupation.parquet' → 3168 rows
#   ✓ Included '1931-land_area_shares.parquet' → 4224 rows
#   ✓ Included '1931-religion.parquet' → 3696 rows
#   ✓ Included '1931-total_population.parquet' → 264 rows
#   ✓ Included '1931_occupation_ready_clean.parquet' → 72072 rows
#   ✓ Included '1932-crops_area_ha_ready.parquet' → 4752 rows
#   ✓ Included '1932-crops_q_ready.parquet' → 5280 rows
#   ✓ Included '1932_trade_permissions_cat_1_ready_clean.parquet' → 11352 rows
#   ✓ Included '1932_trade_permissions_cat_2_ready_clean.parquet' → 11352 rows
#   ✓ Included '1932_trade_permissions_cat_3_ready_clean.parquet' → 11352 rows
#   ✓ Included '1932_trade_permissions_cat_4_ready_clean.parquet' → 11352 rows
#   ✓ Included '1932_trade_permissions_cat_5a_ready_clean.parquet' → 11352 rows
#   ✓ Included '1932_trade_permissions_cat_5b_ready_clean.parquet' → 11352 rows
#   ✓ Included '1932_trade_permissions_total_ready_clean.parquet' → 11352 rows
#   ✓ Included '1934-crops_area_ha_ready.parquet' → 2112 rows
#   ✓ Included '1934-crops_q_ready.parquet' → 1848 rows
#   ✓ Included '1935-crops_q_ready.parquet' → 1584 rows
#   ✓ Included '1935-industry_permissions_ready_clean.parquet' → 19800 rows
#   ✓ Included '1935-trade_permissions_no_fixed_location_ready_clean.parquet' → 21384 rows
#   ✓ Included '1935-trade_permissions_total_ready_clean.parquet' → 21384 rows
#   ✓ Included '1936-crops_area_ha_ready.parquet' → 1848 rows
#   ✓ Included '1936-crops_q_ready.parquet' → 1584 rows
#   ✓ Included '1938-crops_area_ha_ready.parquet' → 2376 rows
#   ✓ Included '1938-crops_q_ready.parquet' → 2376 rows
#   ✓ Included '30.06.1929-livestock_ready.parquet' → 1056 rows
#   ✓ Included '30.06.1930-livestock_ready.parquet' → 1320 rows
#   ✓ Included '30.06.1931-livestock_ready.parquet' → 1320 rows
#   ✓ Included '30.06.1932-livestock_ready.parquet' → 1320 rows
#   ✓ Included '30.06.1933-livestock_ready.parquet' → 1320 rows
#   ✓ Included '30.06.1934-livestock_ready.parquet' → 1320 rows
#   ✓ Included '30.06.1935-livestock_ready.parquet' → 1320 rows
#   ✓ Included '30.06.1936-livestock_ready.parquet' → 1320 rows
#   ✓ Included '30.06.1938-livestock_ready.parquet' → 1320 rows
#   ✓ Included '30.11.1927-livestock_ready.parquet' → 1320 rows
#   ✓ Included 'destroyed_buildings.parquet' → 528 rows
#   ✓ Included 'dist_area_baseline_adm_state.parquet' → 264 rows
#   ✓ Included 'large_land_estates_private.parquet' → 25344 rows
# ✅ Wrote combined District long dataset: data/datasets/interwar_poland_database/processed_data/District_datasets.parquet (478368 rows from 78 files; mode=strict).
# 🧹 Deleted 78 source file(s) for District.
# 📦 Combining 2 Region Parquet file(s) in 'strict' mode…
#   ✓ Canonical Region count: 17 from 'regions_1935_share_workers_by_enterprise_type_size.parquet'
#   ✓ Included 'regions_1935_share_workers_by_enterprise_type_size.parquet' → 765 rows
#   ✓ Included 'regions_1935_total_num_workers.parquet' → 272 rows
# ✅ Wrote combined Region long dataset: data/datasets/interwar_poland_database/processed_data/Region_datasets.parquet (1037 rows from 2 files; mode=strict).
# 🧹 Deleted 2 source file(s) for Region.
# 📦 Combining 3 City Parquet file(s) in 'union' mode…
#   ✓ Included 'city-1921-population.parquet' → 645 rows
#   ✓ Included 'city-1931-population.parquet' → 645 rows
#   ✓ Included 'city-1939-population.parquet' → 612 rows
# ✅ Wrote combined City long dataset: data/datasets/interwar_poland_database/processed_data/City_datasets.parquet (1902 rows from 3 files; mode=union).
# 🧹 Deleted 3 source file(s) for City.

# %%
# English category tree
adm_history_processor.build_database_tree(filename="database_tree", format="csv")
adm_history_processor.build_database_tree(filename="database_tree", format="markdown")
adm_history_processor.build_database_tree(filename="database_tree", format="ascii")

# Polish category tree
adm_history_processor.build_database_tree(filename="database_tree_pl", format="csv", lang="pol")
adm_history_processor.build_database_tree(filename="database_tree_pl", format="markdown", lang="pol")
adm_history_processor.build_database_tree(filename="database_tree_pl", format="ascii", lang="pol")

# %% [markdown]
# # Initial definitions

# %% [markdown]
# ### Define constants

# %%
# Define paths to csvs with regional data
region_agro_production_costs_path = "data/datasets/interwar_poland_database/adm_units_raw_data/data/regions_production_cost_per_ha_ready.csv"
region_total_crops_production_path = "data/datasets/interwar_poland_database/adm_units_raw_data/data/regions_total_crops_production_value_ready.csv"
region_total_sown_area_path = "data/datasets/interwar_poland_database/adm_units_raw_data/data/regions_total_sown_area_ha_ready.csv"
regions_remaining_crops_production_path = "data/datasets/interwar_poland_database/adm_units_raw_data/data/regions_remaining_crops_production.csv"
hourly_wage_by_industry_path = "data/datasets/interwar_poland_database/adm_units_raw_data/data/hourly_wage_by_industry_sector.csv"
hours_per_employee_path = "data/datasets/interwar_poland_database/adm_units_raw_data/data/hours_per_employee.csv"
regional_industry_va_path = "data/datasets/interwar_poland_database/adm_units_raw_data/data/regions_industry_value_added.csv"
regional_private_services_va_path = "data/datasets/interwar_poland_database/adm_units_raw_data/data/regions_private_services_va.csv"
regional_public_services_va_path = "data/datasets/interwar_poland_database/adm_units_raw_data/data/regions_public_services_va.csv"
regional_public_services_employment_path = "data/datasets/interwar_poland_database/adm_units_raw_data/data/regions_public_services_employment.csv"
regional_population_path = "data/datasets/interwar_poland_database/adm_units_raw_data/data/regions_population.csv"

# Private services
regional_private_paths = {}
regional_private_paths['domestic_service'] = "data/datasets/interwar_poland_database/adm_units_raw_data/data/regions_private_domestic_service.csv"
regional_private_paths['education'] = "data/datasets/interwar_poland_database/adm_units_raw_data/data/regions_private_education.csv"
regional_private_paths['finance'] = "data/datasets/interwar_poland_database/adm_units_raw_data/data/regions_private_finance.csv"
regional_private_paths['health'] = "data/datasets/interwar_poland_database/adm_units_raw_data/data/regions_private_health.csv"
regional_private_paths['hygiene'] = "data/datasets/interwar_poland_database/adm_units_raw_data/data/regions_private_hygiene.csv"
regional_private_paths['immobility'] = "data/datasets/interwar_poland_database/adm_units_raw_data/data/regions_private_immobility.csv"
regional_private_paths['justice'] = "data/datasets/interwar_poland_database/adm_units_raw_data/data/regions_private_justice.csv"
regional_private_paths['lit_sci_culture'] = "data/datasets/interwar_poland_database/adm_units_raw_data/data/regions_private_lit_sci_culture.csv"
regional_private_paths['religion'] = "data/datasets/interwar_poland_database/adm_units_raw_data/data/regions_private_religion.csv"
regional_private_paths['trans_com'] = "data/datasets/interwar_poland_database/adm_units_raw_data/data/regions_private_trans_com.csv"
regional_private_paths['trade'] = "data/datasets/interwar_poland_database/adm_units_raw_data/data/regions_trade.csv"

# %%
# Define frequent references used in the whole notebook
reference_date = adm_history_processor.harmonize_to_date
reference_adm_state = administrative_history.find_adm_state_by_date(reference_date)
all_districts_raw = reference_adm_state.all_district_names(homeland_only=True)
all_regions_raw = reference_adm_state.all_region_names(homeland_only=True)

# %%
# Define a dict mapping voivodships to voivodship group.
r_to_r_group = {
    'BIAŁOSTOCKIE': 'CENTRAL',
    'KIELECKIE': 'CENTRAL',
    'KRAKOWSKIE': 'SOUTHERN',
    'LUBELSKIE': 'CENTRAL',
    'LWOWSKIE': 'SOUTHERN',
    'ŁÓDZKIE': 'CENTRAL',
    'M. ST. WARSZAWA': 'CENTRAL',
    'NOWOGRÓDZKIE': 'EASTERN',
    'POLESKIE': 'EASTERN',
    'POMORSKIE': 'WESTERN',
    'POZNAŃSKIE': 'WESTERN',
    'STANISŁAWOWSKIE': 'SOUTHERN',
    'ŚLĄSKIE': 'WESTERN',
    'TARNOPOLSKIE': 'SOUTHERN',
    'WARSZAWSKIE': 'CENTRAL',
    'WOŁYŃSKIE': 'EASTERN',
    'ZIEMIA WILEŃSKA': 'EASTERN'
    }
# Define colors for r_groups for plotting.
r_group_to_color = {
    'CENTRAL': '#0000a2',
    'SOUTHERN': '#e9c716',
    'EASTERN': '#bc272d',
    'WESTERN': '#50ad9f'
}

r_to_example_r = {
    r:r if r in ['ŁÓDZKIE', 'LWOWSKIE', 'POZNAŃSKIE']
    else 'OTHER'
    for r in all_regions_raw
}

# Example voivodeships colors for plotting
example_r_to_color = {
    'ŁÓDZKIE': '#0000a2',
    'LWOWSKIE': '#e9c716',
    'POZNAŃSKIE': '#bc272d',
    'OTHER': '#d3d3d3'
}

# %%
# Grouping to collapse data for WARSZAWSKIE voivodship and M. ST. WARSZAWA (Warsaw capital, which had the legal status of a voivodship)
#   to one voivodship WARSZAWSKIE
warsaw_region_grouping = {
    'BIAŁOSTOCKIE': 'BIAŁOSTOCKIE',
    'KIELECKIE': 'KIELECKIE',
    'KRAKOWSKIE': 'KRAKOWSKIE',
    'LUBELSKIE': 'LUBELSKIE',
    'LWOWSKIE': 'LWOWSKIE',
    'M. ST. WARSZAWA': 'WARSZAWSKIE', # The difference is here
    'NOWOGRÓDZKIE': 'NOWOGRÓDZKIE',
    'POLESKIE': 'POLESKIE',
    'POMORSKIE': 'POMORSKIE',
    'POZNAŃSKIE': 'POZNAŃSKIE',
    'STANISŁAWOWSKIE': 'STANISŁAWOWSKIE',
    'TARNOPOLSKIE': 'TARNOPOLSKIE',
    'WARSZAWSKIE': 'WARSZAWSKIE',
    'WOŁYŃSKIE': 'WOŁYŃSKIE',
    'ZIEMIA WILEŃSKA': 'ZIEMIA WILEŃSKA',
    'ŁÓDZKIE': 'ŁÓDZKIE',
    'ŚLĄSKIE': 'ŚLĄSKIE'
    }

# %%
"""
Grouping aggregating smaller cities with their districts.

Some city districts that were created in the interwar period didn't exist from
the beginning and so the differentiation between them and their surrounding
districts (e.g. Inowrocławski and Inowrocław (city)) is of poor quality.
In all of the estimtes, we sum up data from such district pairs and analyze
them together.
"""
d_city_mapping = {
    'BĘDZIŃSKI': 'BĘDZIŃSKI',
    'SOSNOWIEC': 'BĘDZIŃSKI',
    'ZAWIERCIAŃSKI': 'BĘDZIŃSKI',
    'BIELSKI (BIELSKO)': 'BIELSKO',
    'BIELSKO (MIASTO)': 'BIELSKO',
    'BIAŁYSTOK (MIASTO)': 'BIAŁOSTOCKI',
    'BIAŁOSTOCKI': 'BIAŁOSTOCKI',
    'BYDGOSZCZ (MIASTO)': 'BYDGOSKI',
    'BYDGOSKI': 'BYDGOSKI',
    'CZĘSTOCHOWA (MIASTO)': 'CZĘSTOCHOWSKI',
    'CZĘSTOCHOWSKI': 'CZĘSTOCHOWSKI',
    'GDYNIA (MIASTO)': 'MORSKI',
    'GNIEZNO (MIASTO)': 'GNIEŹNIEŃSKI',
    'GNIEŹNIEŃSKI': 'GNIEŹNIEŃSKI',
    'MORSKI': 'MORSKI',
    'GRUDZIĄDZ (MIASTO)': 'GRUDZIĄDZKI',
    'GRUDZIĄDZKI': 'GRUDZIĄDZKI',
    'INOWROCŁAW (MIASTO)': 'INOWROCŁAWSKI',
    'INOWROCŁAWSKI': 'INOWROCŁAWSKI',
    'KATOWICE (MIASTO)': 'KATOWICE',
    'KATOWICKI': 'KATOWICE',
    'LUBLIN (MIASTO)': 'LUBELSKI',
    'LUBELSKI': 'LUBELSKI',
    'RADOMSKI': 'RADOMSKI',
    'RADOM (MIASTO)': 'RADOMSKI',
    'TORUŃ (MIASTO)': 'TORUŃSKI',
    'TORUŃSKI': 'TORUŃSKI',
    'POŁUDNIOWO-WARSZAWSKI': 'M. ST. WARSZAWA',
    'PÓŁNOCNO-WARSZAWSKI': 'M. ST. WARSZAWA',
    'PRASKO-WARSZAWSKI': 'M. ST. WARSZAWA',
    'ŚRÓDMIEJSKO-WARSZAWSKI': 'M. ST. WARSZAWA',
}

# Other districts are mapped to themselves
d_city_mapping = {dist:d_city_mapping[dist] if dist in d_city_mapping.keys() else dist for dist in all_districts_raw}

"""
List of big cities. I omit the cities below 150 000 citizens according to 1931 census:
 - 'BYDGOSZCZ (MIASTO)' (117 000)
 - 'CZĘSTOCHOWA (MIASTO)' (117 000)
 - 'LUBLIN' (112 000)
 - 'BIAŁYSTOK (MIASTO)' (91 000)
 - 'BIELSKO' (84 000) ('BIELSKO (MIASTO)' and 'BIELSKI (BIELSKO)' together)
 - 'RADOM (MIASTO)' (78 000)
 - 'GRUDZIĄDZ (MIASTO)' (54 000)
 - 'TORUŃ (MIASTO)' (54 000)
 - 'INOWROCŁAW (MIASTO)' (34 000)
 - 'GDYNIA (MIASTO)' (33 000)
 - 'GNIEZNO (MIASTO)' (31 000)
 """

big_cities = [
    'KATOWICE', # 341 000 ('KATOWICKI' and 'KATOWICE (MIASTO)' together)
    'KRAKÓW', # 220 000
    'LWÓW', # 312 000
    'ŁÓDŹ', # 605 000
    'POZNAŃ (MIASTO)', # 246 000
    'M. ST. WARSZAWA', # 1 172 000 (all Warsaw district together)
    'WILNO (MIASTO)' # 195 000
]

big_cities_to_color = {
    'Big City': '#0a0903ff',
    'Not a Big City': '#ff8200ff'
}

# %%
# For plotting
sector_colors = {
    'Agriculture': '#2ca02c',      # Green
    'Industry': 'purple',         # Red
    'Private_Services': '#1f77b4', # Light Blue
    'Public_Services': '#084594'   # Dark Blue
}

# %%
"""
Create lists of all districts and regions used in the Notebook
(they are raw districts and regions grouped according to warsaw_region_grouping
and d_city_mapping).
"""
all_districts = list({d_city_mapping[dist] for dist in all_districts_raw})
all_regions = list({warsaw_region_grouping[region] for region in all_regions_raw})

# Load region-district pairs in the reference_adm_state
r_d_pairs_reference_adm_state = reference_adm_state.to_address_list(only_homeland=True)

# Create a dict mapping raw (not grouped with d_city_mapping) districts to regions
d_to_r_raw = {}
for region, dist in r_d_pairs_reference_adm_state:
    d_to_r_raw[dist] = region

# Create a dict mapping grouped district to regions
d_to_r = {d_city_mapping[dist]: warsaw_region_grouping[d_to_r_raw[dist]] for dist in d_to_r_raw.keys()}

# Define a dict mapping districts in the go-to administrative state to voivodship group.
d_to_r_group = {}
for dist, region in d_to_r.items():
    d_to_r_group[dist] = r_to_r_group[region]

# Define a dict mapping to example region
d_to_example_r = {}
for dist, region in d_to_r.items():
    d_to_example_r[dist] = r_to_example_r[region]

# %%
# Dist mapping a district name to whether the district is a big city
is_big_city = {
    dist: 'Big City' if dist in big_cities else 'Not a Big City'
    for dist in all_districts
}

# %%
# Create empty dfs
empty_dist_df = pd.DataFrame(all_districts, columns = ['District'])
empty_dist_df.set_index('District', inplace=True)
empty_region_df = pd.DataFrame(all_regions, columns = ['Region'])
empty_region_df.set_index('Region', inplace=True)

all_years = list(range(1924, 1939))

# Create a df dict to store production estimates for each year
empty_year_df_dict = {}
for year in all_years:
    empty_year_df_dict[year] = empty_dist_df.copy()

production_by_year = copy.deepcopy(empty_year_df_dict)

# %% [markdown]
# ### Load utils

# %%
from gdp_computation_utils.general import (
    distribute_r_values_to_d,
    interpolate_missing_years,
    fill_zero_values_by_proportional_scaling,
    sum_up_regions,
    collect_variable_over_years
)
from gdp_computation_utils.plots import (
    plot_administrative_borders,
    plot_convergence,
    plot_year_df_columns,
    plot_df_columns_and_export_excel,
    plot_va_growth_scatter,
    plot_theil_decompositions,
    spatial_autocorrelation_over_time,
    plot_cumulative_variance_decomposition,
    plot_cv_over_time,
    plot_many_cvs_over_time,
    plot_morans_I_over_time,
    plot_theil_decomposition_sequence
)
from gdp_computation_utils.estimates import (
    theil_index, # Computes Theil-index
    decompose_theil_regionally,
    compute_shapley_contributions,
    compute_shapley_contributions,
    analyze_all_years_theil,
    create_distance_matrix,
    distance_matrix_to_weights,
    compute_morans_I, # Computes Moran's I
    compute_gearys_C, # Computes Geary's C
    compute_lisa, # Computes LISA,
    variance_decomposition, # Within-region vs between-region variance
    estimate_multilevel_convergence
)

# %% [markdown]
# ### Create Distance and Proximity Weights Matrix

# %%
def prepare_dist_geoms(administrative_history: AdministrativeHistory):
    """
    Prepares an empty geodataframe with 'District' index and geometries
    """
    # Assign new group names using the mapping
    dist_geoms = administrative_history.dist_registry._plot_layer(date=reference_date)[['name_id', 'geometry']]
    dist_geoms = dist_geoms.rename(columns={'name_id': 'District'}).set_index('District')

    # Map each district to its city/group
    dist_geoms['Group'] = dist_geoms.index.map(d_city_mapping)

    # Dissolve (i.e., merge) geometries by group
    dist_geoms = dist_geoms.dissolve(by='Group')

    # Rename index to 'District'
    dist_geoms.index.name = 'District'
    return dist_geoms

dist_geoms = prepare_dist_geoms(administrative_history)

# %%
# Generate a distance matrix
distance_matrix = create_distance_matrix(dist_geoms)
# Out:
# e:\Studia\Studia magisterskie\Masterarbeit - Wirtschaftwissenschaft\dane\Digitalizacja\border_harmonization_toolkit\examples\interwar_poland_gdp\gdp_computation_utils\estimates.py:161: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = dist_geoms.geometry.centroid

# %%
# Build the weights matrix
weights = distance_matrix_to_weights(distance_matrix, threshold=120000, binary=False)  # threshold 120000 means 120km radius

# %% [markdown]
# ### Plot administrative borders

# %%
plot_administrative_borders(
    dist_geoms,
    d_to_r_group,
    r_group_to_color,
    show_labels=False,
    save_to_path=plots_output_path + "/Administrative_Maps/region_groups.png"
)

for region_group in ['CENTRAL','EASTERN', 'SOUTHERN', 'WESTERN']:
    plot_administrative_borders(
        dist_geoms,
        d_to_r_group,
        r_group_to_color,
        focus_group=region_group,
        save_to_path=plots_output_path + f"/Administrative_Maps/{region_group}_districts.png"
    )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 plot_administrative_borders(
#       2     dist_geoms,
#       3     d_to_r_group,
#       4     r_group_to_color,
#       5     show_labels=False,
#       6     save_to_path=plots_output_path + "/Administrative_Maps/region_groups.png"
#       7 )
#       9 for region_group in ['CENTRAL','EASTERN', 'SOUTHERN', 'WESTERN']:
#      10     plot_administrative_borders(
#      11         dist_geoms,
#      12         d_to_r_group,
#    (...)
#      15         save_to_path=plots_output_path + f"/Administrative_Maps/{region_group}_districts.png"
#      16     )
#
# File e:\Studia\Studia magisterskie\Masterarbeit - Wirtschaftwissenschaft\dane\Digitalizacja\border_harmonization_toolkit\examples\interwar_poland_gdp\gdp_computation_utils\plots.py:105, in plot_administrative_borders(dist_geoms, d_to_r_group, r_group_to_color, default_color, figsize, focus_group, show_labels, save_to_path)
#     103 plt.tight_layout()
#     104 if save_to_path:
# --> 105     plt.savefig(save_to_path, dpi=300)
#     106     print(f"Plot saved to: {save_to_path}")
#     107 else:
#
# File c:\Users\janek\miniconda3\Lib\site-packages\matplotlib\pyplot.py:1134, in savefig(*args, **kwargs)
#    1131 fig = gcf()
#    1132 # savefig default implementation has no return, so mypy is unhappy
#    1133 # presumably this is here because subclasses can return?
# -> 1134 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1135 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1136 return res
#
# File c:\Users\janek\miniconda3\Lib\site-packages\matplotlib\figure.py:3390, in Figure.savefig(self, fname, transparent, **kwargs)
#    3388     for ax in self.axes:
#    3389         _recursively_make_axes_transparent(stack, ax)
# -> 3390 self.canvas.print_figure(fname, **kwargs)
#
# File c:\Users\janek\miniconda3\Lib\site-packages\matplotlib\backend_bases.py:2193, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2189 try:
#    2190     # _get_renderer may change the figure dpi (as vector formats
#    2191     # force the figure dpi to 72), so we need to set it again here.
#    2192     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2193         result = print_method(
#    2194             filename,
#    2195             facecolor=facecolor,
#    2196             edgecolor=edgecolor,
#    2197             orientation=orientation,
#    2198             bbox_inches_restore=_bbox_inches_restore,
#    2199             **kwargs)
#    2200 finally:
#    2201     if bbox_inches and restore_bbox:
#
# File c:\Users\janek\miniconda3\Lib\site-packages\matplotlib\backend_bases.py:2043, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2039     optional_kws = {  # Passed by print_figure for other renderers.
#    2040         "dpi", "facecolor", "edgecolor", "orientation",
#    2041         "bbox_inches_restore"}
#    2042     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2043     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2044         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2045 else:  # Let third-parties do as they see fit.
#    2046     print_method = meth
#
# File c:\Users\janek\miniconda3\Lib\site-packages\matplotlib\backends\backend_agg.py:497, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     450 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     451     """
#     452     Write the figure to a PNG file.
#     453
#    (...)
#     495         *metadata*, including the default 'Software' key.
#     496     """
# --> 497     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File c:\Users\janek\miniconda3\Lib\site-packages\matplotlib\backends\backend_agg.py:446, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     441 """
#     442 Draw the canvas, then save it using `.image.imsave` (to which
#     443 *pil_kwargs* and *metadata* are forwarded).
#     444 """
#     445 FigureCanvasAgg.draw(self)
# --> 446 mpl.image.imsave(
#     447     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     448     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File c:\Users\janek\miniconda3\Lib\site-packages\matplotlib\image.py:1656, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1654 pil_kwargs.setdefault("format", format)
#    1655 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1656 image.save(fname, **pil_kwargs)
#
# File c:\Users\janek\miniconda3\Lib\site-packages\PIL\Image.py:2436, in Image.save(self, fp, format, **params)
#    2434         fp = builtins.open(filename, "r+b")
#    2435     else:
# -> 2436         fp = builtins.open(filename, "w+b")
#    2438 try:
#    2439     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:/Studia/Studia magisterskie/Masterarbeit - Wirtschaftwissenschaft/post_master_data_plots/Administrative_Maps/region_groups.png'

# %% [markdown]
# # Population and district area

# %% [markdown]
# ### Load population

# %% [markdown]
# 1931 population is loaded directly from census data.

# %%
population_1931, population_1931_data_table_metadata, population_1931_adm_state_date = adm_history_api.load_data_table(data_table_id = '1931-total_population', version='harmonized', custom_grouping=d_city_mapping, custom_grouping_method = 'sum')
population_1931.rename(columns = {"Census 1931/Population/Total": "Population"}, inplace = True)

# %% [markdown]
# 1921 population is loaded directly from census data and corrected where needed.

# %%
population_1921_raw, population_1921_data_table_metadata, population_1921_adm_state_date = adm_history_api.load_data_table(data_table_id = '1921-total_population_from_1931_census_publications', version='harmonized', custom_grouping=d_city_mapping, custom_grouping_method = 'sum')
population_1921_raw.rename(columns = {"Census 1921/Population/Total (Data from 1931 Census Publications)": "Population"}, inplace = True)
population_1921 = population_1921_raw.copy()

# %% [markdown]
# Regional population estimates are taken from Bukowski et al. (2025) paper.

# %%
region_population = read_economic_csv_input(adm_level='Region', input_csv_path=regional_population_path)
# Out:
# E:\Studia\Studia magisterskie\Masterarbeit - Wirtschaftwissenschaft\dane\Digitalizacja\border_harmonization_toolkit\src\administrative_history\utils\helper_functions.py:308: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %% [markdown]
# Load city population

# %%
city_population_1921, city_population_1921_data_table_metadata, city_population_1921_adm_state_date = adm_history_api.load_data_table(data_table_id = 'city-1921-population', version='harmonized')
city_population_1931, city_population_1931_data_table_metadata, city_population_1931_adm_state_date = adm_history_api.load_data_table(data_table_id = 'city-1931-population', version='harmonized')
city_population_1939, city_population_1939_data_table_metadata, city_population_1939_adm_state_date = adm_history_api.load_data_table(data_table_id = 'city-1939-population', version='harmonized')

city_population = pd.concat([
    city_population_1921.rename(columns={city_population_1921.columns[0]: "1921"}),
    city_population_1931.rename(columns={city_population_1931.columns[0]: "1931"}),
    city_population_1939.rename(columns={city_population_1939.columns[0]: "1939"})
], axis=1)

# %% [markdown]
# Map city population data to districts

# %%
# Map city data to districts
dist_urban_population = adm_history_processor.map_city_data_to_dists(city_population, reference_date, geojson_path="output/cities_used_for_population_estimates.geojson", custom_grouping=d_city_mapping, custom_grouping_method = 'sum')
dist_urban_population.index.name = "District"
# Out:
# ⚠️ Dropped 55 rows due to NaN values: ['Bnin (Kórnik)', 'Boćki', 'Brzostek', 'Budzyń', 'Busk', 'Chodorów', 'Ciężkowice', 'Czarny Dunajec', 'Dobromil', 'Gąsawa', 'Gębice', 'Jagielnica (dziś Ukraina)', 'Jaraczew (Jaraczewo)', 'Jazłowiec', 'Kopanica', 'Kopyczyńce', 'Lanckorona', 'Mielnik (nad Bugiem)', 'Mieścisko', 'Narew', 'Niżankowice (dziś Ukraina)', 'Nowe Miasto nad Wartą', 'Nowy Dwór (nad Biebrzą)', 'Obrzycko', 'Odelsk', 'Ostrzeszów', 'Piaski', 'Powidz', 'Raków (Mołodecki)', 'Rogowo (nad jez. Rogowskim)', 'Rostarzewo', 'Rychtal', 'Ryczywół', 'Rynarzewo', 'Stara Sól', 'Szereszów', 'Ulanów', 'Uście Solne', 'Wiśnicz Nowy', 'Wojnicz', 'Władysławów', 'Włodzimierz (dziś Ukraina)', 'Zaniemyśl', 'Łohiszyn', 'Bogumin', 'Bogumin Nowy', 'Chorostków', 'Frysztat', 'Gwoździec', 'Karwina', 'Mielnica Podolska', 'Orłowa', 'Skórcz', 'Trzyniec', 'Tłuste']
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona\\ogrext.pyx:175, in fiona.ogrext.gdal_create()
#
# File fiona\\_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: Failed to create GeoJSON datasource: output/cities_used_for_population_estimates.geojson: output/cities_used_for_population_estimates.geojson: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# Cell In[34], line 2
#       1 # Map city data to districts
# ----> 2 dist_urban_population = adm_history_processor.map_city_data_to_dists(city_population, reference_date, geojson_path="output/cities_used_for_population_estimates.geojson", custom_grouping=d_city_mapping, custom_grouping_method = 'sum')
#       3 dist_urban_population.index.name = "District"
#
# File E:\Studia\Studia magisterskie\Masterarbeit - Wirtschaftwissenschaft\dane\Digitalizacja\border_harmonization_toolkit\src\administrative_history\core\processor.py:983, in AdministrativeHistoryProcessor.map_city_data_to_dists(self, df, date, geojson_path, custom_grouping, custom_grouping_method)
#     981 if geojson_path is not None:
#     982     gdf = gpd.GeoDataFrame(geo_records, geometry="geometry", crs="EPSG:4326")
# --> 983     gdf.to_file(geojson_path, driver="GeoJSON")
#     984     print(f"📂 GeoJSON with {len(gdf)} city points written to: {geojson_path}")
#     986 # ✅ Step 7: Apply custom grouping if provided
#
# File c:\Users\janek\miniconda3\Lib\site-packages\geopandas\geodataframe.py:1246, in GeoDataFrame.to_file(self, filename, driver, schema, index, **kwargs)
#    1155 """Write the ``GeoDataFrame`` to a file.
#    1156
#    1157 By default, an ESRI shapefile is written, but any OGR data source
#    (...)
#    1242
#    1243 """
#    1244 from geopandas.io.file import _to_file
# -> 1246 _to_file(self, filename, driver, schema, index, **kwargs)
#
# File c:\Users\janek\miniconda3\Lib\site-packages\geopandas\io\file.py:633, in _to_file(df, filename, driver, schema, index, mode, crs, engine, **kwargs)
#     630     raise ValueError(f"'mode' should be one of 'w' or 'a', got '{mode}' instead")
#     632 if engine == "fiona":
# --> 633     _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
#     634 elif engine == "pyogrio":
#     635     _to_file_pyogrio(df, filename, driver, schema, crs, mode, **kwargs)
#
# File c:\Users\janek\miniconda3\Lib\site-packages\geopandas\io\file.py:661, in _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
#     659 elif crs:
#     660     crs_wkt = crs.to_wkt("WKT1_GDAL")
# --> 661 with fiona.open(
#     662     filename, mode=mode, driver=driver, crs_wkt=crs_wkt, schema=schema, **kwargs
#     663 ) as colxn:
#     664     colxn.writerecords(df.iterfeatures())
#
# File c:\Users\janek\miniconda3\Lib\site-packages\fiona\env.py:457, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     454     session = DummySession()
#     456 with env_ctor(session=session):
# --> 457     return f(*args, **kwds)
#
# File c:\Users\janek\miniconda3\Lib\site-packages\fiona\__init__.py:316, in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, allow_unsupported_drivers, **kwargs)
#     305     colxn = Collection(
#     306         path,
#     307         mode,
#    (...)
#     313         **kwargs
#     314     )
#     315 elif mode == "w":
# --> 316     colxn = Collection(
#     317         path,
#     318         mode,
#     319         crs=crs,
#     320         driver=driver,
#     321         schema=schema,
#     322         encoding=encoding,
#     323         layer=layer,
#     324         enabled_drivers=enabled_drivers,
#     325         crs_wkt=crs_wkt,
#     326         allow_unsupported_drivers=allow_unsupported_drivers,
#     327         **kwargs
#     328     )
#     329 else:
#     330     raise ValueError("mode string must be one of {'r', 'w', 'a'}")
#
# File c:\Users\janek\miniconda3\Lib\site-packages\fiona\collection.py:246, in Collection.__init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, include_fields, wkt_version, allow_unsupported_drivers, **kwargs)
#     244     elif self.mode in ("a", "w"):
#     245         self.session = WritingSession()
# --> 246         self.session.start(self, **kwargs)
#     247 except OSError:
#     248     self.session = None
#
# File fiona\\ogrext.pyx:1110, in fiona.ogrext.WritingSession.start()
#
# File fiona\\ogrext.pyx:1111, in fiona.ogrext.WritingSession.start()
#
# File fiona\\ogrext.pyx:179, in fiona.ogrext.gdal_create()
#
# DriverError: Failed to create GeoJSON datasource: output/cities_used_for_population_estimates.geojson: output/cities_used_for_population_estimates.geojson: No such file or directory

# %% [markdown]
# Impute data for Wileński region (in 1921 census didn't cover its territory)

# %%
# Districts with data from 1919 census
# Extrapolate the data to 1921 to be (1921-1919/1931-1919)*population_1931+population_1919
for dist in ["MOŁODECZAŃSKI", "OSZMIAŃSKI", "POSTAWSKI", "ŚWIĘCIAŃSKI", "WILEJSKI", "WILEŃSKO-TROCKI"]:
    population_1921.loc[dist, "Population"] = (10/12)*population_1921_raw.loc[dist, "Population"] + (2/12)*population_1931.loc[dist, "Population"]

# The data for district 'Wileńsko-Trocki' doesn't incorporate the city 'Nowa Wilejka', so we add it
population_1921.loc["WILEŃSKO-TROCKI", "Population"] = population_1921_raw.loc["WILEŃSKO-TROCKI", "Population"] + city_population.loc["Nowa Wilejka", "1921"]

# %% [markdown]
# Compute population weights for distribution of the regional data in 1921 in Silesia and 1939 for all districts

# %%
# For districts with plain data problems, use extrapolated dist trends from 1921-1931 to estimate the city population
dist_urban_population.loc["HORODEŃSKI", "1939"] = dist_urban_population.loc["HORODEŃSKI", "1931"] + (8/10)*(dist_urban_population.loc["HORODEŃSKI", "1931"]-dist_urban_population.loc["HORODEŃSKI", "1921"])

# %%
dist_urban_population.loc["HORODEŃSKI", "1939"]

# %%
production_by_year[1921] = empty_dist_df.copy()
production_by_year[1922] = empty_dist_df.copy()
production_by_year[1923] = empty_dist_df.copy()
production_by_year[1939] = empty_dist_df.copy()

# %%
dist_urban_population

# %%
production_by_year[1921]['Urban_Population'] = dist_urban_population['1921']
production_by_year[1931]['Urban_Population'] = dist_urban_population['1931']
production_by_year[1939]['Urban_Population'] = dist_urban_population['1939']

# %%
production_by_year[1921]['Population_Weights'] = (production_by_year[1921]['Urban_Population']/production_by_year[1931]['Urban_Population'])*population_1931["Population"]

# %%
# Distribute the Śląskie data
region_population["1921_silesia"] = 0
region_population.loc["ŚLĄSKIE", "1921_silesia"] = 1125334

# Distribute the regional estimates for 1921
dist_population_df = distribute_r_values_to_d(region_df=region_population, region_value_col="1921_silesia", dist_df=production_by_year[1921], dist_value_col = 'Population_Weights', new_col_name='Population', d_to_r=d_to_r)
production_by_year[1921]['Population'] = dist_population_df['Population']

# Fill in all other slots with 1921 census data
production_by_year[1921].loc[production_by_year[1921]['Population']==0, 'Population'] = population_1921.loc[production_by_year[1921]['Population']==0,"Population"]

# Add 1931 population
production_by_year[1931]["Population"] = population_1931["Population"]

# %%
production_by_year[1931].loc['PSZCZYŃSKI', 'Urban_Population']

# %%
production_by_year[1921]['Rural_Population'] = production_by_year[1921]['Population'] - production_by_year[1921]['Urban_Population']
production_by_year[1931]['Rural_Population'] = production_by_year[1931]['Population'] - production_by_year[1931]['Urban_Population']

# %%
# Interpolation of Urban Population
production_by_year = interpolate_missing_years(year_to_df=production_by_year, col_name='Urban_Population',
                                all_years=all_years+[1921, 1922, 1923, 1939], empty_dist_df=empty_dist_df.copy(), extrapolate_trends = False)
# Interpolation of Rural Population
production_by_year = interpolate_missing_years(year_to_df=production_by_year, col_name='Rural_Population',
                                all_years=all_years+[1921, 1922, 1923, 1939], empty_dist_df=empty_dist_df.copy(), extrapolate_trends = True)

# %%
for year in all_years + [1921, 1922, 1923, 1939]:
    production_by_year[year].loc['M. ST. WARSZAWA', 'Rural_Population'] = 1
    production_by_year[year].loc['POZNAŃ (MIASTO)', 'Rural_Population'] = 1
    production_by_year[year].loc['LWÓW (MIASTO)', 'Rural_Population'] = 1
    production_by_year[year].loc['ŁÓDŹ (MIASTO)', 'Rural_Population'] = 1
    production_by_year[year].loc['KRAKÓW (MIASTO)', 'Rural_Population'] = 1
    production_by_year[year].loc['WILNO (MIASTO)', 'Rural_Population'] = 1

# %%
# Sum up urban and rural population for all years
for year in all_years + [1921, 1922, 1923]:
    production_by_year[year]['Population'] = production_by_year[year]['Urban_Population']+production_by_year[year]['Rural_Population']
    # Distribute the regional estimates for each year
    if year not in [1921, 1931]:
        dist_population_df = distribute_r_values_to_d(region_df=region_population, region_value_col=str(year), dist_df=production_by_year[year], dist_value_col = 'Population', new_col_name='Population', d_to_r=d_to_r)
        production_by_year[year]['Population'] = dist_population_df['Population']

# %% [markdown]
# Compute Population Growth

# %%
population_growth=empty_dist_df.copy()
population_growth['Population Growth 1921-1931'] = 100*(production_by_year[1931]['Population']-production_by_year[1921]['Population'])/production_by_year[1921]['Population']
population_growth['Population Growth 1931-1938'] = 100*(production_by_year[1938]['Population']-production_by_year[1931]['Population'])/production_by_year[1931]['Population']
population_growth['Population Growth 1921-1938'] = 100*(production_by_year[1938]['Population']-production_by_year[1921]['Population'])/production_by_year[1921]['Population']

population_growth['Urban Population Growth 1921-1931 (%)'] = (
    100 * (production_by_year[1931]['Urban_Population'] - production_by_year[1921]['Urban_Population'])
    / production_by_year[1921]['Urban_Population']
).replace([np.inf, -np.inf], 0)

population_growth['Urban Population Growth 1931-1938 (%)'] = (
    100 * (production_by_year[1938]['Urban_Population'] - production_by_year[1931]['Urban_Population'])
    / production_by_year[1931]['Urban_Population']
).replace([np.inf, -np.inf], 0)

population_growth['Urban Population Growth 1921-1938 (%)'] = (
    100 * (production_by_year[1938]['Urban_Population'] - production_by_year[1921]['Urban_Population'])
    / production_by_year[1921]['Urban_Population']
).replace([np.inf, -np.inf], 0)


population_growth['Rural Population Growth 1921-1931 (%)'] = (
    100 * (production_by_year[1931]['Rural_Population'] - production_by_year[1921]['Rural_Population'])
    / production_by_year[1921]['Rural_Population']
).replace([np.inf, -np.inf], 0)

population_growth['Rural Population Growth 1931-1938 (%)'] = (
    100 * (production_by_year[1938]['Rural_Population'] - production_by_year[1931]['Rural_Population'])
    / production_by_year[1931]['Rural_Population']
).replace([np.inf, -np.inf], 0)

population_growth['Rural Population Growth 1921-1938 (%)'] = (
    100 * (production_by_year[1938]['Rural_Population'] - production_by_year[1921]['Rural_Population'])
    / production_by_year[1921]['Rural_Population']
).replace([np.inf, -np.inf], 0)

# %%
sum_up_regions(production_by_year[1922], d_to_r)

# %%
for year in [1921, 1922, 1923] + all_years:
    region_population[str(year)+"dist_population_sum"] = sum_up_regions(production_by_year[year], d_to_r)["Population"]

# %% [markdown]
# Plot Population Growth

# %%
del production_by_year[1939]

# %%
plot_df_columns_and_export_excel(
    administrative_history=administrative_history,
    custom_dist_grouping=d_city_mapping,
    plots_output_path=plots_output_path,
    path_suffix = "/Population/Growth/",
    df = population_growth,
    col_title_prefix="",
    cmap = 'Reds',
    export_excel = True
)

# %%
# Plot population
plot_year_df_columns(
    administrative_history=administrative_history,
    custom_dist_grouping=d_city_mapping,
    plots_output_path=plots_output_path,
    path_suffix = "/Population/Total/",
    year_df_dict = production_by_year,
    col_name = 'Population',
    title = 'Population',
    export_excel = True
)

# %%
# Plot urban population
plot_year_df_columns(
    administrative_history=administrative_history,
    custom_dist_grouping=d_city_mapping,
    plots_output_path=plots_output_path,
    path_suffix = "/Population/Urban/",
    year_df_dict = production_by_year,
    col_name = 'Urban_Population',
    title = 'Population',
    export_excel = True
)

# %%
# Plot rural population
plot_year_df_columns(
    administrative_history=administrative_history,
    custom_dist_grouping=d_city_mapping,
    plots_output_path=plots_output_path,
    path_suffix = "/Population/Rural/",
    year_df_dict = production_by_year,
    col_name = 'Rural_Population',
    title = 'Population',
    export_excel = True
)

# %% [markdown]
# Remove years 1921-1923 from production_by_year dict for further processing

# %%
del production_by_year[1921]
del production_by_year[1922]
del production_by_year[1923]

# %% [markdown]
# ### Load district area

# %%
dist_area_data_table, dist_area_metadata, dist_area_date = adm_history_api.load_data_table(data_table_id = 'dist_area_baseline_adm_state', version = 'harmonized', custom_grouping=d_city_mapping, custom_grouping_method = 'sum')
dist_area_data_table.rename(columns={'Area: Together': 'Total District Area'}, inplace = True)

# %% [markdown]
# ### Compute population density

# %%
population_1931['Population Density: People per km2'] = 10*(production_by_year[1931]['Population']/dist_area_data_table['Total District Area'])
population_1931['Log Population Density'] = np.log(population_1931['Population Density: People per km2'])

# %%
plot_df_columns_and_export_excel(
    administrative_history=administrative_history,
    custom_dist_grouping=d_city_mapping,
    plots_output_path=plots_output_path,
    path_suffix = "/Population/",
    df = population_1931,
    col_title_prefix = "1931",
    cmap = 'Reds',
    export_excel = True
)

# %% [markdown]
# # Agriculture

# %% [markdown]
# ## Forests

# %% [markdown]
# ### Load forests data

# %%
forests_data_table, forests_metadata, forests_date = adm_history_api.load_data_table(data_table_id = '1930-forests_area_ha_ready', version = 'harmonized', custom_grouping=d_city_mapping, custom_grouping_method = 'sum')
forests_data_table.rename(columns={'Area: Together': 'Total Forest Area'}, inplace = True)
forests_data_table = forests_data_table.merge(dist_area_data_table, on='District', how='left')
forests_data_table['Forest as District Area Proportion'] = forests_data_table['Total Forest Area']/forests_data_table['Total District Area']

# %% [markdown]
# Generate and save plots with forest area and forest area in comparison to .

# %%
plot_df_columns_and_export_excel(
    administrative_history=administrative_history,
    custom_dist_grouping=d_city_mapping,
    plots_output_path=plots_output_path,
    path_suffix = "/Agriculture/Forests/",
    df = forests_data_table,
    col_title_prefix = "",
    cmap = "YlOrBr",
    export_excel = True,
    columns_subset = ['Total Forest Area', 'Forest as District Area Proportion']
)

# %% [markdown]
# I compute the total value of the forest production as Wronski et al. (2025) - I take yearly incomes of 'Lasy Państwowe' ('State Forests') that controlled and managed 46% of the forests in Poland (Wronski et al., 2025), multiply it by (2.17 = 1/0.46), and spread the incomes according to the forest area per district in 1930. The incomes exist for years 1921-1925 and 1932-1937, for years 1926-1931 they are interpolated with the use of the time series of State Forests' payments to the state budget.

# %%
state_forests_incomes = {
    1921: 13_116_000.0,
    1922: 35_291_000.0,
    1923: 33_889_000.0,
    1924: 25_331_000.0,
    1925: 62_522_000.0,
    1926: None,
    1927: None,
    1928: None,
    1929: None,
    1930: None,
    1931: None,
    1932: 120_200_000.0,
    1933: 128_400_000.0,
    1934: 181_300_000.0,
    1935: 210_000_000.0,
    1936: 287_600_000.0,
    1937: 374_100_000.0
    }

# Interpolate for 1938 linearly
state_forests_incomes[1938] = state_forests_incomes[1937] + (state_forests_incomes[1937]-state_forests_incomes[1936])

prop_total_to_state_forest_area = 2.17

budget_payment = {
    1925: 36_157_000.0,
    1926: 89_287_000.0,
    1927: 118_999_000.0,
    1928: 80_643_000.0,
    1929: 80_395_000.0,
    1930: 72_000_000.0,
    1931: 33_000_000.0,
    1932: 48_000_000.0
}

# %%
total_forests_incomes = {year: prop_total_to_state_forest_area*incomes if incomes is not None else None for year, incomes in state_forests_incomes.items()}
print(total_forests_incomes)

# %%
prop_budget_payment = {}
for year, payment in budget_payment.items():
    prop_budget_payment[year] = payment/budget_payment[1925]
print(prop_budget_payment)

# %%
for year in range(1926, 1932):
    total_forests_incomes[year] = total_forests_incomes[1925]*prop_budget_payment[year]
print(total_forests_incomes)

# %% [markdown]
# Distribute yearly forest production according to 1930 forest area per district.

# %%
for year in all_years:
    df = forests_data_table[['Total Forest Area']].copy()
    total_area = df['Total Forest Area'].sum()

    # Compute proportional share and assign
    production_by_year[year]['Forest Value Added'] = (df['Total Forest Area']/total_area)*total_forests_incomes[year]

# %% [markdown]
# ## Crops

# %% [markdown]
# ### Prepare prices and yields data for 5 main crops

# %% [markdown]
# Load crop prices for 5 main crops:
# - 'Pszenica',
# - 'Żyto',
# - 'Jęczmień',
# - 'Owies',
# - 'Ziemniaki'.
#
# In cases where prices of multiple crop subtypes are given, I choose:
# - 'Ziemniaki: Jadalne', where 'Ziemniaki: Jadalne' and 'Ziemniaki: Fabryczne' are given,
# - 'Jęczmień: Browarny', where 'Jęczmień: Browarny', and 'Jęczmień: Innych gatunków' or 'Jęczmień: Na kaszę' are given.

# %%
def save_dict_of_dfs_to_excel(df_dict, filename):
    """
    Save a dictionary of DataFrames to an Excel file, 
    where each key corresponds to a separate sheet.

    Parameters:
        df_dict (dict[int, pd.DataFrame]): Dictionary of DataFrames.
        filename (str): Output Excel filename, e.g. 'output.xlsx'.
    """
    with pd.ExcelWriter(filename, engine='openpyxl') as writer:
        for key, df in df_dict.items():
            # Ensure the sheet name is a string (Excel sheet names must be strings and ≤31 chars)
            sheet_name = str(key)[:31]
            df.to_excel(writer, sheet_name=sheet_name)
    print(f"✅ Saved {len(df_dict)} DataFrames to '{filename}'")

# %%
def fill_zeros_with_column(target_df, source_df, target_col, source_col):
    """
    Replace 0s in `target_col` of `target_df` with corresponding values from `source_col` in `source_df`.

    Parameters:
        source_df (pd.DataFrame): DataFrame with values used for filling.
        target_df (pd.DataFrame): DataFrame whose column will be filled.
        target_col (str): Name of the column to fill.
        source_col (str): Name of the column to pull values from.

    Returns:
        pd.DataFrame: Updated DataFrame with the target column filled.
    """
    if source_col not in source_df.columns:
        print(f"❌ Column '{source_col}' not present in source_df.")
    else:
        target_df = target_df.copy()
        zero_mask = target_df[target_col] == 0
        filled_indices = target_df.index[zero_mask]

        target_df.loc[zero_mask, target_col] = source_df.loc[zero_mask, source_col]

        print(f"✅ Filled '{target_col}' in {len(filled_indices)} rows using '{source_col}' from source_df.")
        if not filled_indices.empty:
            print("📍 Filled indices:")
            print(filled_indices.tolist())
    return target_df

# %%
columns_to_select = ['Wheat', 'Rye', 'Barley/All Types', 'Oats', 'Potatoes/All Types', 'Potatoes/Edible', 'Barley/Malting Barley']
columns_to_select = ['Prices/Local Paid to Producers/' + col for col in columns_to_select]
# Load the crops prices
crops_prices_data_table_ids = [
    data_table.data_table_id
    for data_table in adm_history_processor.processed_data_metadata.items
    if any(col.startswith("Prices/") for col in data_table.columns.keys())
]
crops_prices_dfs = [adm_history_api.load_data_table(data_table_id = crops_data_table_id, version = 'harmonized', custom_grouping=d_city_mapping, custom_grouping_method='average') for crops_data_table_id in crops_prices_data_table_ids]
crops_prices_year_df = {extract_date_parts(metadata.date)[0]: df for df, metadata, date in crops_prices_dfs if extract_date_parts(metadata.date)[1] == 8 or extract_date_parts(metadata.date)[0] is None}
crops_prices_year_df_clean = copy.deepcopy(empty_year_df_dict)
for year, df in crops_prices_year_df.items():
    print(f"Year: {year}.")
    print(f"df.columns: {df.columns}")
    existing_columns = [col for col in columns_to_select if col in df.columns]
    df = df[existing_columns]
    df.columns = [col.split('/')[2].strip() for col in df.columns]
    print(f"columns_to_select: {columns_to_select}")
    print(f"existing_columns: {existing_columns}")
    df_filled = fill_zeros_with_column(df, crops_prices_year_df[year], 'Barley', 'Prices/Local Paid to Producers/Barley/For Groats')
    df_filled = fill_zeros_with_column(df_filled, crops_prices_year_df[year], 'Barley', 'Prices/Local Paid to Producers/Barley/Other Varieties')
    crops_prices_year_df_clean[year] = df_filled
# Out:
# Year: 1926.
# df.columns: Index(['Prices/Local Paid to Producers/Barley/All Types',
#        'Prices/Local Paid to Producers/Buckwheat',
#        'Prices/Local Paid to Producers/Hay/All Types',
#        'Prices/Local Paid to Producers/Milking Cow (Maximum Price)',
#        'Prices/Local Paid to Producers/Milking Cow (Minimum Price)',
#        'Prices/Local Paid to Producers/Oats',
#        'Prices/Local Paid to Producers/Pig (per kg)',
#        'Prices/Local Paid to Producers/Potatoes/Edible',
#        'Prices/Local Paid to Producers/Potatoes/For Processing',
#        'Prices/Local Paid to Producers/Rye',
#        'Prices/Local Paid to Producers/Straw',
#        'Prices/Local Paid to Producers/Wheat',
#        'Prices/Local Paid to Producers/Working Horse (Maximum Price)',
#        'Prices/Local Paid to Producers/Working Horse (Minimum Price)'],
#       dtype='object', name='variable_name')
# columns_to_select: ['Prices/Local Paid to Producers/Wheat', 'Prices/Local Paid to Producers/Rye', 'Prices/Local Paid to Producers/Barley/All Types', 'Prices/Local Paid to Producers/Oats', 'Prices/Local Paid to Producers/Potatoes/All Types', 'Prices/Local Paid to Producers/Potatoes/Edible', 'Prices/Local Paid to Producers/Barley/Malting Barley']
# existing_columns: ['Prices/Local Paid to Producers/Wheat', 'Prices/Local Paid to Producers/Rye', 'Prices/Local Paid to Producers/Barley/All Types', 'Prices/Local Paid to Producers/Oats', 'Prices/Local Paid to Producers/Potatoes/Edible']
# ❌ Column 'Prices/Local Paid to Producers/Barley/For Groats' not present in source_df.
# ❌ Column 'Prices/Local Paid to Producers/Barley/Other Varieties' not present in source_df.
# Year: 1928.
# df.columns: Index(['Prices/Local Paid to Producers/Barley/All Types',
#        'Prices/Local Paid to Producers/Buckwheat',
#        'Prices/Local Paid to Producers/Hay/Clover Hay',
#        'Prices/Local Paid to Producers/Hay/Meadow Hay',
#        'Prices/Local Paid to Producers/Milking Cow (Maximum Price)',
#        'Prices/Local Paid to Producers/Milking Cow (Minimum Price)',
#        'Prices/Local Paid to Producers/Oats',
#        'Prices/Local Paid to Producers/Potatoes/Edible',
#        'Prices/Local Paid to Producers/Rye',
#        'Prices/Local Paid to Producers/Straw',
#        'Prices/Local Paid to Producers/Wheat',
#        'Prices/Local Paid to Producers/Working Horse (Maximum Price)',
#        'Prices/Local Paid to Producers/Working Horse (Minimum Price)'],
#       dtype='object', name='variable_name')
# columns_to_select: ['Prices/Local Paid to Producers/Wheat', 'Prices/Local Paid to Producers/Rye', 'Prices/Local Paid to Producers/Barley/All Types', 'Prices/Local Paid to Producers/Oats', 'Prices/Local Paid to Producers/Potatoes/All Types', 'Prices/Local Paid to Producers/Potatoes/Edible', 'Prices/Local Paid to Producers/Barley/Malting Barley']
# existing_columns: ['Prices/Local Paid to Producers/Wheat', 'Prices/Local Paid to Producers/Rye', 'Prices/Local Paid to Producers/Barley/All Types', 'Prices/Local Paid to Producers/Oats', 'Prices/Local Paid to Producers/Potatoes/Edible']
# ❌ Column 'Prices/Local Paid to Producers/Barley/For Groats' not present in source_df.
# ❌ Column 'Prices/Local Paid to Producers/Barley/Other Varieties' not present in source_df.
# Year: 1930.
# df.columns: Index(['Prices/Local Paid to Producers/Barley/Malting Barley',
#        'Prices/Local Paid to Producers/Barley/Other Varieties',
#        'Prices/Local Paid to Producers/Buckwheat',
#        'Prices/Local Paid to Producers/Hay/Clover Hay',
#        'Prices/Local Paid to Producers/Hay/Meadow Hay',
#        'Prices/Local Paid to Producers/Oats',
#        'Prices/Local Paid to Producers/Peas',
#        'Prices/Local Paid to Producers/Potatoes/Edible',
#        'Prices/Local Paid to Producers/Potatoes/For Processing',
#        'Prices/Local Paid to Producers/Rye',
#        'Prices/Local Paid to Producers/Straw',
#        'Prices/Local Paid to Producers/Wheat'],
#       dtype='object', name='variable_name')
# columns_to_select: ['Prices/Local Paid to Producers/Wheat', 'Prices/Local Paid to Producers/Rye', 'Prices/Local Paid to Producers/Barley/All Types', 'Prices/Local Paid to Producers/Oats', 'Prices/Local Paid to Producers/Potatoes/All Types', 'Prices/Local Paid to Producers/Potatoes/Edible', 'Prices/Local Paid to Producers/Barley/Malting Barley']
# existing_columns: ['Prices/Local Paid to Producers/Wheat', 'Prices/Local Paid to Producers/Rye', 'Prices/Local Paid to Producers/Oats', 'Prices/Local Paid to Producers/Potatoes/Edible', 'Prices/Local Paid to Producers/Barley/Malting Barley']
# ❌ Column 'Prices/Local Paid to Producers/Barley/For Groats' not present in source_df.
# ✅ Filled 'Barley' in 0 rows using 'Prices/Local Paid to Producers/Barley/Other Varieties' from source_df.
# Year: 1931.
# df.columns: Index(['Prices/Local Paid to Producers/Barley/Malting Barley',
#        'Prices/Local Paid to Producers/Barley/Other Varieties',
#        'Prices/Local Paid to Producers/Buckwheat',
#        'Prices/Local Paid to Producers/Hay/Clover Hay',
#        'Prices/Local Paid to Producers/Hay/Meadow Hay',
#        'Prices/Local Paid to Producers/Oats',
#        'Prices/Local Paid to Producers/Peas',
#        'Prices/Local Paid to Producers/Potatoes/Edible',
#        'Prices/Local Paid to Producers/Potatoes/For Processing',
#        'Prices/Local Paid to Producers/Rye',
#        'Prices/Local Paid to Producers/Straw',
#        'Prices/Local Paid to Producers/Wheat'],
#       dtype='object', name='variable_name')
# columns_to_select: ['Prices/Local Paid to Producers/Wheat', 'Prices/Local Paid to Producers/Rye', 'Prices/Local Paid to Producers/Barley/All Types', 'Prices/Local Paid to Producers/Oats', 'Prices/Local Paid to Producers/Potatoes/All Types', 'Prices/Local Paid to Producers/Potatoes/Edible', 'Prices/Local Paid to Producers/Barley/Malting Barley']
# existing_columns: ['Prices/Local Paid to Producers/Wheat', 'Prices/Local Paid to Producers/Rye', 'Prices/Local Paid to Producers/Oats', 'Prices/Local Paid to Producers/Potatoes/Edible', 'Prices/Local Paid to Producers/Barley/Malting Barley']
# ❌ Column 'Prices/Local Paid to Producers/Barley/For Groats' not present in source_df.
# ✅ Filled 'Barley' in 0 rows using 'Prices/Local Paid to Producers/Barley/Other Varieties' from source_df.
# Year: 1932.
# df.columns: Index(['Prices/Local Paid to Producers/Barley/Malting Barley',
#        'Prices/Local Paid to Producers/Barley/Other Varieties',
#        'Prices/Local Paid to Producers/Buckwheat',
#        'Prices/Local Paid to Producers/Hay/Clover Hay',
#        'Prices/Local Paid to Producers/Hay/Meadow Hay',
#        'Prices/Local Paid to Producers/Oats',
#        'Prices/Local Paid to Producers/Peas',
#        'Prices/Local Paid to Producers/Potatoes/Edible',
#        'Prices/Local Paid to Producers/Potatoes/For Processing',
#        'Prices/Local Paid to Producers/Rye',
#        'Prices/Local Paid to Producers/Straw',
#        'Prices/Local Paid to Producers/Wheat'],
#       dtype='object', name='variable_name')
# columns_to_select: ['Prices/Local Paid to Producers/Wheat', 'Prices/Local Paid to Producers/Rye', 'Prices/Local Paid to Producers/Barley/All Types', 'Prices/Local Paid to Producers/Oats', 'Prices/Local Paid to Producers/Potatoes/All Types', 'Prices/Local Paid to Producers/Potatoes/Edible', 'Prices/Local Paid to Producers/Barley/Malting Barley']
# existing_columns: ['Prices/Local Paid to Producers/Wheat', 'Prices/Local Paid to Producers/Rye', 'Prices/Local Paid to Producers/Oats', 'Prices/Local Paid to Producers/Potatoes/Edible', 'Prices/Local Paid to Producers/Barley/Malting Barley']
# ❌ Column 'Prices/Local Paid to Producers/Barley/For Groats' not present in source_df.
# ✅ Filled 'Barley' in 0 rows using 'Prices/Local Paid to Producers/Barley/Other Varieties' from source_df.
# Year: 1934.
# df.columns: Index(['Prices/Local Paid to Producers/Barley/Malting Barley',
#        'Prices/Local Paid to Producers/Barley/Other Varieties',
#        'Prices/Local Paid to Producers/Buckwheat',
#        'Prices/Local Paid to Producers/Hay/Clover Hay',
#        'Prices/Local Paid to Producers/Hay/Meadow Hay',
#        'Prices/Local Paid to Producers/Oats',
#        'Prices/Local Paid to Producers/Peas',
#        'Prices/Local Paid to Producers/Potatoes/Edible',
#        'Prices/Local Paid to Producers/Potatoes/For Processing',
#        'Prices/Local Paid to Producers/Rye',
#        'Prices/Local Paid to Producers/Straw',
#        'Prices/Local Paid to Producers/Wheat'],
#       dtype='object', name='variable_name')
# columns_to_select: ['Prices/Local Paid to Producers/Wheat', 'Prices/Local Paid to Producers/Rye', 'Prices/Local Paid to Producers/Barley/All Types', 'Prices/Local Paid to Producers/Oats', 'Prices/Local Paid to Producers/Potatoes/All Types', 'Prices/Local Paid to Producers/Potatoes/Edible', 'Prices/Local Paid to Producers/Barley/Malting Barley']
# existing_columns: ['Prices/Local Paid to Producers/Wheat', 'Prices/Local Paid to Producers/Rye', 'Prices/Local Paid to Producers/Oats', 'Prices/Local Paid to Producers/Potatoes/Edible', 'Prices/Local Paid to Producers/Barley/Malting Barley']
# ❌ Column 'Prices/Local Paid to Producers/Barley/For Groats' not present in source_df.
# ✅ Filled 'Barley' in 41 rows using 'Prices/Local Paid to Producers/Barley/Other Varieties' from source_df.
# 📍 Filled indices:
# ['BIŁGORAJSKI', 'BRZOZOWSKI', 'CHORZÓW', 'CZARNKOWSKI', 'DOBROMILSKI', 'DOLIŃSKI', 'DROHOBYCKI', 'DZIŚNIEŃSKI', 'DĄBROWSKI', 'IWACEWICKI', 'JAWOROWSKI', 'KONECKI', 'KOSOWSKI (KOSÓW HUCULSKI)', 'KOSZYRSKI', 'KRAKÓW (MIASTO)', 'LESKI', 'LIDZKI', 'LUBOMELSKI', 'LWÓW (MIASTO)', 'M. ST. WARSZAWA', 'MOŁODECZAŃSKI', 'MYŚLENICKI', 'NIŻAŃSKI', 'NOWOGRÓDZKI', 'NOWOTARSKI', 'PIŃSKI', 'POZNAŃ (MIASTO)', 'ROHATYŃSKI', 'SAMBORSKI', 'SARNEŃSKI', 'STANISŁAWOWSKI', 'STOŁPECKI', 'TURCZAŃSKI', 'WADOWICKI', 'WILNO (MIASTO)', 'WOŁOŻYŃSKI', 'ŁUNINIECKI', 'ŁÓDŹ (MIASTO)', 'ŚWIĘCIAŃSKI', 'ŚWIĘTOCHŁOWICKI', 'ŻYWIECKI']
# Year: 1935.
# df.columns: Index(['Prices/Local Paid to Producers/Barley/For Groats',
#        'Prices/Local Paid to Producers/Barley/Malting Barley',
#        'Prices/Local Paid to Producers/Buckwheat',
#        'Prices/Local Paid to Producers/Hay/Clover Hay',
#        'Prices/Local Paid to Producers/Hay/Meadow Hay',
#        'Prices/Local Paid to Producers/Oats',
#        'Prices/Local Paid to Producers/Peas',
#        'Prices/Local Paid to Producers/Potatoes/Edible',
#        'Prices/Local Paid to Producers/Potatoes/For Processing',
#        'Prices/Local Paid to Producers/Rye',
#        'Prices/Local Paid to Producers/Straw',
#        'Prices/Local Paid to Producers/Wheat'],
#       dtype='object', name='variable_name')
# columns_to_select: ['Prices/Local Paid to Producers/Wheat', 'Prices/Local Paid to Producers/Rye', 'Prices/Local Paid to Producers/Barley/All Types', 'Prices/Local Paid to Producers/Oats', 'Prices/Local Paid to Producers/Potatoes/All Types', 'Prices/Local Paid to Producers/Potatoes/Edible', 'Prices/Local Paid to Producers/Barley/Malting Barley']
# existing_columns: ['Prices/Local Paid to Producers/Wheat', 'Prices/Local Paid to Producers/Rye', 'Prices/Local Paid to Producers/Oats', 'Prices/Local Paid to Producers/Potatoes/Edible', 'Prices/Local Paid to Producers/Barley/Malting Barley']
# ✅ Filled 'Barley' in 56 rows using 'Prices/Local Paid to Producers/Barley/For Groats' from source_df.
# 📍 Filled indices:
# ['BIAŁOSTOCKI', 'BIELSKO', 'BIŁGORAJSKI', 'BRZOZOWSKI', 'CHORZÓW', 'DOLIŃSKI', 'DROHICKI', 'DROHOBYCKI', 'GRÓDECKI', 'IWACEWICKI', 'KATOWICE', 'KOLBUSZOWSKI', 'KONECKI', 'KOSOWSKI (KOSÓW HUCULSKI)', 'KOSTOPOLSKI', 'KOSZYRSKI', 'KOZIENICKI', 'KOŁOMYJSKI', 'KRAKÓW (MIASTO)', 'LESKI', 'LUBOMELSKI', 'LWÓW (MIASTO)', 'M. ST. WARSZAWA', 'MIĘDZYCHODZKI', 'MIŃSKI', 'NIEŚWIESKI', 'NIŻAŃSKI', 'NOWOTARSKI', 'OPOCZYŃSKI', 'OSTROWSKI (OSTRÓW MAZOWIECKA)', 'OSZMIAŃSKI', 'PIŃSKI', 'POSTAWSKI', 'POZNAŃ (MIASTO)', 'PRZEMYŚLAŃSKI', 'RADZYMIŃSKI', 'ROHATYŃSKI', 'SANDOMIERSKI', 'SARNEŃSKI', 'SKIERNIEWICKI', 'STOLIŃSKI', 'STOŁPECKI', 'TURCZAŃSKI', 'WADOWICKI', 'WILNO (MIASTO)', 'WOŁOŻYŃSKI', 'WĘGROWSKI', 'ZBOROWSKI', 'ŁAŃCUCKI', 'ŁOMŻYŃSKI', 'ŁUNINIECKI', 'ŁÓDŹ (MIASTO)', 'ŚWIĘCIAŃSKI', 'ŚWIĘTOCHŁOWICKI', 'ŻYWIECKI', 'ŻÓŁKIEWSKI']
# ❌ Column 'Prices/Local Paid to Producers/Barley/Other Varieties' not present in source_df.
# Year: 1936.
# df.columns: Index(['Prices/Local Paid to Producers/Barley/For Groats',
#        'Prices/Local Paid to Producers/Barley/Malting Barley',
#        'Prices/Local Paid to Producers/Buckwheat',
#        'Prices/Local Paid to Producers/Hay/Clover Hay',
#        'Prices/Local Paid to Producers/Hay/Meadow Hay',
#        'Prices/Local Paid to Producers/Oats',
#        'Prices/Local Paid to Producers/Peas',
#        'Prices/Local Paid to Producers/Potatoes/Edible',
#        'Prices/Local Paid to Producers/Potatoes/For Processing',
#        'Prices/Local Paid to Producers/Rye',
#        'Prices/Local Paid to Producers/Straw',
#        'Prices/Local Paid to Producers/Wheat'],
#       dtype='object', name='variable_name')
# columns_to_select: ['Prices/Local Paid to Producers/Wheat', 'Prices/Local Paid to Producers/Rye', 'Prices/Local Paid to Producers/Barley/All Types', 'Prices/Local Paid to Producers/Oats', 'Prices/Local Paid to Producers/Potatoes/All Types', 'Prices/Local Paid to Producers/Potatoes/Edible', 'Prices/Local Paid to Producers/Barley/Malting Barley']
# existing_columns: ['Prices/Local Paid to Producers/Wheat', 'Prices/Local Paid to Producers/Rye', 'Prices/Local Paid to Producers/Oats', 'Prices/Local Paid to Producers/Potatoes/Edible', 'Prices/Local Paid to Producers/Barley/Malting Barley']
# ✅ Filled 'Barley' in 56 rows using 'Prices/Local Paid to Producers/Barley/For Groats' from source_df.
# 📍 Filled indices:
# ['BIAŁOSTOCKI', 'BIELSKO', 'BIŁGORAJSKI', 'BRZOZOWSKI', 'CHORZÓW', 'DOLIŃSKI', 'DROHICKI', 'DROHOBYCKI', 'GRÓDECKI', 'IWACEWICKI', 'KATOWICE', 'KOLBUSZOWSKI', 'KONECKI', 'KOSOWSKI (KOSÓW HUCULSKI)', 'KOSTOPOLSKI', 'KOSZYRSKI', 'KOZIENICKI', 'KOŁOMYJSKI', 'KRAKÓW (MIASTO)', 'LESKI', 'LUBOMELSKI', 'LWÓW (MIASTO)', 'M. ST. WARSZAWA', 'MIĘDZYCHODZKI', 'MIŃSKI', 'NIEŚWIESKI', 'NIŻAŃSKI', 'NOWOTARSKI', 'OPOCZYŃSKI', 'OSTROWSKI (OSTRÓW MAZOWIECKA)', 'OSZMIAŃSKI', 'PIŃSKI', 'POSTAWSKI', 'POZNAŃ (MIASTO)', 'PRZEMYŚLAŃSKI', 'RADZYMIŃSKI', 'ROHATYŃSKI', 'SANDOMIERSKI', 'SARNEŃSKI', 'SKIERNIEWICKI', 'STOLIŃSKI', 'STOŁPECKI', 'TURCZAŃSKI', 'WADOWICKI', 'WILNO (MIASTO)', 'WOŁOŻYŃSKI', 'WĘGROWSKI', 'ZBOROWSKI', 'ŁAŃCUCKI', 'ŁOMŻYŃSKI', 'ŁUNINIECKI', 'ŁÓDŹ (MIASTO)', 'ŚWIĘCIAŃSKI', 'ŚWIĘTOCHŁOWICKI', 'ŻYWIECKI', 'ŻÓŁKIEWSKI']
# ❌ Column 'Prices/Local Paid to Producers/Barley/Other Varieties' not present in source_df.

# %% [markdown]
# Load crops size data

# %%
# Load the crops size
columns_to_select = ['Wheat', 'Rye', 'Barley', 'Oats', 'Potatoes']
columns_to_select = ['Crops/Size/' + col for col in columns_to_select]
# Load the crops size
crops_size_data_table_ids = [
    data_table.data_table_id
    for data_table in adm_history_processor.processed_data_metadata.items
    if any(col in columns_to_select for col in data_table.columns.keys())
]
crops_size_dfs = [adm_history_api.load_data_table(data_table_id = crops_data_table_id, version = 'harmonized', custom_grouping=d_city_mapping, custom_grouping_method = 'sum') for crops_data_table_id in crops_size_data_table_ids]
crops_size_year_df = {extract_date_parts(metadata.date)[0]: df for df, metadata, date in crops_size_dfs}
crops_size_years = crops_size_year_df.keys()
crops_size_year_df_clean = copy.deepcopy(empty_year_df_dict)
for year, df in crops_size_year_df.items():
    print(f"Year: {year}")
    print(f"df.columns: {df.columns}")
    existing_columns = [col for col in columns_to_select if col in df.columns]
    df = df[existing_columns]
    df.columns = [col.split('/')[2].strip() for col in df.columns]
    crops_size_year_df_clean[year] = df
# Out:
# Year: 1924
# df.columns: Index(['Crops/Size/Barley', 'Crops/Size/Oats', 'Crops/Size/Potatoes',
#        'Crops/Size/Rye', 'Crops/Size/Wheat'],
#       dtype='object', name='variable_name')
# Year: 1926
# df.columns: Index(['Crops/Size/Barley', 'Crops/Size/Oats', 'Crops/Size/Potatoes',
#        'Crops/Size/Rye', 'Crops/Size/Wheat'],
#       dtype='object', name='variable_name')
# Year: 1928
# df.columns: Index(['Crops/Size/Barley', 'Crops/Size/Oats', 'Crops/Size/Potatoes',
#        'Crops/Size/Rye', 'Crops/Size/Sugar Beets', 'Crops/Size/Wheat'],
#       dtype='object', name='variable_name')
# Year: 1930
# df.columns: Index(['Crops/Size/Barley', 'Crops/Size/Oats', 'Crops/Size/Potatoes',
#        'Crops/Size/Rye', 'Crops/Size/Sugar Beets', 'Crops/Size/Wheat'],
#       dtype='object', name='variable_name')
# Year: 1931
# df.columns: Index(['Crops/Size/Barley', 'Crops/Size/Oats', 'Crops/Size/Potatoes',
#        'Crops/Size/Rye', 'Crops/Size/Sugar Beets', 'Crops/Size/Wheat'],
#       dtype='object', name='variable_name')
# Year: 1932
# df.columns: Index(['Crops/Size/Barley', 'Crops/Size/Beans, Broad Beans, and Lentils',
#        'Crops/Size/Buckwheat', 'Crops/Size/Flax/Fiber', 'Crops/Size/Flax/Seed',
#        'Crops/Size/Hemp/Seed', 'Crops/Size/Hops', 'Crops/Size/Maize',
#        'Crops/Size/Millet', 'Crops/Size/Mixtures for Grain/Barley',
#        'Crops/Size/Mixtures for Grain/Other mixtures', 'Crops/Size/Oats',
#        'Crops/Size/Peas', 'Crops/Size/Potatoes',
#        'Crops/Size/Rapeseed and Turnip Rape', 'Crops/Size/Rye',
#        'Crops/Size/Seed/Fiber', 'Crops/Size/Sugar Beets', 'Crops/Size/Tabacco',
#        'Crops/Size/Wheat'],
#       dtype='object', name='variable_name')
# Year: 1934
# df.columns: Index(['Crops/Size/Barley', 'Crops/Size/Millet', 'Crops/Size/Oats',
#        'Crops/Size/Potatoes', 'Crops/Size/Rye', 'Crops/Size/Sugar Beets',
#        'Crops/Size/Wheat'],
#       dtype='object', name='variable_name')
# Year: 1935
# df.columns: Index(['Crops/Size/Barley', 'Crops/Size/Oats', 'Crops/Size/Potatoes',
#        'Crops/Size/Rye', 'Crops/Size/Sugar Beets', 'Crops/Size/Wheat'],
#       dtype='object', name='variable_name')
# Year: 1936
# df.columns: Index(['Crops/Size/Barley', 'Crops/Size/Buckwheat', 'Crops/Size/Oats',
#        'Crops/Size/Potatoes', 'Crops/Size/Rye', 'Crops/Size/Wheat'],
#       dtype='object', name='variable_name')
# Year: 1938
# df.columns: Index(['Crops/Size/Barley', 'Crops/Size/Buckwheat', 'Crops/Size/Maize',
#        'Crops/Size/Millet', 'Crops/Size/Oats', 'Crops/Size/Potatoes',
#        'Crops/Size/Rye', 'Crops/Size/Sugar Beets', 'Crops/Size/Wheat'],
#       dtype='object', name='variable_name')

# %% [markdown]
# I load 5 main crops price index computed on the basis of data for all years by Wronski et al. (2025) on the basis of voivodship average prices for 5 main crops.

# %%
price_index_5_main_crops = {
    1924: 1.00,
    1925: 1.34,
    1926: 2.12,
    1927: 2.78,
    1928: 3.25,
    1929: 2.06,
    1930: 1.55,
    1931: 1.44,
    1932: 1.24,
    1933: 1.07,
    1934: 1.07,
    1935: 0.84,
    1936: 0.99,
    1937: 1.54,
    1938: 1.14
}

# %% [markdown]
# ### Interpolate the prices

# %%
for crop_name in ['Wheat', 'Rye', 'Barley', 'Oats', 'Potatoes']:
    crops_prices_year_df_clean = interpolate_missing_years(year_to_df=crops_prices_year_df_clean, col_name=crop_name,
                                all_years=all_years, empty_dist_df=empty_dist_df.copy(), extrapolate_trends = False)
crops_prices_years = all_years

# %% [markdown]
# ### Compute Crop Value of 5 main crops

# %%
crops_production_years = copy.deepcopy(empty_year_df_dict)

# Find years present in both datasets
common_years = sorted(set(crops_size_years) & set(crops_prices_years))

for year in common_years:
    yield_df = crops_size_year_df_clean[year]
    price_df = crops_prices_year_df_clean[year]

    # Ensure both dfs have the same columns (crops) and index
    if set(yield_df.columns) != set(price_df.columns):
        raise ValueError(f"Crop mismatch in year {year}:\nYield: {yield_df.columns}\nPrice: {price_df.columns}")
    if set(yield_df.index) != set(price_df.index):
        missing_in_price_df_index = set(yield_df.index) - set(price_df.index)
        missing_in_yield_df_index = set(price_df.index) - set(yield_df.index)
        raise ValueError(f"Index mismatch in year {year}:\nMissing in price df: {missing_in_price_df_index}.\nMissing in yield df: {missing_in_yield_df_index}.")

    # Compute total crop value for each crop
    result_df = yield_df*price_df
    # Compute the total value of the 5 main crops by summing across all crop columns
    result_df['5 Main Crops Value'] = result_df.sum(axis=1)

    crops_production_years[year] = result_df

# %% [markdown]
# ### Interpolate

# %%
crops_production_years = interpolate_missing_years(year_to_df=crops_production_years, col_name='5 Main Crops Value',
                               all_years=all_years, empty_dist_df=empty_dist_df.copy(), extrapolate_trends = False)

# %% [markdown]
# ### Add '5 Main Crops Value %' column

# %%
for year, df in crops_production_years.items():
    df['5 Main Crops Value Per Capita'] = df['5 Main Crops Value']/production_by_year[year]['Population']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\janek\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Population'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 2
#       1 for year, df in crops_production_years.items():
# ----> 2     df['5 Main Crops Value Per Capita'] = df['5 Main Crops Value']/production_by_year[year]['Population']
#
# File c:\Users\janek\miniconda3\Lib\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File c:\Users\janek\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Population'

# %% [markdown]
# Generate and save plots with 5 Main Crops total production value.

# %%
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/Agriculture/5_Crops_Value/",
#     year_df_dict = crops_production_years,
#     col_name = '5 Main Crops Value Per Capita',
#     title = '5 Main Crops Value Per Capita (Current Prices)',
#     export_excel = True,
#     cmap = 'Greens'
# )

# %% [markdown]
# ## Compute crops yields per ha

# %%
# Load the crops area
columns_to_select = ['Wheat', 'Rye', 'Barley', 'Oats', 'Potatoes']
columns_to_select = ['Crops/Area/' + col for col in columns_to_select]
crops_area_data_table_ids = [
    data_table.data_table_id
    for data_table in adm_history_processor.processed_data_metadata.items
    if any(col in columns_to_select for col in data_table.columns.keys())
]
crops_area_dfs = [adm_history_api.load_data_table(data_table_id = crops_data_table_id, version = 'harmonized', custom_grouping=d_city_mapping, custom_grouping_method = 'sum') for crops_data_table_id in crops_area_data_table_ids]
crops_area_year_df = {extract_date_parts(metadata.date)[0]: df for df, metadata, date in crops_area_dfs}
crops_area_years = crops_area_year_df.keys()
crops_area_year_df_clean = copy.deepcopy(empty_year_df_dict)
for year, df in crops_area_year_df.items():
    print(f"df.columns: {df.columns}")
    existing_columns = [col for col in columns_to_select if col in df.columns]
    df = df[existing_columns]
    df.columns = [col.split('/')[2].strip() for col in df.columns]
    crops_area_year_df_clean[year] = df
# Out:
# df.columns: Index(['Crops/Area/Barley', 'Crops/Area/Oats', 'Crops/Area/Potatoes',
#        'Crops/Area/Rye', 'Crops/Area/Wheat'],
#       dtype='object', name='variable_name')
# df.columns: Index(['Crops/Area/Barley', 'Crops/Area/Oats', 'Crops/Area/Potatoes',
#        'Crops/Area/Rye', 'Crops/Area/Wheat'],
#       dtype='object', name='variable_name')
# df.columns: Index(['Crops/Area/Barley', 'Crops/Area/Beans, Broad Beans, and Lentils',
#        'Crops/Area/Buckwheat',
#        'Crops/Area/Cereal Mixtures for Grain (Barley and Oats)',
#        'Crops/Area/Chicory', 'Crops/Area/Clover',
#        'Crops/Area/Field Pea, Vetch, and Faba Bean', 'Crops/Area/Flax',
#        'Crops/Area/Hemp', 'Crops/Area/Hops', 'Crops/Area/Lupin',
#        'Crops/Area/Maize', 'Crops/Area/Millet', 'Crops/Area/Oats',
#        'Crops/Area/Other Cereal Mixtures for Grain',
#        'Crops/Area/Other Fodder Crops and Mixtures', 'Crops/Area/Peas',
#        'Crops/Area/Potatoes', 'Crops/Area/Rye', 'Crops/Area/Serradella',
#        'Crops/Area/Sugar Beets', 'Crops/Area/Wheat',
#        'Crops/Area/Winter and Spring Rapeseed and Turnip Rape'],
#       dtype='object', name='variable_name')
# df.columns: Index(['Crops/Area/Barley', 'Crops/Area/Beans, Broad Beans, and Lentils',
#        'Crops/Area/Buckwheat', 'Crops/Area/Flax', 'Crops/Area/Hemp',
#        'Crops/Area/Hops', 'Crops/Area/Maize', 'Crops/Area/Millet',
#        'Crops/Area/Mixtures for Grain/Barley',
#        'Crops/Area/Mixtures for Grain/Other mixtures', 'Crops/Area/Oats',
#        'Crops/Area/Peas', 'Crops/Area/Potatoes',
#        'Crops/Area/Rapeseed and Turnip Rape', 'Crops/Area/Rye',
#        'Crops/Area/Sugar Beets', 'Crops/Area/Tabacco', 'Crops/Area/Wheat'],
#       dtype='object', name='variable_name')
# df.columns: Index(['Crops/Area/Barley', 'Crops/Area/Buckwheat', 'Crops/Area/Millet',
#        'Crops/Area/Oats', 'Crops/Area/Potatoes', 'Crops/Area/Rye',
#        'Crops/Area/Sugar Beets', 'Crops/Area/Wheat'],
#       dtype='object', name='variable_name')
# df.columns: Index(['Crops/Area/Barley', 'Crops/Area/Buckwheat', 'Crops/Area/Oats',
#        'Crops/Area/Potatoes', 'Crops/Area/Rye', 'Crops/Area/Sugar Beets',
#        'Crops/Area/Wheat'],
#       dtype='object', name='variable_name')
# df.columns: Index(['Crops/Area/Barley', 'Crops/Area/Buckwheat', 'Crops/Area/Maize',
#        'Crops/Area/Millet', 'Crops/Area/Oats', 'Crops/Area/Potatoes',
#        'Crops/Area/Rye', 'Crops/Area/Sugar Beets', 'Crops/Area/Wheat'],
#       dtype='object', name='variable_name')

# %%
for crop_name in ['Wheat', 'Rye', 'Barley', 'Oats', 'Potatoes']:
    crops_area_year_df_clean = interpolate_missing_years(year_to_df=crops_area_year_df_clean, col_name=crop_name,
                                all_years=all_years, empty_dist_df=empty_dist_df.copy(), extrapolate_trends = False)

crops_area_excel_path = r"E:\OneDrive\Studia\Studia magisterskie\Masterarbeit - Wirtschaftwissenschaft\Additional computations for the article\crops_area_interpolated_with_index.xlsx"
save_dict_of_dfs_to_excel(crops_area_year_df_clean, crops_area_excel_path)
# Out:
# ✅ Saved 15 DataFrames to 'E:\OneDrive\Studia\Studia magisterskie\Masterarbeit - Wirtschaftwissenschaft\Additional computations for the article\crops_area_interpolated_with_index.xlsx'

# %%
crops_area_year_df_clean[1926]
# Out:
#                                  Wheat           Rye       Barley  \
# District
# AUGUSTOWSKI                 660.000000  18720.000000  2800.000000
# BARANOWICKI                 793.152387  11388.101558  2839.681386
# BIALSKI (BIAŁA KRAKOWSKA)  1968.688649   6371.375053  2834.729115
# BIALSKI (BIAŁA PODLASKA)   3002.915980  32841.703499  5628.871480
# BIAŁOSTOCKI                1180.000000  29260.000000  4240.000000
# ...                                ...           ...          ...
# ŚWIĘTOCHŁOWICKI             196.872486   1476.543646    98.436243
# ŻNIŃSKI                    2476.262989  18898.512577  4254.029131
# ŻYDACZOWSKI                4041.914066   5389.218754  2326.281477
# ŻYWIECKI                   1022.327292   4698.243674  4843.672348
# ŻÓŁKIEWSKI                 6056.110976   8359.662390  3715.405507
#
#                                    Oats      Potatoes
# District
# AUGUSTOWSKI                10100.000000   7600.000000
# BARANOWICKI                 5581.442724   3720.961816
# BIALSKI (BIAŁA KRAKOWSKA)  11127.995510   6727.238670
# BIALSKI (BIAŁA PODLASKA)   14759.092194  17077.001038
# BIAŁOSTOCKI                15800.000000  11800.000000
# ...                                 ...           ...
# ŚWIĘTOCHŁOWICKI             1279.671160   1574.979890
# ŻNIŃSKI                     4025.451582   6986.108018
# ŻYDACZOWSKI                 6978.844430   5331.061717
# ŻYWIECKI                   13289.276867  11639.935401
# ŻÓŁKIEWSKI                  6316.189362   5944.648811
#
# [247 rows x 5 columns]

# %%
# Find years present in both datasets
common_yields_per_ha_years = sorted(set(crops_size_years) & set(crops_area_years))

for year in common_yields_per_ha_years:
    size_df = crops_size_year_df_clean[year]
    area_df = crops_area_year_df_clean[year]

    # Ensure both dfs have the same columns (crops) and index
    if set(size_df.columns) != set(area_df.columns):
        raise ValueError(f"Crop mismatch in year {year}:\nYield: {size_df.columns}\Area: {area_df.columns}")
    if set(size_df.index) != set(area_df.index):
        missing_in_area_df_index = set(size_df.index) - set(area_df.index)
        missing_in_yield_df_index = set(area_df.index) - set(size_df.index)
        raise ValueError(f"Index mismatch in year {year}:\nMissing in area df: {missing_in_area_df_index}.\nMissing in yield df: {missing_in_yield_df_index}.")

    # Compute total crop yield from ha, avoiding NaNs from 0 division
    with np.errstate(divide='ignore', invalid='ignore'):  # suppress warnings
        result_df = size_df.div(area_df).fillna(0)

    # Rename columns with suffix
    result_df = result_df.rename(columns={col: f"{col}_yields_per_ha" for col in yield_df.columns})

    # Add new columns to the existing df in crops_production_years without replacing it
    crops_production_years[year] = pd.concat([crops_production_years.get(year, pd.DataFrame()), result_df], axis=1)

# %% [markdown]
# ### Disaggregate regional 11 crop value added from Wroński et al. (2025)

# %% [markdown]
# Load regional data from Wronski et al. (2025)

# %%
region_total_crops_production = read_economic_csv_input(adm_level='Region', input_csv_path=region_total_crops_production_path)
region_agro_production_costs_per_ha = read_economic_csv_input(adm_level='Region', input_csv_path=region_agro_production_costs_path)
region_total_sown_area = read_economic_csv_input(adm_level='Region', input_csv_path=region_total_sown_area_path)

# %%
region_agro_production_costs = region_total_sown_area*region_agro_production_costs_per_ha
dist_area_data_table['Non-Forest Area'] = dist_area_data_table['Total District Area']-forests_data_table['Total Forest Area']

# %%
for year, dist_df in crops_production_years.items():
    dist_production_df = distribute_r_values_to_d(region_df=region_total_crops_production, region_value_col=str(year), dist_df=dist_df, dist_value_col = '5 Main Crops Value', new_col_name='Crops Production', d_to_r=d_to_r)
    dist_costs_df = distribute_r_values_to_d(region_df=region_agro_production_costs, region_value_col=str(year), dist_df=dist_area_data_table, dist_value_col = 'Non-Forest Area', new_col_name='Production Costs', d_to_r=d_to_r)
    production_by_year[year]['Crops Value Added'] = dist_production_df['Crops Production']-dist_costs_df['Production Costs']

# %% [markdown]
# ### Plot prices

# %%
# Plot VA constant prices
plot_year_df_columns(
    administrative_history=administrative_history,
    custom_dist_grouping=d_city_mapping,
    plots_output_path=plots_output_path,
    path_suffix = "/Agriculture/Prices/Wheat/",
    year_df_dict = crops_prices_year_df_clean,
    col_name = 'Pszenica',
    title = 'Local Wheat Producer Price (current złoty)',
    export_excel = True,
    cmap = 'Oranges'
)

# %%
# Plot VA constant prices
plot_year_df_columns(
    administrative_history=administrative_history,
    custom_dist_grouping=d_city_mapping,
    plots_output_path=plots_output_path,
    path_suffix = "/Agriculture/Prices/Oats/",
    year_df_dict = crops_prices_year_df_clean,
    col_name = 'Owies',
    title = 'Local Oats Producer Price (current złoty)',
    export_excel = True,
    cmap = 'Oranges'
)

# %%
# Plot VA constant prices
plot_year_df_columns(
    administrative_history=administrative_history,
    custom_dist_grouping=d_city_mapping,
    plots_output_path=plots_output_path,
    path_suffix = "/Agriculture/Prices/Barley/",
    year_df_dict = crops_prices_year_df_clean,
    col_name = 'Jęczmień',
    title = 'Local Barley Producer Price (current złoty)',
    export_excel = True,
    cmap = 'Oranges'
)

# %%
# Plot VA constant prices
plot_year_df_columns(
    administrative_history=administrative_history,
    custom_dist_grouping=d_city_mapping,
    plots_output_path=plots_output_path,
    path_suffix = "/Agriculture/Prices/Potatoes/",
    year_df_dict = crops_prices_year_df_clean,
    col_name = 'Ziemniaki',
    title = 'Local Potatoes Producer Price (current złoty)',
    export_excel = True,
    cmap = 'Oranges'
)

# %%
# Plot VA constant prices
plot_year_df_columns(
    administrative_history=administrative_history,
    custom_dist_grouping=d_city_mapping,
    plots_output_path=plots_output_path,
    path_suffix = "/Agriculture/Prices/Rye/",
    year_df_dict = crops_prices_year_df_clean,
    col_name = 'Żyto',
    title = 'Local Rye Producer Price (current złoty)',
    export_excel = True,
    cmap = 'Oranges'
)

# %% [markdown]
# ## Livestock

# %% [markdown]
# ### Load Livestock data

# %%
# Load industry_permissions datasets
livestock_data_table_ids = [data_table.data_table_id for data_table in adm_history_processor.processed_data_metadata.items if data_table.category.eng=='Livestock']
livestock_dfs = [adm_history_api.load_data_table(data_table_id = livestock_data_table_id, version = 'harmonized', custom_grouping=d_city_mapping, custom_grouping_method = 'sum') for livestock_data_table_id in livestock_data_table_ids]
livestock_year_df_dict = {extract_date_parts(metadata.date)[0]: df for df, metadata, date in livestock_dfs}
# Add Livestock_Units column
for year, df in livestock_year_df_dict.items():
    horse_units = df['Konie: Together']
    cow_units = df['Bydło rogate: Together']
    pig_units = df['Trzoda chlewna: Together'] / 4

    if 'Owce i kozy: Together' in df.columns:
        sheep_goat_units = df['Owce i kozy: Together'] / 10
        livestock_units = horse_units + cow_units + pig_units + sheep_goat_units
    else:
        df['Owce i kozy: Together'] = df.get('Kozy: Together', 0) + df.get('Owce: Together', 0)
        goat_units = df.get('Kozy: Together', 0) / 10
        sheep_units = df.get('Owce: Together', 0) / 10
        livestock_units = horse_units + cow_units + pig_units + goat_units + sheep_units

    df['Livestock_Units'] = livestock_units

# %%
livestock_year_df_dict = interpolate_missing_years(year_to_df=livestock_year_df_dict, col_name='Livestock_Units',
                               all_years = all_years, empty_dist_df=empty_dist_df.copy(), extrapolate_trends = False)
livestock_year_df_dict = interpolate_missing_years(year_to_df=livestock_year_df_dict, col_name='Konie: Together',
                               all_years = all_years, empty_dist_df=empty_dist_df.copy(), extrapolate_trends = False)
livestock_year_df_dict = interpolate_missing_years(year_to_df=livestock_year_df_dict, col_name='Bydło rogate: Together',
                               all_years = all_years, empty_dist_df=empty_dist_df.copy(), extrapolate_trends = False)
livestock_year_df_dict = interpolate_missing_years(year_to_df=livestock_year_df_dict, col_name='Trzoda chlewna: Together',
                               all_years = all_years, empty_dist_df=empty_dist_df.copy(), extrapolate_trends = False)
livestock_year_df_dict = interpolate_missing_years(year_to_df=livestock_year_df_dict, col_name='Owce i kozy: Together',
                               all_years = all_years, empty_dist_df=empty_dist_df.copy(), extrapolate_trends = False)

# %%
for year, df in livestock_year_df_dict.items():
    df['Livestock_Units_per_capita'] = df['Livestock_Units']/production_by_year[year]['Population']
    df['Horses_per_capita'] = df['Konie: Together']/production_by_year[year]['Population']

# %% [markdown]
# Generate and save plots with total livestock units.

# %%
plot_year_df_columns(
    administrative_history=administrative_history,
    custom_dist_grouping=d_city_mapping,
    plots_output_path=plots_output_path,
    path_suffix = "/Agriculture/Livestock_Units/",
    year_df_dict = livestock_year_df_dict,
    col_name = 'Livestock_Units',
    title = 'Livestock Units',
    export_excel = True,
    legend_min = 0,
    legend_max = 250000
)

# %%
plot_year_df_columns(
    administrative_history=administrative_history,
    custom_dist_grouping=d_city_mapping,
    plots_output_path=plots_output_path,
    path_suffix = "/Agriculture/Livestock_Units_per_capita/",
    year_df_dict = livestock_year_df_dict,
    col_name = 'Livestock_Units_per_capita',
    title = 'Livestock Units (Per Capita)',
    export_excel = True
)

# %% [markdown]
# ### Compute Livestock Value Added

# %% [markdown]
# I use the same method as Wronsky et al. (2025) to disaggregate the total animal production, but on on the region, but on the district level.
# I rely on the estimates of a renown Polish agricultural economist Ponikowski who estimated that the animal production in 1928 amounted to 59,07% of the crops production.
# I further rely on the estimation of another agricultural economist Dederko who assumed the production value of animals be roughly proportional to the formula:
# 1 horse = 1 cow = 4 pigs = 10 sheep = 10 goats. I compute the number of 'livestock units' for every district this way.
#
# For year n, I use the total crops production in 1928 deflated by average yearly average crop prices index computed by Wronski et al. (2025). I disaggregate this value by the proportion of the livestock units in district d in year n to the total number of livestock units in year 1928.

# %%
# Crop price index in relation to 1928 computed by Wronski et al. (2025).
crop_price_index = {'1924': 0.3059, '1925': 0.4096, '1926': 0.6479, '1927': 0.8540, '1928': 1.0000, '1929': 0.6398, '1930': 0.4818, '1931': 0.4640, '1932': 0.3971, '1933': 0.3377, '1934': 0.3425, '1935': 0.2745, '1936': 0.3244, '1937': 0.5056, '1938': 0.3779}
total_crops_production_1928 = 11205070843

total_livestock_units_1928 = sum(livestock_year_df_dict[1928]['Livestock_Units'])
for year, df in livestock_year_df_dict.items():
    production_by_year[year]['Livestock Value Added'] = (df['Livestock_Units']/total_livestock_units_1928)*total_crops_production_1928*crop_price_index[str(year)]

# %%
plot_convergence(
    year_df_dict=production_by_year,
    values_column='Livestock Value Added',
    color_by_district=True,
    d_to_group=d_to_r_group,
    group_to_color=r_group_to_color,
    path_suffix = "/Agriculture/Livestock_Units/"
    )

# %% [markdown]
# ## Sea Fishing

# %% [markdown]
# ### Sea Fishing Value Added

# %% [markdown]
# The values for sea fishing were provided by GUS from 1931 on. All the values are allocated to the district 'MORSKI'. The values for years 1924-1930 is the value from 1931 extrapolated by Wronski et al. (2025) based on the Pomorskie voivodship value of 5 main crops production in the given year in relation to its value of 5 main crops production in year 1931. Voivosdhip Pomorskie was the only on that had access to the sea.
#
# Inland fishing was added by Ponikowski within his estimations of the Livestock production and it's why I don't add it here.

# %%
# Values published by GUS (1931-1938) and extrapolated by Wronski et al. (2025) (1924-1930).
sea_fishing_value = {
    1924: 2_747_607.0,
    1925: 4_081_133.0,
    1926: 5_014_687.0,
    1927: 8_833_781.0,
    1928: 10_921_172.0,
    1929: 7_844_862.0,
    1930: 6_542_626.0,
    1931: 2_393_700.0,
    1932: 2_559_700.0,
    1933: 4_589_400.0,
    1934: 3_991_980.0,
    1935: 3_431_700.0,
    1936: 3_986_000.0,
    1937: 5_127_300.0,
    1938: 7_181_700.0
    }

# %%
sea_fishing_df = empty_dist_df.copy()
sea_fishing_df['Sea Fishing'] = 0
for year in all_years:
    sea_fishing_year = sea_fishing_df.copy()
    sea_fishing_year.loc['MORSKI', 'Sea Fishing'] = sea_fishing_value[year]
    production_by_year[year]['Sea Fishing Value Added'] = sea_fishing_year['Sea Fishing']

# %% [markdown]
# ## Horticulture

# %% [markdown]
# ### Horticulture Value Added

# %% [markdown]
# I follow Wronski et al. (2025) and take 6.87% (Ponikowski's estimate for total horticulture production in 1928 in proportion to his estimate of the total crops production in 1928), and assume that horticulture amounts to additional 6.87% of crops production to every district's crops in a given year.

# %%
horticulture_df = empty_dist_df.copy()
horticulture_year_df_dict = {}
for year in crops_production_years.keys():
    production_by_year[year]['Horticulture Value Added'] = production_by_year[year]['Crops Value Added']*0.0687

# %% [markdown]
# ## Remaining crops

# %% [markdown]
# Statistics on other types of crops apart from the 11 main crops were not systematically collected by GUS. I take Bukowski et al. (2025) regional estimates of the yearly value of the 11 crops and disaggregate them with the 5 main crops value.

# %%
regions_remaining_crops_production = read_economic_csv_input(adm_level='Region', input_csv_path=regions_remaining_crops_production_path)

# %%
for year, dist_df in crops_production_years.items():
    dist_va_df = distribute_r_values_to_d(region_df=regions_remaining_crops_production, region_value_col=str(year), dist_df=dist_df, dist_value_col='5 Main Crops Value', new_col_name='Remaining Crops Value Added', d_to_r=d_to_r)
    production_by_year[year]['Remaining Crops Value Added'] = dist_va_df['Remaining Crops Value Added']

# %%
plot_year_df_columns(
    administrative_history=administrative_history,
    custom_dist_grouping=d_city_mapping,
    plots_output_path=plots_output_path,
    path_suffix = "/Agriculture/Remaining_Crops/",
    year_df_dict = production_by_year,
    col_name = 'Remaining Crops Value Added',
    title = 'Remaining Crops VA',
    export_excel = True
)

# %% [markdown]
# ## Final agriculture production estimation

# %%
for year in all_years:
    print(list(production_by_year[year].columns))

# %%
# Compute final aggricultural production
for year in all_years:
    production_by_year[year]['Agriculture VA'] = production_by_year[year]['Crops Value Added'] + production_by_year[year]['Livestock Value Added'] + production_by_year[year]['Forest Value Added'] + production_by_year[year]['Sea Fishing Value Added'] + production_by_year[year]['Horticulture Value Added']
    production_by_year[year]['Agriculture VA Per Capita'] = production_by_year[year]['Agriculture VA']/production_by_year[year]['Population']

# %% [markdown]
# # Industry

# %% [markdown]
# ## Load industry datasets

# %%
# Load industry_permissions datasets
industry_permissions_data_table_ids = [data_table.data_table_id for data_table in adm_history_processor.processed_data_metadata.items if data_table.category.eng=='Industry Permissions']
industry_permissions_dfs = [adm_history_api.load_data_table(data_table_id = industry_permissions_data_table_id, version = 'harmonized', custom_grouping=d_city_mapping, custom_grouping_method = 'sum') for industry_permissions_data_table_id in industry_permissions_data_table_ids]
industry_permissions_year_df = {extract_date_parts(metadata.date)[0]: df for df, metadata, date in industry_permissions_dfs}
# Strip numbers from the beginning of the 1935 column names
industry_permissions_year_df[1935].columns = [re.sub(r'^\d+\.\s*', '', col) for col in industry_permissions_year_df[1935].columns]
# Strip ": Together" from column names
for year, df in industry_permissions_year_df.items():
    df.columns = df.columns.str.replace(": Together", "", regex=False)
    print(df.columns)

# %%
industry_permissions_year_df[1928].loc['BIELSKO']

# %% [markdown]
# ### Plot the 1935 industry dataset

# %%
# plot_df_columns_and_export_excel(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/Industry/1935/num_workers/true_total/",
#     df = industry_permissions_year_df[1935],
#     col_title_prefix = "",
#     cmap = 'Blues',
#     export_excel = True,
#     columns_subset = ['Number of workers in plants I-VII']
# )

# plot_df_columns_and_export_excel(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/Industry/1935/num_plants/",
#     df = industry_permissions_year_df[1935],
#     col_title_prefix = "Number of Plants",
#     cmap = 'OrRd',
#     export_excel = True,
#     columns_subset = [col for col in industry_permissions_year_df[1935].columns if col != 'Number of workers in plants I-VII']
# )

# %% [markdown]
# ## 1924, 1925 and 1928 data preparation

# %% [markdown]
# ### Compute number of workers per district for years 1924, 1925 and 1928.

# %%
# Industry size per category used in the estimations of Wronski et al. (2025)
industry_size_cat = {
    "I": 1250,
    "II": 750.5,
    "III": 350.5,
    "IV": 113.5,
    "V": 19,
    "VI": 8,
    "VII": 6,
    "VIII": 2.5
    }

big_industry_size_cat = {
    "I": 1250,
    "II": 750.5,
    "III": 350.5,
    "IV": 113.5,
    "V": 19,
    "VI": 0,
    "VII": 0,
    "VIII": 0
    }

I_VII_industry_size_cat = {
    "I": 1250,
    "II": 750.5,
    "III": 350.5,
    "IV": 113.5,
    "V": 19,
    "VI": 8,
    "VII": 6,
    "VIII": 0 # Set 0 here
}

r_pr_to_num = {"R": 1, "PR": 0.5}

# %%
import re

def parse_kategoria_column(col_name: str):
    match = re.match(r"Kategoria\s+([IVXLCDM]+)(P?R)", col_name.strip())
    if match:
        roman, suffix = match.groups()
        return roman, suffix
    return None

def add_total_employment_column(df: pd.DataFrame, cat_to_size, col_name) -> pd.DataFrame:
    df = df.copy()
    total_series = pd.Series(0.0, index=df.index)

    for col in df.columns:
        parsed = parse_kategoria_column(col)
        if parsed:
            roman, suffix = parsed
            if roman in cat_to_size and suffix in r_pr_to_num:
                # Add to total weight column
                weight = cat_to_size[roman] * r_pr_to_num[suffix]
                total_series += df[col].astype(float) * weight
                
            else:
                raise KeyError(f"Missing weight for category: {roman}, {suffix}")
    
    df[col_name] = total_series
    return df

# %%
total_employment = {}
for year in [1924, 1925, 1928]:
    total_employment[year] = add_total_employment_column(industry_permissions_year_df[year], I_VII_industry_size_cat, "Total Employment I-VII")
    total_employment[year] = add_total_employment_column(total_employment[year], big_industry_size_cat, "Total Employment I-V")
    total_employment[year] = total_employment[year][["Total Employment I-VII", "Total Employment I-V"]]

# %% [markdown]
# ### Impute missing 1924 Silesia information (assume same intra-regional proportions as in 1925)

# %%
silesia_indices = [dist for dist in all_districts if d_to_r[dist]=='ŚLĄSKIE']

# %%
total_employment[1924].loc[silesia_indices]

# %%
total_employment = fill_zero_values_by_proportional_scaling(year_to_df=total_employment, col_name="Total Employment I-VII", only_fill_indices=silesia_indices)

# %% [markdown]
# ## 1931 Census data preparation

# %% [markdown]
# ### Load total number of employed in industry from 1931 census

# %%
# Load industry_permissions datasets
census_1931_occupations_df, census_1931_occupations_metadata, census_1931_occupations_date = adm_history_api.load_data_table(data_table_id = '1931_occupation_ready_clean', version = 'harmonized', custom_grouping=d_city_mapping, custom_grouping_method = 'sum')

# Store total employment estimations
total_employment[1931] = empty_dist_df.copy()
total_employment[1931]["Total Employment I-V"] = census_1931_occupations_df["1-2 Industrial plants: Categories I-V - all: Together"]
total_employment[1931]["Total Employment I-VII"] = census_1931_occupations_df["1-2 Industrial plants: Categories I-V - all: Together"] + census_1931_occupations_df["1-2 Industrial plants: Categories VI-VII - all: Together"]

# %% [markdown]
# ## 1935 data preparation

# %% [markdown]
# ### Compute regional total number of workers per district per industry category for year 1935

# %%
# Load data table with regional workers number
regional_workers_num, regional_workers_num_metadata, _ = adm_history_api.load_data_table(data_table_id = "regions_1935_total_num_workers", version = 'harmonized', custom_grouping=warsaw_region_grouping, custom_grouping_method = 'sum')
regional_workers_num.columns = regional_workers_num.columns.str.replace(": Together", "", regex=False)

# %%
# Load data table with regional workers share per industry type and size
regional_workers_share, regional_workers_share_metadata, _ = adm_history_api.load_data_table(data_table_id = "regions_1935_share_workers_by_enterprise_type_size", version = 'harmonized', custom_grouping=warsaw_region_grouping, custom_grouping_method = 'sum')
regional_workers_share.columns

# %%
# The regional_workers_share dataframe must be initially cleaned - sum up columns with I-III and IV-V endings
# Sum up I-III and IV-V share categories

def sum_industry_categories(df: pd.DataFrame) -> pd.DataFrame:
    result = pd.DataFrame(index=df.index)

    # Track handled industries
    processed_industries = set()

    for col in df.columns:
        if ": I-III" in col:
            base = col.split(":")[0].strip()
            col_iv_v = f"{base}: IV-V"
            col_i_iii = col
            cols_to_sum = [df[col_i_iii]]
            if col_iv_v in df.columns:
                cols_to_sum.append(df[col_iv_v])
            result[f"{base}: I-V"] = sum(cols_to_sum)
            processed_industries.add(col_i_iii)
            processed_industries.add(col_iv_v)
        elif ": VI-VII" in col:
            result[col] = df[col]
            processed_industries.add(col)

    # Add any columns that were not matched above (e.g. if IV-V exists but I-III doesn’t)
    for col in df.columns:
        if col not in processed_industries:
            result[col] = df[col]

    return result

# Use:
regional_workers_share = sum_industry_categories(regional_workers_share)

# %%
regional_workers_share

# %%
# Use two above dataframes to compute number of workers by plant size in each REGION
def compute_workers_by_plant_size(share_df: pd.DataFrame, num_df: pd.DataFrame) -> pd.DataFrame:
    results = pd.DataFrame(index=share_df.index)

    # Regular industry mapping (1:1 correspondence)
    industry_list = [
        'Mining', 'Mineral', 'Chemical', 'Textile', 'Paper', 'Leather',
        'Wood', 'Food', 'Clothing and Toymaking', 'Printing',
        'Construction', 'Power plants and waterworks'
    ]

    for industry in industry_list:
        if industry not in num_df.columns:
            print(f"Warning: '{industry}' not found in worker numbers. Skipping.")
            continue

        total_workers = num_df[industry]

        col_iv = f"{industry}: I-V"
        col_vivii = f"{industry}: VI-VII"

        results[f"{industry}: I-V"] = share_df.get(col_iv, 0) * total_workers
        results[f"{industry}: VI-VII"] = share_df.get(col_vivii, 0) * total_workers

    # Special case: "Metal and electrotechnical"
    industry = "Metal and electrotechnical"
    if industry in num_df.columns:
        total_workers = num_df[industry]

        # Average shares from "Metal" and "Electrotechnical"
        metal_iv = share_df.get("Metal: I-V", 0)
        elec_iv = share_df.get("Electrotechnical: I-V", 0)
        avg_iv = (metal_iv + elec_iv) / 2

        metal_vivii = share_df.get("Metal: VI-VII", 0)
        elec_vivii = share_df.get("Electrotechnical: VI-VII", 0)
        avg_vivii = (metal_vivii + elec_vivii) / 2

        results[f"{industry}: I-V"] = avg_iv * total_workers
        results[f"{industry}: VI-VII"] = avg_vivii * total_workers
    else:
        print("Warning: 'Metal and electrotechnical' not found in worker numbers.")

    return results

workers_by_industry_type_and_size = compute_workers_by_plant_size(share_df=regional_workers_share, num_df = regional_workers_num)

# %%
workers_by_industry_type_and_size

# %%
# Some initial cleaning of the workers_by_industry_type_and_size df to adjust its column names to the industry_permissions_year_df[1935] column names.
rename_map = {
    'Power plants and waterworks: I-V': 'Power plants: I-V',
    'Power plants and waterworks: VI-VII': 'Power plants: VI-VII',
    'Clothing and Toymaking: I-V': 'Clothing: I-V',
    'Clothing and Toymaking: VI-VII': 'Clothing: VI-VII'
}

workers_by_industry_type_and_size.rename(columns=rename_map, inplace=True)

# %%
plants_by_main_industry_type = industry_permissions_year_df[1935][['Number of workers in plants I-VII'] + list(workers_by_industry_type_and_size.columns)]

# %%
plants_by_main_industry_type.columns

# %% [markdown]
# ### Estimate the total number of workers per industry category and size for each DISTRICT for year 1935

# %% [markdown]
# For every district we have the information about the total number of workers in the district and the regional total of workers in each industry category for plants of sizes I-V and VI-VII (technically speaking, we have both marginal distributions).
# I use the data to estimate the number of workers in each category through a procedure called Iterative Proportional Fitting:
#   - I start with estimates for every district industry type and size equal to the regional average number of workers in the industry type and size times the number of industrial permissions in the category.
#   - I repeatedly perform the following step until the program converges:
#     - I scale the district total sum of workers to fit the known total
#     - I scale the regional total sum of workers for industry category-size to fit the known total for this category-size

# %%
def estimate_workers_by_industry(plants_by_main_industry_type, workers_by_industry_type_and_size, d_to_r, max_iter=100, tol=1e-5):
    # Identify industry columns (exclude total)
    industry_cols = [col for col in plants_by_main_industry_type.columns if col != 'Number of workers in plants I-VII']

    # Add Region info to plant data
    worker_estimations = plants_by_main_industry_type.copy()
    worker_estimations['Region'] = worker_estimations.index.map(d_to_r)

    results = []

    for region in workers_by_industry_type_and_size.index:
        region_df = worker_estimations[worker_estimations['Region'] == region]
        district_names = region_df.index

        # Get margins
        district_totals = region_df['Number of workers in plants I-VII'].values  # (n_districts,)
        industry_totals = workers_by_industry_type_and_size.loc[region, industry_cols].values  # (n_categories,)

        # Raw counts of plants
        plant_counts = region_df[industry_cols].values  # (n_districts, n_categories)

        # Create a mask of valid cells (i.e. where number of plants > 0)
        mask = plant_counts > 0

        # Avoid division by zero when calculating shares
        row_sums = plant_counts.sum(axis=1, keepdims=True)
        row_sums[row_sums == 0] = 1  # prevent division by zero

        shares = np.where(mask, plant_counts / row_sums, 0)

        # Initialize estimate
        estimate = shares * industry_totals

        for i in range(max_iter):
            prev_estimate = estimate.copy()

            # Row normalization (district totals)
            row_sums = estimate.sum(axis=1)
            row_scaling = np.divide(
                district_totals, row_sums, out=np.ones_like(district_totals), where=row_sums != 0
            )
            estimate = estimate * row_scaling[:, np.newaxis]

            # Column normalization (industry totals)
            col_sums = estimate.sum(axis=0)
            col_scaling = np.divide(
                industry_totals, col_sums, out=np.ones_like(industry_totals), where=col_sums != 0
            )
            estimate = estimate * col_scaling

            # Mask out cells that should remain zero
            estimate = np.where(mask, estimate, 0)

            # Check convergence
            if np.allclose(estimate, prev_estimate, atol=tol):
                break
        
        # Final row normalization to match district totals **exactly**
        row_sums = estimate.sum(axis=1)
        row_scaling = np.divide(
            district_totals, row_sums, out=np.ones_like(district_totals), where=row_sums != 0
        )
        estimate = estimate * row_scaling[:, np.newaxis]
        estimate = np.where(mask, estimate, 0)

        # Save result as DataFrame
        estimate_df = pd.DataFrame(estimate, index=district_names, columns=industry_cols)
        results.append(estimate_df)

    final_estimates = pd.concat(results)
    final_estimates['Estimates: Number of workers in plants I-VII'] = final_estimates[industry_cols].sum(axis=1)
    final_estimates['Number of workers in plants I-VII'] = plants_by_main_industry_type['Number of workers in plants I-VII']
    return final_estimates

# %%
worker_estimates = estimate_workers_by_industry(plants_by_main_industry_type, workers_by_industry_type_and_size, d_to_r, max_iter=100, tol=1e-5)
worker_estimates.loc['AUGUSTOWSKI']

# %%
# plot_df_columns_and_export_excel(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/Industry/1935/num_workers/estimated_by_industry_cat/total/",
#     df = worker_estimates,
#     col_title_prefix = "",
#     cmap = 'Blues',
#     export_excel = True,
#     columns_subset = [col for col in worker_estimates.columns if col != 'Number of workers in plants I-VII']
# )

# %%
worker_estimates_per_capita = worker_estimates.div(production_by_year[year]['Population'], axis=0)
worker_estimates_per_capita.rename(columns = {col: f"{col} (Per Capita)" for col in worker_estimates.columns}, inplace = True)

# %%
plot_df_columns_and_export_excel(
    administrative_history=administrative_history,
    custom_dist_grouping=d_city_mapping,
    plots_output_path=plots_output_path,
    path_suffix = "/Industry/1935/num_workers/estimated_by_industry_cat/per_capita/",
    df = worker_estimates_per_capita,
    col_title_prefix = "",
    cmap = 'Blues',
    export_excel = True,
    columns_subset = [col for col in worker_estimates_per_capita.columns if col != 'Number of workers in plants I-VII']
)

# %%
total_employment[1935] = empty_dist_df.copy()
total_employment[1935]["Total Employment I-VII"] = worker_estimates['Number of workers in plants I-VII']

# %% [markdown]
# ## Esimate employment for missing years between 1924 and 1936.

# %%
total_employment = interpolate_missing_years(year_to_df=total_employment, col_name="Total Employment I-VII",
                               all_years=all_years, empty_dist_df=empty_dist_df.copy(), extrapolate_trends = False)

# %% [markdown]
# ## Plot employment data

# %%
for year in total_employment.keys():
    total_employment[year]["Total Employment I-VII (Per Capita)"] = total_employment[year]["Total Employment I-VII"]/production_by_year[year]['Population']
    total_employment[year]["Log of Total Employment I-VII"] = np.log(total_employment[year]["Total Employment I-VII"])
    total_employment[year]["Log of Total Employment I-VII (Per Capita)"] = np.log(total_employment[year]["Total Employment I-VII (Per Capita)"])

# %%
# # Plot total employment
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/Industry/num_workers/",
#     year_df_dict = total_employment,
#     col_name = "Log of Total Employment I-VII",
#     title = 'Logarithm of Total Industry Employment Estimate',
#     cmap = 'Blues',
#     legend_min=5.0,
#     legend_max=11.5,
#     export_excel = True
# )

# %%
# # Plot total employment Per Capita
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/Industry/num_workers_per_capita/",
#     year_df_dict = total_employment,
#     col_name = "Log of Total Employment I-VII (Per Capita)",
#     title = 'Logarithm of Industry Employment Per Capita Estimate',
#     cmap = 'Blues',
#     legend_min=-7.5,
#     legend_max=-0.8,
#     export_excel = True
# )

# %% [markdown]
# ## Average District Wage Computation

# %% [markdown]
# ### Load average wage and number of worked hours per industry data

# %% [markdown]
# I estimate the average wage in every district for years 1921-1938 by assuming that the proportion of workers in different industry branches remains constant. I compute the weighted national average of wage in year n (weight is the district proportion of the number of workers in every one of the 13 categories).

# %%
hourly_wage_by_industry = pd.read_csv(hourly_wage_by_industry_path, sep=";", decimal=",")
hourly_wage_by_industry.set_index("Industry Sector", inplace=True)
hourly_wage_by_industry = hourly_wage_by_industry[[str(year) for year in range(1924, 1939)]]
hourly_wage_by_industry

# %%
hours_per_employee = pd.read_csv(hours_per_employee_path, sep=";", decimal=",")
hours_per_employee.set_index("Industry Sector", inplace=True)
hours_per_employee = hours_per_employee[[str(year) for year in range(1924, 1939)]]
hours_per_employee

# %% [markdown]
# ### Compute national average yearly wage per sector

# %%
yearly_wage_by_industry = hours_per_employee*hourly_wage_by_industry

# %% [markdown]
# ### Estimate district industry shares

# %%
# Create a list of industry types
industry_types = [column.split(":")[0] for column in set(worker_estimates.columns)-{'Estimates: Number of workers in plants I-VII', 'Number of workers in plants I-VII'} if column.split(":")[1] == " I-V"]

# Create a df with industry_types_worker_estimates
industry_types_worker_estimates = empty_dist_df.copy()

# Sum the two columns for each industry type
for ind_type in industry_types:
    col_iv = f"{ind_type}: I-V"
    col_vi = f"{ind_type}: VI-VII"
    industry_types_worker_estimates[ind_type] = worker_estimates[col_iv] + worker_estimates[col_vi]

# %%
industry_dist_shares_1935 = industry_types_worker_estimates.div(
    industry_types_worker_estimates.sum(axis=1), axis=0
)
industry_dist_shares_1935

# %% [markdown]
# ### Compute average district hourly wage

# %%
average_hourly_wage_year = {}

# Ensure alignment between industry sectors and column names
hourly_wage_by_industry = hourly_wage_by_industry.loc[industry_dist_shares_1935.columns]

for year in hourly_wage_by_industry.columns:
    # Get wage vector for this year (aligned with industry sectors)
    wages = hourly_wage_by_industry[year]  # Series: index = industry sectors

    # Compute weighted average wage per district
    weighted_avg = industry_dist_shares_1935.dot(wages)

    # Store in dictionary (as a DataFrame to keep it consistent)
    average_hourly_wage_year[int(year)] = pd.DataFrame({
        'Average Wage': weighted_avg
    })

# %%
# # Plot district hourly wages
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/Industry/Wages/hourly/",
#     year_df_dict = average_hourly_wage_year,
#     col_name = 'Average Wage',
#     title = 'Average Hourly Wage',
#     cmap = 'Purples',
#     legend_min=0.45,
#     legend_max=1.5,
#     export_excel = True
# )

# %% [markdown]
# ### Compute average district yearly wage

# %%
average_yearly_wage_year = {}

# Ensure alignment between industry sectors and column names
yearly_wage_by_industry = yearly_wage_by_industry.loc[industry_dist_shares_1935.columns]

for year in yearly_wage_by_industry.columns:
    # Get wage vector for this year (aligned with industry sectors)
    wages = yearly_wage_by_industry[year]  # Series: index = industry sectors

    # Compute weighted average wage per district
    weighted_avg = industry_dist_shares_1935.dot(wages)

    # Store in dictionary (as a DataFrame to keep it consistent)
    average_yearly_wage_year[int(year)] = pd.DataFrame({
        'Average Wage': weighted_avg
    })

# %%
total_employment[1924][total_employment[1924].index.map(d_to_r)=='ŚLĄSKIE']

# %%
# # Plot district yearly wages
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/Industry/Wages/yearly/",
#     year_df_dict = average_yearly_wage_year,
#     col_name = 'Average Wage',
#     title = 'Average Yearly Wage',
#     cmap = 'Purples',
#     legend_min=980,
#     legend_max=3020,
#     export_excel = True
# )

# %% [markdown]
# ## Disaggregate regional industry VA to districts

# %% [markdown]
# ### Define regional industry VA disaggregator

# %% [markdown]
# For disaggregation of the regional GDP I use the average_yearly_wage*num_workers value for every district for big industry.

# %%
industry_disaggregator = {}
for year in all_years:
    industry_disaggregator[year] = empty_dist_df.copy()
    industry_disaggregator[year]["Disaggregator"] = average_yearly_wage_year[year]["Average Wage"]*total_employment[year]["Total Employment I-VII"]

# %% [markdown]
# Load regional industry VA estimates

# %%
regional_industry_va = read_economic_csv_input(adm_level='Region', input_csv_path=regional_industry_va_path)

# %% [markdown]
# ### Disaggregate regional industry VA estimates

# %%
for year, dist_df in industry_disaggregator.items():
    production_estimate = distribute_r_values_to_d(regional_industry_va, str(year), dist_df, "Disaggregator", "Industry VA", d_to_r)
    production_by_year[year]["Industry VA"] = production_estimate["Industry VA"]
    production_by_year[year]["Industry VA Per Capita"] = production_estimate["Industry VA"]/production_by_year[year]['Population']

# %% [markdown]
# # Private Services

# %% [markdown]
# ## Load data on trade permissions

# %%
trade_permissions_data_table_ids = [data_table.data_table_id for data_table in adm_history_processor.processed_data_metadata.items if data_table.category.eng=='Trade Permissions']
trade_permissions_dfs = [administrative_history.load_data_table(data_table_id = trade_permissions_data_table_id, version = 'harmonized', custom_grouping=d_city_mapping, custom_grouping_method = 'sum') for trade_permissions_data_table_id in trade_permissions_data_table_ids]
trade_permissions_year_df = {extract_date_parts(metadata.date)[0]: df for df, metadata, date in trade_permissions_dfs if extract_date_parts(metadata.date)[0] in [1924, 1925, 1928]}
# Strip numbers from the beginning of the 1935 column names
trade_permissions_1932 = {metadata.data_table_id: df for df, metadata, date in trade_permissions_dfs if extract_date_parts(metadata.date)[0] == 1932}
trade_permissions_1935 = {metadata.data_table_id: df for df, metadata, date in trade_permissions_dfs if extract_date_parts(metadata.date)[0] == 1935}
# Strip ": Together" from column names
for year, df in trade_permissions_year_df.items():
    df.columns = df.columns.str.replace(": Together", "", regex=False)
    print(df.columns)

# %% [markdown]
# ## Prepare 1932 total employment data

# %%
# Dict mapping "cat_i" to "Kategoria XR"
cat_to_kat = {
    'cat_1': 'Kategoria IR',
    'cat_2': 'Kategoria IIR',
    'cat_3': 'Kategoria IIIR',
    'cat_4': 'Kategoria IVR',
    'cat_5a': 'Kategoria VaR',
    'cat_5b': 'Kategoria VbR'
    }

trade_permissions_year_df[1932] = empty_dist_df.copy()
for cat, kat in cat_to_kat.items():
    trade_permissions_year_df[1932][kat] = trade_permissions_1932[f'1932_trade_permissions_{cat}_ready_clean'][f'{kat}: Total']

# %% [markdown]
# ## Estimate the number of employees

# %% [markdown]
# ### Estimate number of employees per district for 1924, 1925, 1928, and 1932

# %%
trade_size_cat = {
    "I": 12,
    "II": 6.5,
    "III": 3,
    "IV": 1.5,
    "Va": 1,
    "Vb": 1
    }

# %% [markdown]
# ### Estimate n. of employees for 1935

# %% [markdown]
# Both correlation, as well as log correlations of estimated total employment and total number of permissions are very high. The very high correlation is very well visible on the scatterplots too.
#
# For year 1935 we don't have the permissions by size, but we estimate simply the total number of permissions and extrapolate the employment estimate for 1925, 1928, and 1932 to 1935.
#
# The direct estimates of employment obtainted by this method may be systematically upwardly biased, because the Great Crisis probably caused the decrease in company size. However, they seem to be fairly appropriate for the purpose of disaggregation.

# %%
for year, df in trade_permissions_year_df.items():
    df = add_total_employment_column(trade_permissions_year_df[year], trade_size_cat, "Total Employment")
    df['Total n. Permissions'] = df.loc[:, df.columns != 'Total Employment'].sum(axis=1)
    trade_permissions_year_df[year] = df

# %%
def correlations(df, x_col, df_2, y_col):
    log_x_col = np.log1p(df[x_col])
    log_y_col = np.log1p(df_2[y_col])
    corr_log = log_x_col.corr(log_y_col)
    corr = df[x_col].corr(df_2[y_col])
    print(f"Correlation of {x_col} and {y_col} ({year}): {corr}, Correlation of log values: {corr_log}")

def scatterplot_columns(df, x_col, df_2, y_col, title=None, xlabel=None, ylabel=None):
    plt.figure(figsize=(8,6))
    plt.scatter(df[x_col], df_2[y_col], alpha=0.7)
    plt.title(title or f'{y_col} vs {x_col}')
    plt.xlabel(xlabel or x_col)
    plt.ylabel(ylabel or y_col)
    plt.grid(True)
    plt.show()

# %%
for year in [1924, 1925, 1928, 1932]:
    df = trade_permissions_year_df[year]
    correlations(df, 'Total Employment', df, 'Total n. Permissions')

# %%
scatterplot_columns(trade_permissions_year_df[1932], 'Total Employment', trade_permissions_year_df[1932], 'Total n. Permissions', 
                    title='Permissions vs Estimated Employment')

# %%
trade_permissions_year_df[1935] = empty_dist_df.copy()
trade_permissions_year_df[1935]["Total n. Permissions"] = trade_permissions_1935['1935-trade_permissions_total_ready_clean']['A-K. Commercial establishments total: Together'] + trade_permissions_1935['1935-trade_permissions_no_fixed_location_ready_clean']['A-K. Commercial establishments total: Together']

# %%
# Define ad-hoc function to compute average employment to permissions ratio.
def compute_average_emp_to_permission_ratio(trade_permissions_year_df: Dict[int, pd.DataFrame], years: List[int]) -> pd.Series:
    """
    Computes the average employment-to-permission ratio per district across given years,
    ignoring divisions by zero and missing values.
    """

    proportion_list = []

    for year in years:
        df = trade_permissions_year_df[year]
        with np.errstate(divide='ignore', invalid='ignore'):
            proportion = df["Total Employment"] / df["Total n. Permissions"]
            proportion.replace([np.inf, -np.inf], np.nan, inplace=True)
            proportion_list.append(proportion)

    proportions_df = pd.concat(proportion_list, axis=1)
    return proportions_df.mean(axis=1, skipna=True)

# %%
# Compute average employment-to-permission ratio for year 1935
avg_ratio = compute_average_emp_to_permission_ratio(
    trade_permissions_year_df,
    years=[1925, 1928, 1932]
)

# Multiply by 1935 permissions to estimate employment
trade_permissions_year_df[1935]["Total Employment"] = (
    avg_ratio * trade_permissions_year_df[1935]["Total n. Permissions"]
).fillna(0)

# %% [markdown]
# ## Extrapolate from 1925 missing 1924 values for Silesia

# %%
trade_permissions_year_df = fill_zero_values_by_proportional_scaling(year_to_df=trade_permissions_year_df, col_name="Total Employment", only_fill_indices=silesia_indices)

# %% [markdown]
# ## Interpolate the number of employees for the missing years

# %%
trade_permissions_year_df = interpolate_missing_years(year_to_df=trade_permissions_year_df, col_name="Total Employment",
                               all_years = all_years, empty_dist_df=empty_dist_df.copy(), extrapolate_trends = False)
trade_permissions_year_df = interpolate_missing_years(year_to_df=trade_permissions_year_df, col_name="Total n. Permissions",
                               all_years = all_years, empty_dist_df=empty_dist_df.copy(), extrapolate_trends = False)

# %% [markdown]
# ### Check 1932 correlation with communication and transport

# %%
correlations(trade_permissions_year_df[1932], 'Total Employment', census_1931_occupations_df, '9 Domestic service: Together')

# %%
scatterplot_columns(trade_permissions_year_df[1932], 'Total Employment', census_1931_occupations_df, '9 Domestic service: Together', 
                    title='Estimated Employment in Trade vs. Census Domestic Service Employment')

# %%
census_1931_occupations_df['4 Communication and transport - all: Together']

# %% [markdown]
# ## Prepare 1932 services mix value data

# %%
private_services_types = ['trade', 'trans_com', 'education', 'hygiene', 'lit_sci_culture', 'justice', 'health', 'religion', 'domestic_service', 'finance', 'immobility', 'other']

service_type_1932_dict = {
    ' Total': 'other',
    ' 1. All types of professional purchasing (total)': 'trade',
    ' a. Professional purchasing (agricultural products)': 'other',
    ' b. Professional purchasing (livestock)': 'other',
    ' c. Professional purchasing (plant and animal products)': 'other',
    ' 2. Food and colonial goods (exclusively)': 'trade',
    ' 3. Food products along with non-food items (excluding wine and spirits)': 'trade',
    ' 4. Meat, fats, and meat products (exclusively)': 'trade',
    ' 5. Catering establishments with and without alcohol': 'trade',
    ' 6. Wine, spirits, and beer (possibly with food and colonial goods)': 'trade',
    ' 7. Tobacco monopoly products': 'trade',
    ' 8. Textiles': 'trade',
    ' 9. Textiles with clothing, haberdashery, garments, and footwear': 'trade',
    ' 10. Ready-made clothing and haberdashery': 'trade',
    ' 11. Garments, garment parts, furs, and fur products': 'trade',
    ' 12. Footwear': 'trade',
    ' 13. Footwear with leather and shoemaking accessories': 'trade',
    ' 14. All types of leather and leather products (excluding footwear)': 'trade',
    ' 15. Machinery, tools, and technical goods (excluding agricultural)': 'trade',
    ' 16. Building materials and fuels': 'trade',
    ' 17. Furniture and all wooden products': 'trade',
    ' 18. Iron, ironware, enameled and aluminum goods (possibly with other goods)': 'trade',
    ' 19. Kitchenware, porcelain, faience, glassware, window panes, and mirrors': 'trade',
    ' 20. Soap, candles, paints, gasoline, kerosene, mineral oils, lubricants (soap shops)': 'trade',
    ' 21. Musical, optical, surgical instruments, photographic equipment and accessories': 'trade',
    ' 22. Watchmaking, jewelry, and silver-plated products': 'trade',
    ' 23. Electrical equipment, radio equipment, and all lighting accessories': 'trade',
    ' 24. Pharmacies': 'health',
    ' 25. Pharmaceutical warehouses, perfumeries, and cosmetic shops': 'hygiene',
    ' 26. Rubber goods, oilcloth, linoleum, galoshes, tarpaulins, tires, inner tubes, etc.': 'trade',
    ' 27. Bookstores, stationery, and paper products (possibly with other goods)': 'lit_sci_culture',
    ' 28. Agricultural machinery, tools, and goods': 'trade',
    ' 29. Agricultural-commercial syndicates and cooperatives': 'other',
    ' 30. Banks, exchange offices, and other short- and long-term credit institutions': 'finance',
    ' 31. Forwarding, transport, and communication enterprises': 'trans_com',
    ' 32. Other service enterprises (reading rooms, clinics, laundries, bathhouses, garages, dance halls, etc.)': 'other',
    ' 33. Hotels, boarding houses, furnished rooms, lodging houses': 'immobility',
    ' 34. Theaters, cinemas, and other performances': 'lit_sci_culture',
    ' 35. Insurance companies': 'finance',
    ' 36. Offices': 'justice',
    ' 37. Other enterprises not listed above': 'other',
    ' 38. Cards with no industry/branch specified': 'other',
    ' ZP. Industrial activities': 'other'
}

# %%
private_services_1932_dist_total_type_share = empty_dist_df.copy()
# Fill in private_services_1932_dist_total_type_share with total employment indicators
for cat, kat in cat_to_kat.items():
    cat_multiplier = trade_size_cat[kat.split(" ")[1][:-1]]
    for col_name in trade_permissions_1932[f'1932_trade_permissions_{cat}_ready_clean'].columns:
        kat_type = col_name.split(":")[1]
        if service_type_1932_dict[kat_type] in private_services_1932_dist_total_type_share.columns:
            private_services_1932_dist_total_type_share[service_type_1932_dict[kat_type]] += cat_multiplier*trade_permissions_1932[f'1932_trade_permissions_{cat}_ready_clean'][col_name]
        else:
            private_services_1932_dist_total_type_share[service_type_1932_dict[kat_type]] = cat_multiplier*trade_permissions_1932[f'1932_trade_permissions_{cat}_ready_clean'][col_name]

# Fill in missing private services shares indicators: education, religion, domestic_service

private_services_1932_dist_total_type_share['education'] = private_services_1932_dist_total_type_share['trade']
private_services_1932_dist_total_type_share['religion'] = private_services_1932_dist_total_type_share['trade']
private_services_1932_dist_total_type_share['domestic_service'] = census_1931_occupations_df['9 Domestic service: Together']

# Create private services shares dict for each year based on the average industry wages
private_services_by_year = copy.deepcopy(empty_year_df_dict)
for year, df in private_services_by_year.items():
    df = private_services_1932_dist_total_type_share.mul(
        average_hourly_wage_year[year]['Average Wage'],
        axis=0
    )
    df_rename_cols_dict = {col: f"{col}_share" for col in df.columns}
    df = df.rename(columns = df_rename_cols_dict)
    df = df.div(df.sum(axis=0), axis=1)
    private_services_by_year[year] = df

# %% [markdown]
# ## Disaggregate regional private services VA to districts

# %% [markdown]
# ### Define regional private services VA disaggregator

# %%
private_services_weights = {}
for year in trade_permissions_year_df.keys():
    private_services_weights[year] = empty_dist_df.copy()
    private_services_weights[year]['Weight'] = trade_permissions_year_df[year]['Total Employment']*average_hourly_wage_year[year]['Average Wage']

# %% [markdown]
# ### Load regional private services VA estimates from Wroński et al. (2025)

# %%
regional_private_services_va = {}
for service_type, path in regional_private_paths.items():
    regional_private_services_va[service_type] = read_economic_csv_input(adm_level='Region', input_csv_path=path)
    regional_private_services_va[service_type] = regional_private_services_va[service_type].drop('M. ST. WARSZAWA')

# %% [markdown]
# ### Disaggregate

# %%
private_services_columns = [f"Private Services ({service_type}) VA" for service_type in regional_private_services_va.keys()]
for year, dist_df in private_services_by_year.items():
    # Distribute each service according to its weight in the given year
    for service_type in regional_private_services_va.keys():
        production_estimate = distribute_r_values_to_d(regional_private_services_va[service_type], str(year), dist_df, f"{service_type}_share", f"Private Services ({service_type}) VA", d_to_r)
        production_by_year[year][f"Private Services ({service_type}) VA"] = production_estimate[f"Private Services ({service_type}) VA"]

    # Sum up all services and compute total Private Services VA
    production_by_year[year]["Private Services VA"] = production_by_year[year][private_services_columns].sum(axis=1)
    production_by_year[year]["Private Services VA Per Capita"] = production_by_year[year]["Private Services VA"]/production_by_year[year]['Population']

# %% [markdown]
# ### Plot

# %%
# # Plot Private Services VA Per Capita
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/Services/Private/VA_per_capita/",
#     year_df_dict = production_by_year,
#     col_name = 'Private Services VA Per Capita',
#     title = 'Private Services VA Per Capita',
#     export_excel = True,
#     cmap = 'Blues'
# )

# %%
# # Plot Private Services VA Per Capita
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/Services/Private/VA/",
#     year_df_dict = production_by_year,
#     col_name = 'Private Services VA',
#     title = 'Private Services VA',
#     export_excel = True,
#     cmap = 'Blues'
# )

# %% [markdown]
# Plot employment

# %%
# Compute employment per capita and logarithms of employment and employment per capita
for year in trade_permissions_year_df.keys():
    trade_permissions_year_df[year]['Total Employment Per Capita'] = trade_permissions_year_df[year]['Total Employment']/production_by_year[year]['Population']
    trade_permissions_year_df[year]['Log of Total Employment Per Capita'] = np.log(trade_permissions_year_df[year]['Total Employment Per Capita'])
    trade_permissions_year_df[year]['Log of Total Employment'] = np.log(trade_permissions_year_df[year]['Total Employment'])

# %%
# # Plot Private Services VA Per Capita
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/Services/Private/Employment/",
#     year_df_dict = trade_permissions_year_df,
#     col_name = 'Log of Total Employment',
#     title = 'Logarithm of Employment in Private Services',
#     export_excel = True,
#     legend_min=5.4,
#     legend_max=11.5,
#     cmap = 'Blues'
# )

# %%
# Plot Private Services VA Per Capita
plot_year_df_columns(
    administrative_history=administrative_history,
    custom_dist_grouping=d_city_mapping,
    plots_output_path=plots_output_path,
    path_suffix = "/Services/Private/Employment_per_capita/",
    year_df_dict = trade_permissions_year_df,
    col_name = 'Log of Total Employment Per Capita',
    title = 'Logarithm of Employment Per Capita in Private Services',
    export_excel = True,
    legend_min=-6.5,
    legend_max=-1.5,
    cmap = 'Blues'
)

# %% [markdown]
# # Public Services

# %%
census_1931_occupations_df
census_columns_rename_dict = {
    '5 Public service, church, social organizations and institutions: Together': 'Public service, church, social organizations and institutions',
    '7 Education and culture: Together': 'Education and culture',
    '8 Health care and hygiene, cleaning and social welfare: Together': 'Health care and hygiene, cleaning and social welfare',
    '9 Domestic service: Together': 'Domestic service'
}
census_1931_selected = census_1931_occupations_df[[
    '5 Public service, church, social organizations and institutions: Together',
    '7 Education and culture: Together',
    '8 Health care and hygiene, cleaning and social welfare: Together',
    '9 Domestic service: Together'
    ]]

census_1931_selected.rename(columns=census_columns_rename_dict, inplace = True)
census_1931_selected.columns

# %%
census_1931_selected_per_capita = census_1931_selected.div(production_by_year[year]['Population'], axis=0)

# %% [markdown]
# ### Load regional private services VA and employment estimates from Wroński et al. (2025)

# %%
regional_public_services_va = read_economic_csv_input(adm_level='Region', input_csv_path=regional_public_services_va_path)
regional_public_services_employment = read_economic_csv_input(adm_level='Region', input_csv_path=regional_public_services_employment_path)

# %% [markdown]
# ### Disaggregate

# %%
for year in all_years:
    production_estimate = distribute_r_values_to_d(regional_public_services_va, str(year), census_1931_selected_per_capita, 'Public service, church, social organizations and institutions', "Public Services VA", d_to_r)
    production_by_year[year]["Public Services VA"] = production_estimate["Public Services VA"]
    production_by_year[year]["Public Services VA Per Capita"] = production_estimate["Public Services VA"]/production_by_year[year]['Population']

    employment_estimate = distribute_r_values_to_d(regional_public_services_employment, str(year), census_1931_selected_per_capita, 'Public service, church, social organizations and institutions', "Public Services Employment", d_to_r)
    production_by_year[year]["Public Services Employment"] = employment_estimate["Public Services Employment"]

# %% [markdown]
# ### Plot

# %%
# # Plot Public Services VA Per Capita
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/Services/Public/VA_per_capita/",
#     year_df_dict = production_by_year,
#     col_name = 'Public Services VA Per Capita',
#     title = 'Public Services VA Per Capita',
#     export_excel = True,
#     cmap = 'Blues'
# )

# %%
# # Plot Public Services VA
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/Services/Public/VA/",
#     year_df_dict = production_by_year,
#     col_name = 'Public Services VA',
#     title = 'Public Services VA',
#     export_excel = True,
#     cmap = 'Blues'
# )

# %%
# # Plot Public Services Employment
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/Services/Public/Employment/",
#     year_df_dict = production_by_year,
#     col_name = 'Public Services Employment',
#     title = 'Public Services Employment',
#     export_excel = True,
#     cmap = 'Blues'
# )

# %% [markdown]
# # Total VA

# %%
price_deflator = {
    1924: 1.0,
    1925: 1.16,
    1926: 1.45,
    1927: 1.65,
    1928: 1.65,
    1929: 1.61,
    1930: 1.43,
    1931: 1.25,
    1932: 1.11,
    1933: 1.0,
    1934: 0.93,
    1935: 0.89,
    1936: 0.89,
    1937: 0.98,
    1938: 0.94
 }

# %%
for year in all_years:
    production_by_year[year]['VA_current_prices'] = production_by_year[year]['Agriculture VA'] + production_by_year[year]['Industry VA'] + production_by_year[year]['Private Services VA'] + production_by_year[year]['Public Services VA']
    production_by_year[year]['VA_current_prices_per_capita'] = production_by_year[year]['VA_current_prices']/production_by_year[year]['Population']
    
    production_by_year[year]['VA_constant_prices'] = production_by_year[year]['VA_current_prices']/price_deflator[year]
    production_by_year[year]['VA_constant_prices_per_capita'] = production_by_year[year]['VA_constant_prices']/production_by_year[year]['Population']

    production_by_year[year]['Agriculture_VA_constant_prices'] = production_by_year[year]['Agriculture VA']/price_deflator[year]
    production_by_year[year]['Agriculture_VA_constant_prices_per_capita'] = production_by_year[year]['Agriculture_VA_constant_prices']/production_by_year[year]['Population']

    production_by_year[year]['Industry_VA_constant_prices'] = production_by_year[year]['Industry VA']/price_deflator[year]
    production_by_year[year]['Industry_VA_constant_prices_per_capita'] = production_by_year[year]['Industry_VA_constant_prices']/production_by_year[year]['Population']

    production_by_year[year]['Private_Services_VA_constant_prices'] = production_by_year[year]['Private Services VA']/price_deflator[year]
    production_by_year[year]['Private_Services_VA_constant_prices_per_capita'] = production_by_year[year]['Private_Services_VA_constant_prices']/production_by_year[year]['Population']

    production_by_year[year]['Public_Services_VA_constant_prices'] = production_by_year[year]['Public Services VA']/price_deflator[year]
    production_by_year[year]['Public_Services_VA_constant_prices_per_capita'] = production_by_year[year]['Public_Services_VA_constant_prices']/production_by_year[year]['Population']

    production_by_year[year]['Services_VA_constant_prices'] = production_by_year[year]['Public_Services_VA_constant_prices'] + production_by_year[year]['Private_Services_VA_constant_prices']
    production_by_year[year]['Services_VA_constant_prices_per_capita'] = production_by_year[year]['Public_Services_VA_constant_prices_per_capita'] + production_by_year[year]['Private_Services_VA_constant_prices_per_capita']

    production_by_year[year]['VA_agriculture_share'] = 100*(production_by_year[year]['Agriculture VA']/production_by_year[year]['VA_current_prices'])
    production_by_year[year]['VA_industry_share'] = 100*(production_by_year[year]['Industry VA']/production_by_year[year]['VA_current_prices'])
    production_by_year[year]['VA_private_services_share'] = 100*(production_by_year[year]['Private Services VA']/production_by_year[year]['VA_current_prices'])
    production_by_year[year]['VA_public_services_share'] = 100*(production_by_year[year]['Public Services VA']/production_by_year[year]['VA_current_prices'])

# %% [markdown]
# ## Plot outcomes

# %% [markdown]
# ### Plot VA maps

# %%
# # Plot VA current prices
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/VA/current/",
#     year_df_dict = production_by_year,
#     col_name = 'VA_current_prices',
#     title = 'VA Current Prices',
#     export_excel = True,
#     cmap = 'Oranges'
# )

# %%
# # Plot VA current prices per capita
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/VA/current_per_capita/",
#     year_df_dict = production_by_year,
#     col_name = 'VA_current_prices_per_capita',
#     title = 'VA Current Prices Per Capita',
#     export_excel = True,
#     cmap = 'Oranges'
# )

# %%
# # Plot VA constant prices
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/VA/constant/",
#     year_df_dict = production_by_year,
#     col_name = 'VA_constant_prices',
#     title = 'VA Constant Prices',
#     export_excel = True,
#     cmap = 'Oranges'
# )

# %%
# # Plot VA constant prices per capita
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/VA/constant_per_capita/",
#     year_df_dict = production_by_year,
#     col_name = 'VA_constant_prices_per_capita',
#     title = 'Total Value Added Per Capita (1924 złotys)',
#     export_excel = True,
#     cmap = 'Oranges'
# )

# %% [markdown]
# ## Plot VA growth

# %%
va_constant_per_capita_growth=empty_dist_df.copy()
va_constant_per_capita_growth['Growth 1924-1931'] = 100*(production_by_year[1931]['VA_constant_prices_per_capita']-production_by_year[1924]['VA_constant_prices_per_capita'])/production_by_year[1924]['VA_constant_prices_per_capita']
va_constant_per_capita_growth['Growth 1931-1938'] = 100*(production_by_year[1938]['VA_constant_prices_per_capita']-production_by_year[1931]['VA_constant_prices_per_capita'])/production_by_year[1931]['VA_constant_prices_per_capita']
va_constant_per_capita_growth['Growth 1924-1938'] = 100*(production_by_year[1938]['VA_constant_prices_per_capita']-production_by_year[1924]['VA_constant_prices_per_capita'])/production_by_year[1924]['VA_constant_prices_per_capita']

# %%
plot_df_columns_and_export_excel(
    administrative_history=administrative_history,
    custom_dist_grouping=d_city_mapping,
    plots_output_path=plots_output_path,
    path_suffix = "/VA/constant_per_capita/Growth/",
    df = va_constant_per_capita_growth,
    col_title_prefix = '% of VA Constant Prices Per Capita',
    cmap = 'Reds',
    export_excel = True
)

# %% [markdown]
# ### Plot convergence

# %% [markdown]
# Value Added

# %%
# VA per capita - color by region group
plot_convergence(
    year_df_dict=production_by_year,
    values_column='VA_constant_prices_per_capita',
    color_by_district=True,
    d_to_group=d_to_r_group,
    group_to_color=r_group_to_color,
    plots_output_path=plots_output_path,
    path_suffix = "/VA/constant_per_capita/paritions_"
    )

# VA per capita - color by big_cities
plot_convergence(
    year_df_dict=production_by_year,
    values_column='VA_constant_prices_per_capita',
    color_by_district=True,
    d_to_group=is_big_city,
    group_to_color=big_cities_to_color,
    plots_output_path=plots_output_path,
    path_suffix = "/VA/constant_per_capita/big_cities_"
    )

# %%
# # Agriculture VA per capita - color by region group
# plot_convergence(
#     year_df_dict=production_by_year,
#     values_column='Agriculture_VA_constant_prices_per_capita',
#     color_by_district=True,
#     d_to_group=d_to_r_group,
#     group_to_color=r_group_to_color,
#     plots_output_path=plots_output_path,
#     path_suffix = "/VA/disaggregation/agriculture/partitions_"
#     )

# # Agriculture VA per capita - color by big_cities
# plot_convergence(
#     year_df_dict=production_by_year,
#     values_column='Agriculture_VA_constant_prices_per_capita',
#     color_by_district=True,
#     d_to_group=is_big_city,
#     group_to_color=big_cities_to_color,
#     plots_output_path=plots_output_path,
#     path_suffix = "/VA/disaggregation/agriculture/big_cities_"
#     )

# %% [markdown]
# Industry

# %%
# # Industry VA per capita
# plot_convergence(
#     year_df_dict=production_by_year,
#     values_column='Industry_VA_constant_prices_per_capita',
#     color_by_district=True,
#     d_to_group=d_to_r_group,
#     group_to_color=r_group_to_color,
#     plots_output_path=plots_output_path,
#     path_suffix = "/VA/disaggregation/industry/partitions_"
#     )

# # Industry VA per capita
# plot_convergence(
#     year_df_dict=production_by_year,
#     values_column='Industry_VA_constant_prices_per_capita',
#     color_by_district=True,
#     d_to_group=is_big_city,
#     group_to_color=big_cities_to_color,
#     plots_output_path=plots_output_path,
#     path_suffix = "/VA/disaggregation/industry/big_cities_"
#     )

# %% [markdown]
# Private Services

# %%
# # Private Services VA per capita
# plot_convergence(
#     year_df_dict=production_by_year,
#     values_column='Private_Services_VA_constant_prices_per_capita',
#     color_by_district=True,
#     d_to_group=d_to_r_group,
#     group_to_color=r_group_to_color,
#     plots_output_path=plots_output_path,
#     path_suffix = "/VA/disaggregation/private_services/partitions_"
#     )

# # Private Services VA per capita
# plot_convergence(
#     year_df_dict=production_by_year,
#     values_column='Private_Services_VA_constant_prices_per_capita',
#     color_by_district=True,
#     d_to_group=is_big_city,
#     group_to_color=big_cities_to_color,
#     plots_output_path=plots_output_path,
#     path_suffix = "/VA/disaggregation/private_services/big_cities_"
#     )

# %% [markdown]
# Public Services

# %%
# # Public Services VA per capita
# plot_convergence(
#     year_df_dict=production_by_year,
#     values_column='Public_Services_VA_constant_prices_per_capita',
#     color_by_district=True,
#     d_to_group=d_to_r_group,
#     group_to_color=r_group_to_color,
#     plots_output_path=plots_output_path,
#     path_suffix = "/VA/disaggregation/public_services/partitions_"
#     )

# # Public Services VA per capita
# plot_convergence(
#     year_df_dict=production_by_year,
#     values_column='Public_Services_VA_constant_prices_per_capita',
#     color_by_district=True,
#     d_to_group=is_big_city,
#     group_to_color=big_cities_to_color,
#     plots_output_path=plots_output_path,
#     path_suffix = "/VA/disaggregation/public_services/big_cities_"
#     )

# %%
# adm_history_plotter.plot_dataset(
#     df=crops_prices_year_df[1935],
#     col_name='Pszenica: Together',
#     adm_level='District',
#     adm_state_date=adm_history_processor.harmonize_to_date,
#     custom_grouping = d_city_mapping
# )

# %% [markdown]
# ### Plot VA per sector

# %% [markdown]
# Agriculture

# %%
# # Value Added
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/Agriculture/VA/",
#     year_df_dict = production_by_year,
#     col_name = 'Agriculture_VA_constant_prices',
#     title = 'Agriculture Value Added (1924 złotys)',
#     cmap = 'Greens',
#     export_excel = True
# )

# %%
# # Value Added Per Capita
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/Agriculture/VA_per_capita/",
#     year_df_dict = production_by_year,
#     col_name = 'Agriculture_VA_constant_prices_per_capita',
#     title = 'Agriculture Value Added Per Capita (1924 złotys)',
#     cmap = 'Greens',
#     export_excel = True
# )

# %% [markdown]
# Industry

# %%
# # Value Added
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/Industry/VA/",
#     year_df_dict = production_by_year,
#     col_name = 'Industry_VA_constant_prices',
#     title = 'Industry Value Added (1924 złotys)',
#     cmap = 'Purples',
#     export_excel = True
# )

# %%
# # Value Added Per Capita
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/Industry/VA_per_capita/",
#     year_df_dict = production_by_year,
#     col_name = 'Industry_VA_constant_prices_per_capita',
#     title = 'Industry Value Added Per Capita (1924 złotys)',
#     cmap = 'Purples',
#     export_excel = True
# )

# %% [markdown]
# Private and Public Services Together

# %%
# # Value Added
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/Services/VA/",
#     year_df_dict = production_by_year,
#     col_name = 'Services_VA_constant_prices',
#     title = 'Services Value Added (1924 złotys)',
#     cmap = 'Blues',
#     export_excel = True
# )

# %%
# # Value Added Per Capita
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/Services/VA_per_capita/",
#     year_df_dict = production_by_year,
#     col_name = 'Services_VA_constant_prices_per_capita',
#     title = 'Services Value Added Per Capita (1924 złotys)',
#     cmap = 'Blues',
#     export_excel = True
# )

# %% [markdown]
# ### Plot VA shares

# %%
# # Plot agriculture VA share
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/VA/disaggregation/agriculture/",
#     year_df_dict = production_by_year,
#     col_name = 'VA_agriculture_share',
#     title = 'Agriculture Share in VA (%)',
#     export_excel = True,
#     cmap = 'Greens'
# )

# %%
# # Plot industry VA share
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/VA/disaggregation/industry/",
#     year_df_dict = production_by_year,
#     col_name = 'VA_industry_share',
#     title = 'Industry Share in VA (%)',
#     export_excel = True
# )

# %%
# # Plot private services VA share
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/VA/disaggregation/private_services/",
#     year_df_dict = production_by_year,
#     col_name = 'VA_private_services_share',
#     title = 'Private Services Share in VA (%)',
#     export_excel = True,
#     cmap = 'Blues'
# )

# %%
# # Plot public services VA share
# plot_year_df_columns(
#     administrative_history=administrative_history,
#     custom_dist_grouping=d_city_mapping,
#     plots_output_path=plots_output_path,
#     path_suffix = "/VA/disaggregation/public_services/",
#     year_df_dict = production_by_year,
#     col_name = 'VA_public_services_share',
#     title = 'Public Services Share in VA (%)',
#     export_excel = True,
#     cmap = 'Blues'
# )

# %% [markdown]
# # Analyze the Spatial Convergence

# %% [markdown]
# ## Convergence of VA per capita

# %%
plot_va_growth_scatter(production_by_year, all_years=all_years, save_to_path=plots_output_path+"/Convergence_Analysis/VA_per_capita/va_growth_with_regression.png", d_to_r_group=None, r_group_to_color=None)
plot_va_growth_scatter(production_by_year, all_years=all_years, save_to_path=plots_output_path+"/Convergence_Analysis/VA_per_capita/va_growth_with_regression_r_group.png", d_to_r_group=d_to_r_group, r_group_to_color=r_group_to_color, x_label='Value Added Per Capita in 1924 (1924 złoty)')
plot_va_growth_scatter(production_by_year, all_years=all_years, save_to_path=plots_output_path+"/Convergence_Analysis/VA_per_capita/va_growth_with_regression_big_cities.png", d_to_r_group=is_big_city, r_group_to_color=big_cities_to_color)

# %%
# Compute the regional demeaned VA in constant prices per capita and add to the production_by_year df.

for year, df in production_by_year.items():
        # Get region sums for this year
        regional_df = sum_up_regions(df, d_to_r)

        # Compute regional mean VA per capita = VA sum / Population sum
        regional_va_mean_per_capita = regional_df['VA_constant_prices_per_capita']

        # Map districts to their region means
        region_for_district = df.index.map(d_to_r)
        district_regional_mean = region_for_district.map(regional_va_mean_per_capita)

        # Subtract regional mean from district value
        df['VA_constant_prices_per_capita_demeaned'] = df['VA_constant_prices_per_capita'] - district_regional_mean

        # Regional mean
        df['VA_constant_prices_per_capita_regional_mean'] = district_regional_mean

        # Assign back to dict (optional since df is mutable)
        production_by_year[year] = df

# %%
plot_va_growth_scatter(production_by_year, all_years=all_years, x_col_name='VA_constant_prices_per_capita_demeaned', save_to_path=plots_output_path+"/Convergence_Analysis/VA_per_capita/va_growth_vs_VA_pc_region_demeaned.png", d_to_r_group=d_to_r_group, r_group_to_color=r_group_to_color, title = 'Growth of VA in Constant Prices Per Capita from 1924 to 1938', x_label = 'VA (CP, Per Capita) demeaned by average regional VA (CP, Per Capita)')
plot_va_growth_scatter(production_by_year, all_years=all_years, x_col_name='VA_constant_prices_per_capita_demeaned', save_to_path=plots_output_path+"/Convergence_Analysis/VA_per_capita/va_growth_vs_VA_pc_region_demeaned_is_big_city.png", d_to_r_group=is_big_city, r_group_to_color=big_cities_to_color, title = 'Growth of VA in Constant Prices Per Capita from 1924 to 1938', x_label = 'VA (CP, Per Capita) demeaned by average regional VA (CP, Per Capita)')
plot_va_growth_scatter(production_by_year, all_years=all_years, x_col_name='VA_constant_prices_per_capita_demeaned', save_to_path=plots_output_path+"/Convergence_Analysis/VA_per_capita/va_growth_vs_VA_pc_region_demeaned_example_r.png", d_to_r_group=d_to_example_r, r_group_to_color=example_r_to_color, title = 'Growth of VA in Constant Prices Per Capita from 1924 to 1938', x_label = 'VA (CP, Per Capita) demeaned by average regional VA (CP, Per Capita)')

# %%
plot_va_growth_scatter(production_by_year, all_years=all_years, x_col_name='VA_constant_prices_per_capita_regional_mean', save_to_path=plots_output_path+"/Convergence_Analysis/VA_per_capita/va_growth_vs_VA_pc_region_mean.png", d_to_r_group=d_to_r_group, r_group_to_color=r_group_to_color, title = 'Growth of VA in Constant Prices Per Capita from 1924 to 1938', x_label = 'VA (CP, Per Capita) demeaned by average regional VA (CP, Per Capita)')

# %% [markdown]
# ## Spatial Autocorrelation

# %%
spatial_autocorrelation_over_time(year_to_df=production_by_year, col_name='VA_constant_prices_per_capita', distance_matrix=distance_matrix, threshold=120000, measures=["moran", "geary"], var_name_in_title="Total Value Added Per Capita (1924 złotys)", save_to_path=plots_output_path+"/Convergence_Analysis/VA_per_capita/spatial_VA_cp_per_capita.png")

# %% [markdown]
# ### Within- vs. Between-Regional variance (decomposition)

# %%
# Decompose the variance of VA in constant prices per capita to between-region and within-region variance.
decomp_df = variance_decomposition(production_by_year, d_to_r, 'VA_constant_prices_per_capita')
plot_cumulative_variance_decomposition(decomp_df=decomp_df, path_to_save = plots_output_path+"/Convergence_Analysis/VA_per_capita/", variable_name = 'VA_constant_prices_per_capita')

# %% [markdown]
# ### 2-level Beta-Convergence Model

# %%
beta_2_level_convergence_result = estimate_multilevel_convergence(production_by_year, district_to_region=d_to_r)

# %% [markdown]
# ## Contributions of Sectors to Inequality

# %% [markdown]
# ### Theil decompositions

# %%
spatial_inequality_results = analyze_all_years_theil(production_by_year=production_by_year, d_to_r=d_to_r, sum_up_regions=sum_up_regions)
plot_theil_decompositions(spatial_inequality_results, save_path=plots_output_path+"/Convergence_Analysis/VA_per_capita/", sector_colors=sector_colors)

# %% [markdown]
# ### Coefficients of Variation (districts)

# %%
plot_cv_over_time(production_by_year, 'VA_constant_prices_per_capita', save_path=plots_output_path+"/Convergence_Analysis/dist_total_VA_constant_per_capita", var_title='Value Added Per Capita (1924 złotys)')
plot_cv_over_time(production_by_year, 'Agriculture_VA_constant_prices_per_capita', save_path=plots_output_path+"/Convergence_Analysis/agriculture_VA_constant_per_capita")
plot_cv_over_time(production_by_year, 'Industry_VA_constant_prices_per_capita', save_path=plots_output_path+"/Convergence_Analysis/industry_VA_constant_per_capita")
plot_cv_over_time(production_by_year, 'Public_Services_VA_constant_prices_per_capita', save_path=plots_output_path+"/Convergence_Analysis/public_services_VA_constant_per_capita")
plot_cv_over_time(production_by_year, 'Private_Services_VA_constant_prices_per_capita', save_path=plots_output_path+"/Convergence_Analysis/private_services_VA_constant_per_capita")

# %% [markdown]
# ### Coefficients of Variation (whole regions)

# %%
plot_cv_over_time({year:sum_up_regions(production_by_year[year], d_to_r) for year in production_by_year.keys()}, 'VA_constant_prices_per_capita', save_path=plots_output_path+"/Convergence_Analysis/region_total_VA_constant_per_capita")
plot_cv_over_time({year:sum_up_regions(production_by_year[year], d_to_r) for year in production_by_year.keys()}, 'Agriculture_VA_constant_prices_per_capita', save_path=plots_output_path+"/Convergence_Analysis/region_agriculture_VA_constant_per_capita")
plot_cv_over_time({year:sum_up_regions(production_by_year[year], d_to_r) for year in production_by_year.keys()}, 'Industry_VA_constant_prices_per_capita', save_path=plots_output_path+"/Convergence_Analysis/region_industry_VA_constant_per_capita")
plot_cv_over_time({year:sum_up_regions(production_by_year[year], d_to_r) for year in production_by_year.keys()}, 'Public_Services_VA_constant_prices_per_capita', save_path=plots_output_path+"/Convergence_Analysis/region_public_services_VA_constant_per_capita")
plot_cv_over_time({year:sum_up_regions(production_by_year[year], d_to_r) for year in production_by_year.keys()}, 'Private_Services_VA_constant_prices_per_capita', save_path=plots_output_path+"/Convergence_Analysis/region_private_services_VA_constant_per_capita")

# %%
variables = ['VA_constant_prices_per_capita', 'Agriculture_VA_constant_prices_per_capita', 'Industry_VA_constant_prices_per_capita', 'Services_VA_constant_prices_per_capita']
var_titles = {var:var.split("_")[0] if var.split("_")[0]!="VA" else "Total" for var in variables}
var_colors = {
    'VA_constant_prices_per_capita': 'red',
    'Agriculture_VA_constant_prices_per_capita': 'green',
    'Industry_VA_constant_prices_per_capita': 'purple',
    'Services_VA_constant_prices_per_capita': 'darkblue'
}
plot_many_cvs_over_time(production_by_year, variables, save_path=plots_output_path+"/Convergence_Analysis/Sector_Comparison/VA_cp_per_capita_CV_by_sector", var_titles=var_titles, var_colors=var_colors, title = "District Value Added Per Capita by Sector")

# %% [markdown]
# # Convergence of single sectors

# %% [markdown]
# ## Agriculture

# %% [markdown]
# ### Theil Regional Decomposition

# %%
plot_theil_decomposition_sequence(production_by_year, 'Agriculture_VA_constant_prices_per_capita', save_path=plots_output_path+"/Convergence_Analysis/Agriculture/theil_agriculture_VA_constant_per_capita", d_to_r=d_to_r)

# %% [markdown]
# ### CVs

# %%
variables = ['Pszenica', 'Żyto', 'Jęczmień', 'Owies', 'Ziemniaki']
var_titles = {
    'Pszenica': 'Wheat',
    'Żyto': 'Rye',
    'Jęczmień': 'Barley',
    'Owies': 'Oats',
    'Ziemniaki': 'Potatoes'
}
plot_many_cvs_over_time(crops_prices_year_df_clean, variables, save_path=plots_output_path+"/Convergence_Analysis/Agriculture/crop_prices_CV", var_titles=var_titles, title="Crop Prices")

# %%
variables = ['Pszenica_yields_per_ha', 'Żyto_yields_per_ha', 'Jęczmień_yields_per_ha', 'Owies_yields_per_ha', 'Ziemniaki_yields_per_ha']
var_titles = {
    'Pszenica_yields_per_ha': 'Wheat',
    'Żyto_yields_per_ha': 'Rye',
    'Jęczmień_yields_per_ha': 'Barley',
    'Owies_yields_per_ha': 'Oats',
    'Ziemniaki_yields_per_ha': 'Potatoes'
}
plot_many_cvs_over_time(crops_production_years, variables, save_path=plots_output_path+"/Convergence_Analysis/Agriculture/yields_from_ha_CV", var_titles=var_titles, title="Crop Yields per Hectare")

# %%
livestock_translations = {
    'Konie': 'Horses',
    'Bydło rogate': 'Cows',
    'Trzoda chlewna': 'Pigs',
    'Owce i kozy': 'Sheep and Goats'
}

for year, df in livestock_year_df_dict.items():
    for col in ['Konie: Together', 'Bydło rogate: Together', 'Trzoda chlewna: Together', 'Owce i kozy: Together']:
        new_col = livestock_translations[col.split(':')[0]]+" Per Capita"
        df[new_col] = df[col]/production_by_year[year]['Population']

# %%
variables = [f"{name} Per Capita" for name in livestock_translations.values()]
plot_many_cvs_over_time(livestock_year_df_dict, variables, save_path=plots_output_path+"/Convergence_Analysis/Agriculture/Livestock_by_type_CV", var_titles=var_titles)

# %%
plot_cv_over_time(livestock_year_df_dict, 'Livestock_Units_per_capita', save_path=plots_output_path+"/Convergence_Analysis/Agriculture/Livestock_Units_per_capita_CV", var_title='Livestock Units (Computed According to Dederko (1937)) Per Capita')

# %% [markdown]
# Theil-Index

# %%
plot_theil_decomposition_sequence(livestock_year_df_dict, 'Livestock_Units_per_capita', save_path=plots_output_path+"/Convergence_Analysis/Agriculture/theil_Livestock_Units_per_capita_CV", var_title='Livestock Units (Computed According to Dederko (1937)) Per Capita', d_to_r=d_to_r, pop_by_year=production_by_year)

# %% [markdown]
# ### Spatial convergence

# %% [markdown]
# Value Added Per Capita

# %%
spatial_autocorrelation_over_time(year_to_df=production_by_year, col_name='Agriculture_VA_constant_prices_per_capita', distance_matrix=distance_matrix, threshold=120000, var_name_in_title="Agriculture Value Added Per Capita (1924 złotys)", save_to_path=plots_output_path+"/Convergence_Analysis/Agriculture/spatial_Agriculture_VA_cp_per_capita.png")

# %% [markdown]
# 5 Main Crops Total Value Per Capita

# %%
spatial_autocorrelation_over_time(year_to_df=crops_production_years, col_name='5 Main Crops Value Per Capita', distance_matrix=distance_matrix, threshold=120000, var_name_in_title="5 Main Crops Production Value Per Capita (1924 złotys)", save_to_path=plots_output_path+"/Convergence_Analysis/Agriculture/spatial_5_main_crops_per_capita.png")

# %% [markdown]
# Livestock Per Capita

# %%
spatial_autocorrelation_over_time(year_to_df=livestock_year_df_dict, col_name='Livestock_Units_per_capita', distance_matrix=distance_matrix, threshold=120000, var_name_in_title="Livestock Value Added Per Capita (1924 złotys)", save_to_path=plots_output_path+"/Convergence_Analysis/Agriculture/spatial_Livestock_VA_cp_per_capita.png")

# %% [markdown]
# Livestock Per Capita by Type

# %%
variables = [f"{name} Per Capita" for name in livestock_translations.values()]
moran_df = plot_morans_I_over_time(
    production_by_year=livestock_year_df_dict,
    weights=weights,
    variables=variables,
    threshold=120000,
    save_path=plots_output_path + "/Convergence_Analysis/Agriculture/Morans_I_livestock.png",
    title="of Livestock Per Capita"
)

# %% [markdown]
# Yields from hectare

# %%
variables = [
    'Pszenica_yields_per_ha', 
    'Żyto_yields_per_ha', 
    'Jęczmień_yields_per_ha', 
    'Owies_yields_per_ha', 
    'Ziemniaki_yields_per_ha'
]

var_titles = {
    'Pszenica_yields_per_ha': 'Wheat',
    'Żyto_yields_per_ha': 'Rye',
    'Jęczmień_yields_per_ha': 'Barley',
    'Owies_yields_per_ha': 'Oats',
    'Ziemniaki_yields_per_ha': 'Potatoes'
}

# Assuming you have 'crops_production_years' dict {year: DataFrame}
# and 'distance_matrix' ready

moran_df = plot_morans_I_over_time(
    production_by_year=crops_production_years,
    weights=weights,
    variables=variables,
    var_titles=var_titles,
    threshold=120000,
    save_path=plots_output_path + "/Convergence_Analysis/Agriculture/Morans_I_crop_yields.png",
    title="of Crop Yields per Hectare"
)

# %% [markdown]
# Prices

# %%
variables = ['Pszenica', 'Żyto', 'Jęczmień', 'Owies', 'Ziemniaki']
var_titles = {
    'Pszenica': 'Wheat',
    'Żyto': 'Rye',
    'Jęczmień': 'Barley',
    'Owies': 'Oats',
    'Ziemniaki': 'Potatoes'
}

# Assuming you have 'crops_production_years' dict {year: DataFrame}
# and 'distance_matrix' ready

moran_df = plot_morans_I_over_time(
    production_by_year=crops_prices_year_df_clean,
    weights=weights,
    variables=variables,
    var_titles=var_titles,
    threshold=120000,
    save_path=plots_output_path + "/Convergence_Analysis/Agriculture/Morans_I_crop_prices.png",
    title="of Crop Prices per Hectare"
)

# %% [markdown]
# ## Industry

# %% [markdown]
# Industry VA Per Capita CV

# %%
plot_cv_over_time({year:df for year, df in production_by_year.items() if year in [1924,1925,1926,1927,1928,1935,1936,1937,1938]}, 'Industry_VA_constant_prices_per_capita', var_title="Industry Value Added Per Capita (1924 złotys)", save_path=plots_output_path+"/Convergence_Analysis/Industry/Industry_VA_per_capita_CV")

# %% [markdown]
# Theil-index

# %%
plot_theil_decomposition_sequence({year:df for year, df in production_by_year.items() if year in [1924,1925,1926,1927,1928,1935,1936,1937,1938]}, 'Industry_VA_constant_prices_per_capita', var_title="Industry Value Added Per Capita (1924 złotys)", save_path=plots_output_path+"/Convergence_Analysis/Industry/Theil_Industry_VA_per_capita", d_to_r=d_to_r, pop_by_year=production_by_year)

# %% [markdown]
# Spatial autocorrelation

# %%
spatial_autocorrelation_over_time(year_to_df={year:df for year, df in production_by_year.items() if year in [1924,1925,1926,1927,1928,1935,1936,1937,1938]}, col_name='Industry_VA_constant_prices_per_capita', distance_matrix=distance_matrix, threshold=120000, var_name_in_title="Industry Value Added Per Capita (1924 złotys)", save_to_path=plots_output_path+"/Convergence_Analysis/Industry/spatial_Industry_VA_per_capita")

# %% [markdown]
# ### Employment

# %% [markdown]
# Coefficient of Variation

# %%
for year in total_employment.keys():
    total_employment[year]['Employment Per Capita'] = total_employment[year]['Total Employment I-VII']/production_by_year[year]['Population']

# %% [markdown]
# Coefficient of Variation

# %%
plot_cv_over_time({year:df for year, df in total_employment.items() if year in [1924,1925,1926,1927,1928,1935,1936,1937,1938]}, 'Employment Per Capita', var_title="Employment in Industry Per Capita", save_path=plots_output_path+"/Convergence_Analysis/Industry/Employment_per_capita_CV")

# %% [markdown]
# Theil-index

# %%
plot_theil_decomposition_sequence({year:df for year, df in total_employment.items() if year in [1924,1925,1926,1927,1928,1935,1936,1937,1938]}, 'Total Employment I-VII (Per Capita)', var_title="Employment in Industry", save_path=plots_output_path+"/Convergence_Analysis/Industry/Theil_Industry_Employment_per_capita", d_to_r=d_to_r, pop_by_year=production_by_year)

# %% [markdown]
# Spatial Autocorrelation

# %%
# Spatial autocorrelation of industry employment
spatial_autocorrelation_over_time(year_to_df={year:df for year, df in total_employment.items() if year in [1924,1925,1926,1927,1928,1935,1936,1937,1938]}, col_name='Employment Per Capita', distance_matrix=distance_matrix, threshold=100000, var_name_in_title="Yearly Wage in Industry", save_to_path=plots_output_path+"/Convergence_Analysis/Industry/spatial_employment")

# %% [markdown]
# ### Coefficients of Variation for Wages

# %%
plot_cv_over_time(average_hourly_wage_year, 'Average Wage', save_path=plots_output_path+"/Convergence_Analysis/Industry/hourly_wage_CV", var_title="Average District Hourly Wage in Industry")
plot_cv_over_time(average_yearly_wage_year, 'Average Wage', save_path=plots_output_path+"/Convergence_Analysis/Industry/yearly_wage_CV", var_title="Average District Yearly Wage in Industry")

# %% [markdown]
# ### Theil-Index of Wages

# %%
plot_theil_decomposition_sequence(average_hourly_wage_year, 'Average Wage', var_title="District Average Hourly Wage", save_path=plots_output_path+"/Convergence_Analysis/Industry/Theil_Industry_Hourly_Wage", d_to_r=d_to_r, pop_by_year=production_by_year)

# %%
plot_theil_decomposition_sequence(average_yearly_wage_year, 'Average Wage', var_title="District Average Yearly Wage", save_path=plots_output_path+"/Convergence_Analysis/Industry/Theil_Industry_Yearly_Wage", d_to_r=d_to_r, pop_by_year=production_by_year)

# %% [markdown]
# ### Spatial Autocorrelation of Wages

# %% [markdown]
# Yearly Wages

# %%
# Spatial autocorrelation of average YEARLY wage
spatial_autocorrelation_over_time(year_to_df=average_yearly_wage_year, col_name='Average Wage', distance_matrix=distance_matrix, threshold=100000, var_name_in_title="Yearly Wage in Industry", save_to_path=plots_output_path+"/Convergence_Analysis/Industry/spatial_yearly_wage")

# %% [markdown]
# Hourly Wages

# %%
# Spatial autocorrelation of average HOURLY wage
spatial_autocorrelation_over_time(year_to_df=average_hourly_wage_year, col_name='Average Wage', distance_matrix=distance_matrix, threshold=100000, var_name_in_title="Hourly Industry Wage", save_to_path=plots_output_path+"/Convergence_Analysis/Industry/spatial_hourly_wage")

# %% [markdown]
# ## Services

# %%
plot_cv_over_time(production_by_year, 'Services_VA_constant_prices_per_capita', var_title="Services Value Added Per Capita (1924 złotys)", save_path=plots_output_path+"/Convergence_Analysis/Services/Services_VA_per_capita_CV")

# %%
plot_theil_decomposition_sequence(production_by_year, 'Services_VA_constant_prices_per_capita', var_title="Services Value Added Per Capita (1924 złotys)", save_path=plots_output_path+"/Convergence_Analysis/Services/Theil_Services_VA_per_capita", d_to_r=d_to_r, pop_by_year=production_by_year)

# %%
spatial_autocorrelation_over_time(production_by_year, col_name='Services_VA_constant_prices_per_capita', distance_matrix=distance_matrix, threshold=120000, var_name_in_title="Services Value Added Per Capita (1924 złotys)", save_to_path=plots_output_path+"/Convergence_Analysis/Services/spatial_Services_VA_per_capita")

# %%
for year in trade_permissions_year_df.keys():
    trade_permissions_year_df[year]['Total Employment Per Capita'] = trade_permissions_year_df[year]['Total Employment']/production_by_year[year]['Population']

# %%
plot_cv_over_time(trade_permissions_year_df, 'Total Employment Per Capita', var_title="Employment in Private Services Per Capita", save_path=plots_output_path+"/Convergence_Analysis/Services/Employment_Private_Services_per_capita_CV")

# %%
plot_theil_decomposition_sequence(trade_permissions_year_df, 'Total Employment Per Capita', var_title="Employment in Private Services Per Capita", save_path=plots_output_path+"/Spatial_Inequality/Services/Theil_Private_Services_Employment_per_capita", d_to_r=d_to_r, pop_by_year=production_by_year)

# %%
spatial_autocorrelation_over_time(trade_permissions_year_df, col_name='Total Employment Per Capita', distance_matrix=distance_matrix, threshold=120000, var_name_in_title="Employment in Private Services Per Capita", save_to_path=plots_output_path+"/Convergence_Analysis/Services/spatial_Private_Services_Employment_per_capita")

# %% [markdown]
# # Backup - additional examples of function use

# %% [markdown]
# ## Harmonize an additional CSV file

# %%
# _, data_table_metadata_dict, _ = adm_history_api.load_data_table(data_table_id = '30.06.1938-livestock_ready', version='original')

# %%
# input_csv_path = adm_history_processor.adm_units_raw_data_folder + data_table_metadata_dict.data_table_id + ".csv"
# output_csv_path = adm_history_processor.processed_data_output_folder + data_table_metadata_dict.data_table_id + ".csv"
# #Harmonize single csv file
# adm_history_processor.process_csv_file(
#                     input_csv_path=input_csv_path,
#                     output_csv_path=output_csv_path,
#                     data_table_metadata_dict=data_table_metadata_dict,
#                     date_to=reference_date
#                 )
